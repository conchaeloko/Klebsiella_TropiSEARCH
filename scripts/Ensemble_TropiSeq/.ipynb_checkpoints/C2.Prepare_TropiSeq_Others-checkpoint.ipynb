# %%
# Ground modules
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from Bio import SeqIO
from itertools import product
import random
from collections import Counter
import json
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import logging
import subprocess
from multiprocessing.pool import ThreadPool
import joblib

# SCikitlearn modules :
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report , roc_auc_score

# Scipy modules : 
from scipy.stats import fisher_exact

# %%
# Make the blastp DB of all the dpo sequences :

path_seqbased = "/media/concha-eloko/Linux/PPT_clean/Seqbased_model"
path_db = f"{path_seqbased}/TropiSeq/TropiSeq_0.85.db"
path_work = "/media/concha-eloko/Linux/PPT_clean"


# Run makeblast command :
fasta_file = f"{path_seqbased}/cdhit_clusters_2912/0.85.out"

blast_command = f"makeblastdb -in {fasta_file} -dbtype prot -out {path_seqbased}/TropiSeq/TropiSeq_0.85.db"
#make_blast_process = subprocess.Popen(blast_command, shell =True, stdout = subprocess.PIPE, stderr=subprocess.STDOUT)
#mkblast_out, mkblast_err = make_blast_process.communicate()
#print(mkblast_out , mkblast_err)

# Relevant files :
dico_cluster = json.load(open(f"{path_seqbased}/dico_cluster.cdhit__0.85.json"))
dico_cluster_r = {ref_dpo : key_dpo for key_dpo,list_dpo in dico_cluster.items() for ref_dpo in list_dpo}

# %%
final_annotation = pd.read_csv(f"{path_work}/labeling_depo_clusters.PPT.0804.tsv", sep = "\t", header = 0)
final_annotation_tropiseq = final_annotation[final_annotation["Tropiseq_KLtypes"] != "None"]
final_annotation_tropiseq = final_annotation_tropiseq.drop_duplicates(subset = ["depo_cluster", "Tropiseq_KLtypes"])
final_annotation_tropiseq = final_annotation_tropiseq[["depo_cluster", "Tropiseq_KLtypes", "Tropiseq_scores"]]

dico_tropiseq_data = {row["depo_cluster"] : {"KL_types" : row["Tropiseq_KLtypes"], "Scores" : row["Tropiseq_scores"]} for _, row in final_annotation_tropiseq.iterrows()}
dico_tropiseq_data
# Out:
# {'Dpo_cdhit_12': {'KL_types': 'KL30',
#   'Scores': 'KL30 : 0.00017771665698402528'},
#  'Dpo_cdhit_233': {'KL_types': 'KL19',
#   'Scores': 'KL19 : 0.00013812934086225345'},
#  'Dpo_cdhit_280': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 0.0008645001322490626'},
#  'Dpo_cdhit_182': {'KL_types': 'KL15',
#   'Scores': 'KL15 : 2.4704011248342683e-22'},
#  'Dpo_cdhit_126': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 0.0004611112383402333'},
#  'Dpo_cdhit_132': {'KL_types': 'KL106',
#   'Scores': 'KL106 : 8.518572858997499e-26'},
#  'Dpo_cdhit_74': {'KL_types': 'KL28,KL23',
#   'Scores': 'KL28 : 0.0012451648171312574,KL23 : 0.00012303924662079074'},
#  'Dpo_cdhit_711': {'KL_types': 'KL1', 'Scores': 'KL1 : 0.0020476851628455045'},
#  'Dpo_cdhit_48': {'KL_types': 'KL19',
#   'Scores': 'KL19 : 2.937170125714393e-11'},
#  'Dpo_cdhit_51': {'KL_types': 'KL47',
#   'Scores': 'KL47 : 3.2559635989706166e-08'},
#  'Dpo_cdhit_72': {'KL_types': 'KL28',
#   'Scores': 'KL28 : 5.227116747174737e-10'},
#  'Dpo_cdhit_30': {'KL_types': 'KL60',
#   'Scores': 'KL60 : 1.2041013156222333e-05'},
#  'Dpo_cdhit_77': {'KL_types': 'KL64', 'Scores': 'KL64 : 0.046799204042377585'},
#  'Dpo_cdhit_18': {'KL_types': 'KL23',
#   'Scores': 'KL23 : 0.0010017946010006528'},
#  'Dpo_cdhit_84': {'KL_types': 'KL28',
#   'Scores': 'KL28 : 6.229614093372359e-09'},
#  'Dpo_cdhit_86': {'KL_types': 'KL28',
#   'Scores': 'KL28 : 5.8432206473749084e-08'},
#  'Dpo_cdhit_179': {'KL_types': 'KL145',
#   'Scores': 'KL145 : 1.0718973456337563e-06'},
#  'Dpo_cdhit_164': {'KL_types': 'KL15',
#   'Scores': 'KL15 : 0.017355617569960027'},
#  'Dpo_cdhit_68': {'KL_types': 'KL64', 'Scores': 'KL64 : 0.046799204042377585'},
#  'Dpo_cdhit_97': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 5.032263693781853e-08'},
#  'Dpo_cdhit_125': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 1.5703526356381844e-11'},
#  'Dpo_cdhit_195': {'KL_types': 'KL28,KL23',
#   'Scores': 'KL28 : 0.0012451648171312574,KL23 : 0.0010017946010006528'},
#  'Dpo_cdhit_376': {'KL_types': 'KL149',
#   'Scores': 'KL149 : 5.740442098027151e-09'},
#  'Dpo_cdhit_94': {'KL_types': 'KL106',
#   'Scores': 'KL106 : 4.965725093072291e-05'},
#  'Dpo_cdhit_192': {'KL_types': 'KL28,KL23,KL107',
#   'Scores': 'KL28 : 2.594829628907371e-22,KL23 : 2.34357570382783e-40,KL107 : 0.004597353554226353'},
#  'Dpo_cdhit_50': {'KL_types': 'KL25', 'Scores': 'KL25 : 0.01074301576844586'},
#  'Dpo_cdhit_666': {'KL_types': 'KL23',
#   'Scores': 'KL23 : 0.0010017946010006528'},
#  'Dpo_cdhit_254': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 2.213804360951825e-43'},
#  'Dpo_cdhit_88': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 0.00010714006315332097'},
#  'Dpo_cdhit_23': {'KL_types': 'KL30,KL64',
#   'Scores': 'KL30 : 0.00195368887847524,KL64 : 0.01059063820528795'},
#  'Dpo_cdhit_739': {'KL_types': 'KL30,KL25,KL17',
#   'Scores': 'KL30 : 0.005763059770386412,KL25 : 0.028897643807188324,KL17 : 5.988757926668287e-05'},
#  'Dpo_cdhit_553': {'KL_types': 'KL14',
#   'Scores': 'KL14 : 0.00018484324506579035'},
#  'Dpo_cdhit_853': {'KL_types': 'KL2,KL107,KL51',
#   'Scores': 'KL2 : 2.9258037540857704e-06,KL107 : 0.0192831713596338,KL51 : 1.0347697956192955e-20'},
#  'Dpo_cdhit_618': {'KL_types': 'KL24,KL107',
#   'Scores': 'KL24 : 1.0187682059156442e-68,KL107 : 0.028260349140228083'},
#  'Dpo_cdhit_71': {'KL_types': 'KL64,KL24,KL107,KL112,KL21,KL39',
#   'Scores': 'KL64 : 0.009965586704795812,KL24 : 1.0230966951463448e-36,KL107 : 0.0013864412742293768,KL112 : 1.1338415158765375e-26,KL21 : 2.1075264693030547e-17,KL39 : 0.004238333557914675'},
#  'Dpo_cdhit_568': {'KL_types': 'KL21',
#   'Scores': 'KL21 : 1.2437203887935977e-14'},
#  'Dpo_cdhit_41': {'KL_types': 'KL64', 'Scores': 'KL64 : 4.41548036913066e-06'},
#  'Dpo_cdhit_184': {'KL_types': 'KL64,KL106,KL107,KL112',
#   'Scores': 'KL64 : 0.0026982067777688488,KL106 : 6.214121500257322e-16,KL107 : 4.668224480907766e-44,KL112 : 0.0021278202203327207'},
#  'Dpo_cdhit_596': {'KL_types': 'KL3', 'Scores': 'KL3 : 2.269850311454715e-19'},
#  'Dpo_cdhit_832': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 0.047997252467436205'},
#  'Dpo_cdhit_603': {'KL_types': 'KL110',
#   'Scores': 'KL110 : 1.585713750469775e-05'},
#  'Dpo_cdhit_152': {'KL_types': 'KL2',
#   'Scores': 'KL2 : 1.7720757227201291e-60'},
#  'Dpo_cdhit_704': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 0.004126527224898557'},
#  'Dpo_cdhit_607': {'KL_types': 'KL64,KL107',
#   'Scores': 'KL64 : 3.3892709095454096e-92,KL107 : 0.004258107926198986'},
#  'Dpo_cdhit_384': {'KL_types': 'KL64,KL47,KL107',
#   'Scores': 'KL64 : 3.191613925107866e-25,KL47 : 2.5994343968866735e-79,KL107 : 0.000357573335853197'},
#  'Dpo_cdhit_772': {'KL_types': 'KL106',
#   'Scores': 'KL106 : 0.007413870507302198'},
#  'Dpo_cdhit_927': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 0.046799204042377585'},
#  'Dpo_cdhit_842': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 1.6542086855803298e-23'},
#  'Dpo_cdhit_53': {'KL_types': 'KL14',
#   'Scores': 'KL14 : 4.366846633557784e-12'},
#  'Dpo_cdhit_500': {'KL_types': 'KL15',
#   'Scores': 'KL15 : 5.267600358772479e-59'},
#  'Dpo_cdhit_583': {'KL_types': 'KL39',
#   'Scores': 'KL39 : 1.2903638060131754e-13'},
#  'Dpo_cdhit_569': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 8.596970173983684e-40'},
#  'Dpo_cdhit_227': {'KL_types': 'KL3', 'Scores': 'KL3 : 3.745028684534161e-17'},
#  'Dpo_cdhit_920': {'KL_types': 'KL24',
#   'Scores': 'KL24 : 0.0017327844857829896'},
#  'Dpo_cdhit_39': {'KL_types': 'KL12', 'Scores': 'KL12 : 0.00282555570527645'},
#  'Dpo_cdhit_47': {'KL_types': 'KL51', 'Scores': 'KL51 : 4.50741105912156e-19'},
#  'Dpo_cdhit_872': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 0.0007013119474490825'},
#  'Dpo_cdhit_174': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 6.146559824548795e-09'},
#  'Dpo_cdhit_689': {'KL_types': 'KL51,KL10',
#   'Scores': 'KL51 : 2.500155507717632e-07,KL10 : 0.00246452291887043'},
#  'Dpo_cdhit_850': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 0.0011249050716453052'},
#  'Dpo_cdhit_158': {'KL_types': 'KL151',
#   'Scores': 'KL151 : 8.284412240024116e-17'},
#  'Dpo_cdhit_571': {'KL_types': 'KL53',
#   'Scores': 'KL53 : 0.002261798658015846'},
#  'Dpo_cdhit_541': {'KL_types': 'KL102',
#   'Scores': 'KL102 : 1.101170084446601e-06'},
#  'Dpo_cdhit_172': {'KL_types': 'KL19', 'Scores': 'KL19 : 0.02218720163739315'},
#  'Dpo_cdhit_630': {'KL_types': 'KL1,KL5',
#   'Scores': 'KL1 : 0.023092171276067115,KL5 : 0.0005197273370352354'},
#  'Dpo_cdhit_228': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 0.014852495052757247'},
#  'Dpo_cdhit_575': {'KL_types': 'KL149',
#   'Scores': 'KL149 : 0.0018983613289347244'},
#  'Dpo_cdhit_867': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 5.988757926668287e-05'},
#  'Dpo_cdhit_605': {'KL_types': 'KL10',
#   'Scores': 'KL10 : 6.939400019294917e-20'},
#  'Dpo_cdhit_29': {'KL_types': 'KL57', 'Scores': 'KL57 : 0.003015731544021128'},
#  'Dpo_cdhit_137': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 2.2151172312996706e-22'},
#  'Dpo_cdhit_628': {'KL_types': 'KL145',
#   'Scores': 'KL145 : 7.85933503711575e-09'},
#  'Dpo_cdhit_217': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 2.8755830929040495e-20'},
#  'Dpo_cdhit_368': {'KL_types': 'KL64,KL106,KL47,KL107,KL17,KL102',
#   'Scores': 'KL64 : 1.9279964048580033e-05,KL106 : 0.01143975622787062,KL47 : 0.0045959003587414905,KL107 : 5.561615711430686e-07,KL17 : 0.01899344799861096,KL102 : 9.203257401579149e-234'},
#  'Dpo_cdhit_597': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 0.007824560352659923'},
#  'Dpo_cdhit_291': {'KL_types': 'KL64,KL107,KL17',
#   'Scores': 'KL64 : 0.0013984237199135142,KL107 : 3.757134915291068e-05,KL17 : 1.2771845915604728e-151'},
#  'Dpo_cdhit_260': {'KL_types': 'KL107,KL51',
#   'Scores': 'KL107 : 0.00241691623510215,KL51 : 5.638700917340187e-11'},
#  'Dpo_cdhit_252': {'KL_types': 'KL38',
#   'Scores': 'KL38 : 0.00017228013036717292'},
#  'Dpo_cdhit_544': {'KL_types': 'KL128',
#   'Scores': 'KL128 : 0.0023949734924371626'},
#  'Dpo_cdhit_406': {'KL_types': 'KL25,KL64,KL107,KL111',
#   'Scores': 'KL25 : 5.2604741672530814e-79,KL64 : 0.01407663707221393,KL107 : 0.0036650213098198643,KL111 : 0.00015229461177639173'},
#  'Dpo_cdhit_200': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 0.0016079818752112163'},
#  'Dpo_cdhit_626': {'KL_types': 'KL18,KL60',
#   'Scores': 'KL18 : 1.346505839180008e-05,KL60 : 1.202857382487165e-07'},
#  'Dpo_cdhit_15': {'KL_types': 'KL14', 'Scores': 'KL14 : 1.8225018289425e-05'},
#  'Dpo_cdhit_351': {'KL_types': 'KL43',
#   'Scores': 'KL43 : 2.077762500956533e-05'},
#  'Dpo_cdhit_837': {'KL_types': 'KL25,KL107,KL55,KL36',
#   'Scores': 'KL25 : 0.011276569496410899,KL107 : 0.0002446467107775057,KL55 : 0.00015106147512692245,KL36 : 0.013991899861055618'},
#  'Dpo_cdhit_327': {'KL_types': 'KL107,KL14',
#   'Scores': 'KL107 : 0.011853414034531518,KL14 : 1.1219562691865324e-79'},
#  'Dpo_cdhit_787': {'KL_types': 'KL64,KL106,KL47,KL107,KL17',
#   'Scores': 'KL64 : 7.652746265723154e-05,KL106 : 3.0351882290698114e-40,KL47 : 0.0016244832606839008,KL107 : 3.709382505259133e-104,KL17 : 0.022671261428146183'},
#  'Dpo_cdhit_304': {'KL_types': 'KL64,KL47,KL107,KL17',
#   'Scores': 'KL64 : 6.188856582983505e-06,KL47 : 0.005378316986425981,KL107 : 9.404537154626465e-251,KL17 : 0.01899344799861096'},
#  'Dpo_cdhit_774': {'KL_types': 'KL15,KL64,KL106,KL1,KL107,KL17,KL102',
#   'Scores': 'KL15 : 0.0030737639322173695,KL64 : 3.1853452723008434e-11,KL106 : 5.8877211632808846e-36,KL1 : 1.1373804719447913e-16,KL107 : 2.7570279064398635e-32,KL17 : 1.5040781977753074e-19,KL102 : 0.0006352286099568906'},
#  'Dpo_cdhit_175': {'KL_types': 'KL25,KL15,KL64,KL106,KL24,KL47,KL107,KL62,KL51,KL17,KL3,KL105,KL102,KL13,KL36,KL108,KL111',
#   'Scores': 'KL25 : 4.548261277974428e-09,KL15 : 1.1082734523867174e-35,KL64 : 2.4602541413494075e-107,KL106 : 1.578291531369157e-86,KL24 : 5.0390344845877586e-26,KL47 : 3.905822488806299e-54,KL107 : 9.953138725588619e-251,KL62 : 0.0004008744942322698,KL51 : 0.0067810327379065755,KL17 : 1.9930550070775094e-16,KL3 : 0.0009681602227371498,KL105 : 9.33941152437665e-14,KL102 : 8.437058244183322e-08,KL13 : 1.4688436595061264e-06,KL36 : 2.5944239487410336e-27,KL108 : 0.001671722754268316,KL111 : 4.9921063950832726e-05'},
#  'Dpo_cdhit_800': {'KL_types': 'KL25,KL64,KL106,KL47,KL107,KL17,KL102',
#   'Scores': 'KL25 : 0.01282140464288618,KL64 : 7.520185962021521e-68,KL106 : 4.731509550321319e-10,KL47 : 1.0133930832931604e-34,KL107 : 8.552357819695181e-05,KL17 : 1.1127728292813866e-06,KL102 : 0.004786276992383674'},
#  'Dpo_cdhit_224': {'KL_types': 'KL64,KL107,KL17',
#   'Scores': 'KL64 : 0.011650846771054029,KL107 : 0.001210298988063974,KL17 : 1.689775631046347e-98'},
#  'Dpo_cdhit_589': {'KL_types': 'KL2',
#   'Scores': 'KL2 : 2.2124395041491644e-22'},
#  'Dpo_cdhit_498': {'KL_types': 'KL2,KL18',
#   'Scores': 'KL2 : 2.880594778899379e-12,KL18 : 0.037341056308543646'},
#  'Dpo_cdhit_612': {'KL_types': 'KL64,KL2,KL107',
#   'Scores': 'KL64 : 0.007419933605888801,KL2 : 1.908347809554921e-127,KL107 : 0.00037928171255509997'},
#  'Dpo_cdhit_851': {'KL_types': 'KL1,KL151',
#   'Scores': 'KL1 : 8.086775330311566e-09,KL151 : 7.60320082723033e-08'},
#  'Dpo_cdhit_55': {'KL_types': 'KL64,KL106,KL47,KL107,KL17',
#   'Scores': 'KL64 : 5.412179520439103e-135,KL106 : 0.0021329916306526914,KL47 : 1.4137082149475433e-100,KL107 : 1.8802158477870094e-08,KL17 : 0.01877363863171388'},
#  'Dpo_cdhit_897': {'KL_types': 'KL63',
#   'Scores': 'KL63 : 2.2165849208252348e-05'},
#  'Dpo_cdhit_472': {'KL_types': 'KL25,KL64,KL106,KL46,KL111',
#   'Scores': 'KL25 : 2.520404843282725e-26,KL64 : 0.0017941005969460988,KL106 : 4.872029412638842e-25,KL46 : 0.0006214909612423771,KL111 : 3.3661410055663926e-12'},
#  'Dpo_cdhit_421': {'KL_types': 'KL106',
#   'Scores': 'KL106 : 7.066598821832851e-37'},
#  'Dpo_cdhit_796': {'KL_types': 'KL25,KL64,KL106,KL23,KL2,KL81,KL17',
#   'Scores': 'KL25 : 5.688644741005738e-30,KL64 : 0.0014119872012898732,KL106 : 3.8209554855865975e-21,KL23 : 1.9498321296381893e-06,KL2 : 0.04231839307577987,KL81 : 0.031032423640413434,KL17 : 0.03321176755863103'},
#  'Dpo_cdhit_538': {'KL_types': 'KL15,KL64,KL106,KL107',
#   'Scores': 'KL15 : 0.0020703160511807697,KL64 : 0.00013980728885725063,KL106 : 1.8165638877179315e-10,KL107 : 4.3304516571622e-18'},
#  'Dpo_cdhit_381': {'KL_types': 'KL57',
#   'Scores': 'KL57 : 1.916251600245827e-12'},
#  'Dpo_cdhit_936': {'KL_types': 'KL106,KL107',
#   'Scores': 'KL106 : 3.289441751570713e-11,KL107 : 1.1428283954842144e-18'},
#  'Dpo_cdhit_202': {'KL_types': 'KL47',
#   'Scores': 'KL47 : 1.6135263267229916e-12'},
#  'Dpo_cdhit_650': {'KL_types': 'KL24',
#   'Scores': 'KL24 : 1.0959243248054677e-17'},
#  'Dpo_cdhit_471': {'KL_types': 'KL30,KL64,KL2,KL45,KL17,KL21',
#   'Scores': 'KL30 : 2.587269267847131e-05,KL64 : 0.00033383236153427284,KL2 : 4.406991009587386e-48,KL45 : 2.357445248196487e-05,KL17 : 6.187078993658548e-51,KL21 : 0.0009330890498568652'},
#  'Dpo_cdhit_290': {'KL_types': 'KL127',
#   'Scores': 'KL127 : 2.6948974129825e-16'},
#  'Dpo_cdhit_333': {'KL_types': 'KL45',
#   'Scores': 'KL45 : 4.1900187678255245e-38'},
#  'Dpo_cdhit_389': {'KL_types': 'KL45',
#   'Scores': 'KL45 : 0.021855966150650705'},
#  'Dpo_cdhit_658': {'KL_types': 'KL22',
#   'Scores': 'KL22 : 6.380896959317726e-08'},
#  'Dpo_cdhit_268': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 2.22568076718677e-12'},
#  'Dpo_cdhit_593': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 5.869500767749009e-06'},
#  'Dpo_cdhit_882': {'KL_types': 'KL1,KL54,KL114,KL63',
#   'Scores': 'KL1 : 0.00021527461002675876,KL54 : 1.2360184682751167e-05,KL114 : 5.504049850444481e-09,KL63 : 9.321567109414e-10'},
#  'Dpo_cdhit_124': {'KL_types': 'KL47',
#   'Scores': 'KL47 : 3.2559635989706166e-08'},
#  'Dpo_cdhit_323': {'KL_types': 'KL47,KL107',
#   'Scores': 'KL47 : 1.928137784165278e-62,KL107 : 0.041601660478047725'},
#  'Dpo_cdhit_824': {'KL_types': 'KL2,KL17,KL21',
#   'Scores': 'KL2 : 5.46082481036098e-44,KL17 : 4.190683328352924e-35,KL21 : 9.887924576052652e-07'},
#  'Dpo_cdhit_594': {'KL_types': 'KL30',
#   'Scores': 'KL30 : 0.00017771665698402528'},
#  'Dpo_cdhit_361': {'KL_types': 'KL64,KL107,KL17',
#   'Scores': 'KL64 : 0.0007590826796644132,KL107 : 6.745756872991721e-05,KL17 : 7.950901323215416e-189'},
#  'Dpo_cdhit_96': {'KL_types': 'KL10',
#   'Scores': 'KL10 : 1.9226318185421704e-13'},
#  'Dpo_cdhit_473': {'KL_types': 'KL106',
#   'Scores': 'KL106 : 6.914623079770378e-59'},
#  'Dpo_cdhit_454': {'KL_types': 'KL36',
#   'Scores': 'KL36 : 4.554846053144234e-10'},
#  'Dpo_cdhit_481': {'KL_types': 'KL10', 'Scores': 'KL10 : 0.0271912060386218'},
#  'Dpo_cdhit_560': {'KL_types': 'KL153',
#   'Scores': 'KL153 : 0.00654790223181411'},
#  'Dpo_cdhit_316': {'KL_types': 'KL60',
#   'Scores': 'KL60 : 5.775340189479205e-34'},
#  'Dpo_cdhit_134': {'KL_types': 'KL47',
#   'Scores': 'KL47 : 2.37992415488846e-10'},
#  'Dpo_cdhit_283': {'KL_types': 'KL149',
#   'Scores': 'KL149 : 1.1027079284798899e-16'},
#  'Dpo_cdhit_196': {'KL_types': 'KL36',
#   'Scores': 'KL36 : 4.8397798864190545e-11'},
#  'Dpo_cdhit_186': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 0.007824560352659923'},
#  'Dpo_cdhit_248': {'KL_types': 'KL38',
#   'Scores': 'KL38 : 8.724476329101628e-11'},
#  'Dpo_cdhit_585': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 4.5727046172266625e-11'},
#  'Dpo_cdhit_771': {'KL_types': 'KL28',
#   'Scores': 'KL28 : 8.985464517599461e-06'},
#  'Dpo_cdhit_331': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 8.596970173983684e-40'},
#  'Dpo_cdhit_462': {'KL_types': 'KL64,KL107',
#   'Scores': 'KL64 : 8.317539053894576e-112,KL107 : 0.0009136766910246308'},
#  'Dpo_cdhit_515': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 3.2681546076685253e-10'},
#  'Dpo_cdhit_795': {'KL_types': 'KL23',
#   'Scores': 'KL23 : 5.393541880505037e-10'},
#  'Dpo_cdhit_239': {'KL_types': 'KL81',
#   'Scores': 'KL81 : 4.297225445657571e-16'},
#  'Dpo_cdhit_423': {'KL_types': 'KL36', 'Scores': 'KL36 : 0.022375164359108'},
#  'Dpo_cdhit_141': {'KL_types': 'KL47,KL107',
#   'Scores': 'KL47 : 2.5994343968866735e-79,KL107 : 0.012829054746750172'},
#  'Dpo_cdhit_382': {'KL_types': 'KL114',
#   'Scores': 'KL114 : 0.00023564830138788246'},
#  'Dpo_cdhit_555': {'KL_types': 'KL122',
#   'Scores': 'KL122 : 7.85933503711575e-09'},
#  'Dpo_cdhit_910': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 1.453085782284583e-15'},
#  'Dpo_cdhit_633': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 2.3693697193681465e-21'},
#  'Dpo_cdhit_586': {'KL_types': 'KL2', 'Scores': 'KL2 : 7.018283995195313e-17'},
#  'Dpo_cdhit_302': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 9.062218226242827e-18'},
#  'Dpo_cdhit_355': {'KL_types': 'KL45',
#   'Scores': 'KL45 : 0.021855966150650705'},
#  'Dpo_cdhit_319': {'KL_types': 'KL3', 'Scores': 'KL3 : 7.095978191738445e-40'},
#  'Dpo_cdhit_275': {'KL_types': 'KL3', 'Scores': 'KL3 : 9.353784739402073e-47'},
#  'Dpo_cdhit_606': {'KL_types': 'KL13',
#   'Scores': 'KL13 : 2.3721856220738734e-07'},
#  'Dpo_cdhit_118': {'KL_types': 'KL3',
#   'Scores': 'KL3 : 2.6942957544310383e-28'},
#  'Dpo_cdhit_271': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 2.98393670342642e-20'},
#  'Dpo_cdhit_101': {'KL_types': 'KL3,KL7',
#   'Scores': 'KL3 : 2.269850311454715e-19,KL7 : 1.9174981924729846e-05'},
#  'Dpo_cdhit_218': {'KL_types': 'KL128',
#   'Scores': 'KL128 : 0.0023949734924371626'},
#  'Dpo_cdhit_447': {'KL_types': 'KL22',
#   'Scores': 'KL22 : 7.42897664172917e-20'},
#  'Dpo_cdhit_492': {'KL_types': 'KL47',
#   'Scores': 'KL47 : 6.129496714847509e-05'},
#  'Dpo_cdhit_737': {'KL_types': 'KL21',
#   'Scores': 'KL21 : 9.571276301820284e-07'},
#  'Dpo_cdhit_256': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 4.4684128844078555e-09'},
#  'Dpo_cdhit_722': {'KL_types': 'KL64,KL106,KL23,KL107,KL13,KL36',
#   'Scores': 'KL64 : 0.004961372044325539,KL106 : 7.094251099331979e-11,KL23 : 0.0005480849579651055,KL107 : 5.5960233446892314e-39,KL13 : 0.00024239968060079628,KL36 : 0.00017632215984979087'},
#  'Dpo_cdhit_595': {'KL_types': 'KL3', 'Scores': 'KL3 : 9.336768248260602e-05'},
#  'Dpo_cdhit_925': {'KL_types': 'KL2', 'Scores': 'KL2 : 0.0008156718316272994'},
#  'Dpo_cdhit_56': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 1.3514145354604479e-12'},
#  'Dpo_cdhit_404': {'KL_types': 'KL105',
#   'Scores': 'KL105 : 1.4848462875249281e-15'},
#  'Dpo_cdhit_282': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 5.869500767749009e-06'},
#  'Dpo_cdhit_203': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 9.077104117947974e-07'},
#  'Dpo_cdhit_470': {'KL_types': 'KL151',
#   'Scores': 'KL151 : 1.1675573972789442e-05'},
#  'Dpo_cdhit_576': {'KL_types': 'KL105',
#   'Scores': 'KL105 : 4.482977783833907e-28'},
#  'Dpo_cdhit_270': {'KL_types': 'KL5,KL117',
#   'Scores': 'KL5 : 0.0039665382655472885,KL117 : 0.006351961012939394'},
#  'Dpo_cdhit_496': {'KL_types': 'KL22',
#   'Scores': 'KL22 : 2.76865211072781e-19'},
#  'Dpo_cdhit_908': {'KL_types': 'KL2', 'Scores': 'KL2 : 0.0008156718316272994'},
#  'Dpo_cdhit_448': {'KL_types': 'KL169',
#   'Scores': 'KL169 : 0.007753494772732148'},
#  'Dpo_cdhit_353': {'KL_types': 'KL12',
#   'Scores': 'KL12 : 1.121726329578538e-12'},
#  'Dpo_cdhit_358': {'KL_types': 'KL12',
#   'Scores': 'KL12 : 7.238162819955073e-15'},
#  'Dpo_cdhit_892': {'KL_types': 'KL63',
#   'Scores': 'KL63 : 0.00015917600175185728'},
#  'Dpo_cdhit_724': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 0.019081128672316195'},
#  'Dpo_cdhit_580': {'KL_types': 'KL64,KL107,KL149,KL51,KL136',
#   'Scores': 'KL64 : 0.01847325251306591,KL107 : 0.0006911786884635658,KL149 : 5.740442098027151e-09,KL51 : 3.8242338266221562e-34,KL136 : 0.002766536844676006'},
#  'Dpo_cdhit_377': {'KL_types': 'KL108',
#   'Scores': 'KL108 : 1.3158959481236409e-07'},
#  'Dpo_cdhit_330': {'KL_types': 'KL45',
#   'Scores': 'KL45 : 0.0031153146159452138'},
#  'Dpo_cdhit_95': {'KL_types': 'KL7', 'Scores': 'KL7 : 2.107137372103363e-17'},
#  'Dpo_cdhit_493': {'KL_types': 'KL111',
#   'Scores': 'KL111 : 1.1325610576727138e-06'},
#  'Dpo_cdhit_120': {'KL_types': 'KL24',
#   'Scores': 'KL24 : 4.277320231685534e-30'},
#  'Dpo_cdhit_549': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 7.249911489836492e-16'},
#  'Dpo_cdhit_664': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 2.0325566325034565e-06'},
#  'Dpo_cdhit_266': {'KL_types': 'KL60',
#   'Scores': 'KL60 : 1.2041013156222333e-05'},
#  'Dpo_cdhit_365': {'KL_types': 'KL34',
#   'Scores': 'KL34 : 0.00041997619093760564'},
#  'Dpo_cdhit_413': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 0.019081128672316195'},
#  'Dpo_cdhit_185': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 7.85071322046676e-06'},
#  'Dpo_cdhit_613': {'KL_types': 'KL64,KL1',
#   'Scores': 'KL64 : 0.024991693946389976,KL1 : 5.991120127240432e-59'},
#  'Dpo_cdhit_285': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 1.340089400006258e-07'},
#  'Dpo_cdhit_559': {'KL_types': 'KL105',
#   'Scores': 'KL105 : 7.237219484553186e-08'},
#  'Dpo_cdhit_600': {'KL_types': 'KL52',
#   'Scores': 'KL52 : 0.00028134434876602896'},
#  'Dpo_cdhit_677': {'KL_types': 'KL53',
#   'Scores': 'KL53 : 1.467489782814686e-05'},
#  'Dpo_cdhit_356': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 1.6999276364629087e-14'},
#  'Dpo_cdhit_325': {'KL_types': 'KL155',
#   'Scores': 'KL155 : 6.524133429544486e-07'},
#  'Dpo_cdhit_517': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 2.49016861358724e-09'},
#  'Dpo_cdhit_324': {'KL_types': 'KL62,KL127',
#   'Scores': 'KL62 : 2.544513014661785e-11,KL127 : 1.1581682484295878e-06'},
#  'Dpo_cdhit_883': {'KL_types': 'KL30',
#   'Scores': 'KL30 : 2.587269267847131e-05'},
#  'Dpo_cdhit_107': {'KL_types': 'KL136',
#   'Scores': 'KL136 : 1.498453014707654e-07'},
#  'Dpo_cdhit_332': {'KL_types': 'KL52',
#   'Scores': 'KL52 : 0.00028134434876602896'},
#  'Dpo_cdhit_249': {'KL_types': 'KL52', 'Scores': 'KL52 : 0.04088467057132467'},
#  'Dpo_cdhit_884': {'KL_types': 'KL63',
#   'Scores': 'KL63 : 0.00015917600175185728'},
#  'Dpo_cdhit_960': {'KL_types': 'KL2', 'Scores': 'KL2 : 7.8662054862785e-05'},
#  'Dpo_cdhit_443': {'KL_types': 'KL111',
#   'Scores': 'KL111 : 5.753968897977411e-10'},
#  'Dpo_cdhit_728': {'KL_types': 'KL151',
#   'Scores': 'KL151 : 0.021894681598513595'},
#  'Dpo_cdhit_241': {'KL_types': 'KL62',
#   'Scores': 'KL62 : 2.8583584884221715e-10'},
#  'Dpo_cdhit_255': {'KL_types': 'KL56',
#   'Scores': 'KL56 : 0.005351420848737557'},
#  'Dpo_cdhit_480': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 5.104870744462972e-54'},
#  'Dpo_cdhit_215': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 9.225480691478934e-11'},
#  'Dpo_cdhit_706': {'KL_types': 'KL17',
#   'Scores': 'KL17 : 0.007824560352659923'},
#  'Dpo_cdhit_581': {'KL_types': 'KL110',
#   'Scores': 'KL110 : 1.585713750469775e-05'},
#  'Dpo_cdhit_698': {'KL_types': 'KL20', 'Scores': 'KL20 : 0.00654790223181411'},
#  'Dpo_cdhit_276': {'KL_types': 'KL81',
#   'Scores': 'KL81 : 0.031032423640413434'},
#  'Dpo_cdhit_138': {'KL_types': 'KL145',
#   'Scores': 'KL145 : 0.023916393852789083'},
#  'Dpo_cdhit_820': {'KL_types': 'KL145',
#   'Scores': 'KL145 : 0.00017595179002451194'},
#  'Dpo_cdhit_402': {'KL_types': 'KL60',
#   'Scores': 'KL60 : 0.0015734871265477425'},
#  'Dpo_cdhit_476': {'KL_types': 'KL123,KL60',
#   'Scores': 'KL123 : 0.008014982767491942,KL60 : 0.0015734871265477425'},
#  'Dpo_cdhit_308': {'KL_types': 'KL43',
#   'Scores': 'KL43 : 2.8030910112437536e-06'},
#  'Dpo_cdhit_437': {'KL_types': 'KL118',
#   'Scores': 'KL118 : 0.0036576310973784856'},
#  'Dpo_cdhit_828': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 0.0014856819352225738'},
#  'Dpo_cdhit_159': {'KL_types': 'KL151',
#   'Scores': 'KL151 : 7.858611011100484e-09'},
#  'Dpo_cdhit_532': {'KL_types': 'KL19',
#   'Scores': 'KL19 : 1.3894206723743427e-22'},
#  'Dpo_cdhit_761': {'KL_types': 'KL118',
#   'Scores': 'KL118 : 9.332605962273358e-08'},
#  'Dpo_cdhit_529': {'KL_types': 'KL28,KL23,KL107',
#   'Scores': 'KL28 : 7.204091044069606e-42,KL23 : 2.3079987374200795e-13,KL107 : 0.028260349140228083'},
#  'Dpo_cdhit_528': {'KL_types': 'KL18',
#   'Scores': 'KL18 : 1.562620158243142e-06'},
#  'Dpo_cdhit_312': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 0.014852495052757247'},
#  'Dpo_cdhit_309': {'KL_types': 'KL19',
#   'Scores': 'KL19 : 2.084748948865438e-13'},
#  'Dpo_cdhit_232': {'KL_types': 'KL38',
#   'Scores': 'KL38 : 6.267717945435456e-10'},
#  'Dpo_cdhit_762': {'KL_types': 'KL102',
#   'Scores': 'KL102 : 0.019908819343835718'},
#  'Dpo_cdhit_487': {'KL_types': 'KL25',
#   'Scores': 'KL25 : 5.560223173546723e-07'},
#  'Dpo_cdhit_449': {'KL_types': 'KL57',
#   'Scores': 'KL57 : 1.505738583914414e-14'},
#  'Dpo_cdhit_348': {'KL_types': 'KL22',
#   'Scores': 'KL22 : 6.380896959317726e-08'},
#  'Dpo_cdhit_652': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 9.077104117947974e-07'},
#  'Dpo_cdhit_343': {'KL_types': 'KL23',
#   'Scores': 'KL23 : 5.49890471759824e-09'},
#  'Dpo_cdhit_708': {'KL_types': 'KL112',
#   'Scores': 'KL112 : 0.0003292039291783704'},
#  'Dpo_cdhit_206': {'KL_types': 'KL10',
#   'Scores': 'KL10 : 5.020440869324505e-19'},
#  'Dpo_cdhit_221': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 1.765400571004674e-05'},
#  'Dpo_cdhit_561': {'KL_types': 'KL2', 'Scores': 'KL2 : 0.0008156718316272994'},
#  'Dpo_cdhit_301': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 9.274395935627345e-09'},
#  'Dpo_cdhit_552': {'KL_types': 'KL23', 'Scores': 'KL23 : 0.01243117239499614'},
#  'Dpo_cdhit_484': {'KL_types': 'KL70', 'Scores': 'KL70 : 0.03986065642131514'},
#  'Dpo_cdhit_567': {'KL_types': 'KL128',
#   'Scores': 'KL128 : 0.0004473443525180069'},
#  'Dpo_cdhit_277': {'KL_types': 'KL43',
#   'Scores': 'KL43 : 0.002934547001610486'},
#  'Dpo_cdhit_636': {'KL_types': 'KL28',
#   'Scores': 'KL28 : 0.015141744645915289'},
#  'Dpo_cdhit_257': {'KL_types': 'KL38',
#   'Scores': 'KL38 : 0.00017228013036717292'},
#  'Dpo_cdhit_187': {'KL_types': 'KL13',
#   'Scores': 'KL13 : 0.0023511415882250235'},
#  'Dpo_cdhit_165': {'KL_types': 'KL53',
#   'Scores': 'KL53 : 2.983779545238998e-11'},
#  'Dpo_cdhit_430': {'KL_types': 'KL70',
#   'Scores': 'KL70 : 2.1437946912675125e-06'},
#  'Dpo_cdhit_267': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 0.0004611112383402333'},
#  'Dpo_cdhit_436': {'KL_types': 'KL63,KL104',
#   'Scores': 'KL63 : 0.00181540023013385,KL104 : 0.04391830088094925'},
#  'Dpo_cdhit_264': {'KL_types': 'KL81',
#   'Scores': 'KL81 : 0.031032423640413434'},
#  'Dpo_cdhit_219': {'KL_types': 'KL38',
#   'Scores': 'KL38 : 0.0019136196050937005'},
#  'Dpo_cdhit_278': {'KL_types': 'KL107',
#   'Scores': 'KL107 : 0.0295004546736198'},
#  'Dpo_cdhit_731': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 1.008252856276088e-05'},
#  'Dpo_cdhit_610': {'KL_types': 'KL110',
#   'Scores': 'KL110 : 0.002346398582977624'},
#  'Dpo_cdhit_673': {'KL_types': 'KL110',
#   'Scores': 'KL110 : 5.942266463969446e-18'},
#  'Dpo_cdhit_790': {'KL_types': 'KL145',
#   'Scores': 'KL145 : 0.0020037456918729855'},
#  'Dpo_cdhit_334': {'KL_types': 'KL25,KL15,KL64,KL38,KL107,KL62',
#   'Scores': 'KL25 : 6.1199856700488986e-15,KL15 : 0.009329280209320246,KL64 : 0.015258201973993652,KL38 : 0.018725662303558026,KL107 : 0.001294327489856227,KL62 : 4.444569622125844e-12'},
#  'Dpo_cdhit_440': {'KL_types': 'KL63',
#   'Scores': 'KL63 : 0.021475261817653045'},
#  'Dpo_cdhit_328': {'KL_types': 'KL74',
#   'Scores': 'KL74 : 0.014852495052757247'},
#  'Dpo_cdhit_671': {'KL_types': 'KL29',
#   'Scores': 'KL29 : 2.5167079191016194e-06'},
#  'Dpo_cdhit_345': {'KL_types': 'KL29',
#   'Scores': 'KL29 : 0.004238333557914675'},
#  'Dpo_cdhit_442': {'KL_types': 'KL46',
#   'Scores': 'KL46 : 1.2568818592295825e-05'},
#  'Dpo_cdhit_929': {'KL_types': 'KL149',
#   'Scores': 'KL149 : 0.022060799310251705'},
#  'Dpo_cdhit_961': {'KL_types': 'KL3', 'Scores': 'KL3 : 0.013739120822895086'},
#  'Dpo_cdhit_866': {'KL_types': 'KL21',
#   'Scores': 'KL21 : 0.0001196316616622682'},
#  'Dpo_cdhit_226': {'KL_types': 'KL149',
#   'Scores': 'KL149 : 6.132954035742205e-08'},
#  'Dpo_cdhit_519': {'KL_types': 'KL45,KL136',
#   'Scores': 'KL45 : 0.021855966150650705,KL136 : 0.002766536844676006'},
#  'Dpo_cdhit_416': {'KL_types': 'KL15,KL64,KL106,KL47,KL107',
#   'Scores': 'KL15 : 1.1150987936012135e-15,KL64 : 1.4849318494058994e-88,KL106 : 9.762522342245452e-16,KL47 : 4.1978249777073116e-29,KL107 : 7.843732514763849e-47'},
#  'Dpo_cdhit_839': {'KL_types': 'KL64,KL106,KL47,KL107',
#   'Scores': 'KL64 : 0.0001592784581120834,KL106 : 7.53005724642737e-05,KL47 : 8.460158912751533e-08,KL107 : 8.760441450784986e-37'},
#  'Dpo_cdhit_531': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 0.046799204042377585'},
#  'Dpo_cdhit_964': {'KL_types': 'KL102',
#   'Scores': 'KL102 : 1.101170084446601e-06'},
#  'Dpo_cdhit_695': {'KL_types': 'KL116',
#   'Scores': 'KL116 : 3.2088758614808917e-10'},
#  'Dpo_cdhit_397': {'KL_types': 'KL27',
#   'Scores': 'KL27 : 2.2151172312996706e-22'},
#  'Dpo_cdhit_904': {'KL_types': 'KL64',
#   'Scores': 'KL64 : 3.378535578750341e-07'},
#  'Dpo_cdhit_336': {'KL_types': 'KL21,KL124',
#   'Scores': 'KL21 : 9.058690784864949e-17,KL124 : 1.2360184682751167e-05'},
#  'Dpo_cdhit_520': {'KL_types': 'KL70,KL29',
#   'Scores': 'KL70 : 0.03986065642131514,KL29 : 0.04122098629996923'},
#  'Dpo_cdhit_813': {'KL_types': 'KL2', 'Scores': 'KL2 : 3.32693834007211e-09'},
#  'Dpo_cdhit_405': {'KL_types': 'KL53',
#   'Scores': 'KL53 : 3.832503200491654e-12'}}

# %%
dico_pred = json.load(open("/media/concha-eloko/Linux/PPT_clean/Seqbased_model/prediction_based.labeling.0604.json"))
dico_pred_correct_name = {f"Dpo_cdhit_{cluster.split('_')[1]}":hits  for cluster, hits in dico_pred.items()}
dico_pred_correct_name
# Out:
# {'Dpo_cdhit_0': {'KL103': 0.9887005649717514},
#  'Dpo_cdhit_1': {},
#  'Dpo_cdhit_2': {},
#  'Dpo_cdhit_3': {},
#  'Dpo_cdhit_4': {'KL54': 0.6317016672506052},
#  'Dpo_cdhit_5': {},
#  'Dpo_cdhit_6': {},
#  'Dpo_cdhit_7': {},
#  'Dpo_cdhit_8': {},
#  'Dpo_cdhit_9': {},
#  'Dpo_cdhit_10': {},
#  'Dpo_cdhit_11': {},
#  'Dpo_cdhit_12': {},
#  'Dpo_cdhit_13': {},
#  'Dpo_cdhit_14': {},
#  'Dpo_cdhit_15': {'KL14': 0.9669649842305083},
#  'Dpo_cdhit_16': {},
#  'Dpo_cdhit_17': {},
#  'Dpo_cdhit_18': {},
#  'Dpo_cdhit_19': {},
#  'Dpo_cdhit_20': {'KL1': 0.5049816914017605},
#  'Dpo_cdhit_21': {},
#  'Dpo_cdhit_22': {},
#  'Dpo_cdhit_23': {},
#  'Dpo_cdhit_24': {},
#  'Dpo_cdhit_25': {'KL16': 0.6563300047113529},
#  'Dpo_cdhit_26': {'KL164': 0.615},
#  'Dpo_cdhit_27': {'KL46': 0.5539146456204256},
#  'Dpo_cdhit_28': {},
#  'Dpo_cdhit_29': {'KL57': 0.5119127698312795},
#  'Dpo_cdhit_30': {},
#  'Dpo_cdhit_31': {},
#  'Dpo_cdhit_32': {'KL123': 0.5939826590887848},
#  'Dpo_cdhit_33': {},
#  'Dpo_cdhit_34': {},
#  'Dpo_cdhit_35': {},
#  'Dpo_cdhit_36': {},
#  'Dpo_cdhit_37': {},
#  'Dpo_cdhit_38': {},
#  'Dpo_cdhit_39': {},
#  'Dpo_cdhit_40': {'KL12': 0.512363591269841},
#  'Dpo_cdhit_41': {'KL64': 0.7042461675673053, 'KL74': 0.5471287685267261},
#  'Dpo_cdhit_42': {'KL151': 0.5272071756866026},
#  'Dpo_cdhit_43': {},
#  'Dpo_cdhit_44': {'KL123': 0.6796389493571889},
#  'Dpo_cdhit_45': {'KL13': 0.5709955841502351},
#  'Dpo_cdhit_46': {},
#  'Dpo_cdhit_47': {'KL51': 0.9638243750057931},
#  'Dpo_cdhit_48': {'KL19': 0.7168251004326681},
#  'Dpo_cdhit_49': {'KL137': 0.9095999999999994,
#   'KL123': 0.7074749852628202,
#   'KL126': 0.5325,
#   'KL16': 0.5968473656172357},
#  'Dpo_cdhit_50': {},
#  'Dpo_cdhit_51': {'KL47': 0.9443028851652978},
#  'Dpo_cdhit_52': {},
#  'Dpo_cdhit_53': {'KL14': 0.950674383458824},
#  'Dpo_cdhit_54': {},
#  'Dpo_cdhit_55': {'KL47': 0.8617288920957011,
#   'KL64': 0.7056012444290126,
#   'KL21': 0.6624415598603526},
#  'Dpo_cdhit_56': {'KL64': 0.9037259998449553},
#  'Dpo_cdhit_57': {},
#  'Dpo_cdhit_58': {},
#  'Dpo_cdhit_59': {},
#  'Dpo_cdhit_60': {},
#  'Dpo_cdhit_61': {},
#  'Dpo_cdhit_62': {'KL13': 0.5272369948063018},
#  'Dpo_cdhit_63': {},
#  'Dpo_cdhit_64': {},
#  'Dpo_cdhit_65': {'KL29': 0.5592916666666667},
#  'Dpo_cdhit_66': {},
#  'Dpo_cdhit_67': {'KL157': 0.5649670906618529},
#  'Dpo_cdhit_68': {},
#  'Dpo_cdhit_69': {},
#  'Dpo_cdhit_70': {},
#  'Dpo_cdhit_71': {'KL112': 0.7797781306684983,
#   'KL48': 0.5854146520575353,
#   'KL39': 0.6602983248255738,
#   'KL8': 0.6666666666666659,
#   'KL21': 0.7394041356865866,
#   'KL24': 0.8104974796418947,
#   'KL28': 0.6286225729028304},
#  'Dpo_cdhit_72': {'KL28': 0.6033309503407428},
#  'Dpo_cdhit_73': {},
#  'Dpo_cdhit_74': {'KL10': 0.5240114964736252, 'KL28': 0.7172168665346024},
#  'Dpo_cdhit_75': {},
#  'Dpo_cdhit_76': {},
#  'Dpo_cdhit_77': {},
#  'Dpo_cdhit_78': {},
#  'Dpo_cdhit_79': {},
#  'Dpo_cdhit_80': {},
#  'Dpo_cdhit_81': {},
#  'Dpo_cdhit_82': {},
#  'Dpo_cdhit_83': {},
#  'Dpo_cdhit_84': {'KL28': 0.671802398604203},
#  'Dpo_cdhit_85': {},
#  'Dpo_cdhit_86': {'KL24': 0.6864301060313933, 'KL28': 0.779150961949192},
#  'Dpo_cdhit_87': {},
#  'Dpo_cdhit_88': {},
#  'Dpo_cdhit_89': {},
#  'Dpo_cdhit_90': {'KL158': 0.6268035714285725},
#  'Dpo_cdhit_91': {},
#  'Dpo_cdhit_92': {'KL64': 0.6702590696691522},
#  'Dpo_cdhit_93': {'KL60': 0.5043061339863629},
#  'Dpo_cdhit_94': {},
#  'Dpo_cdhit_95': {'KL7': 0.6564127899324956},
#  'Dpo_cdhit_96': {'KL10': 0.6837630660808999},
#  'Dpo_cdhit_97': {},
#  'Dpo_cdhit_98': {},
#  'Dpo_cdhit_99': {},
#  'Dpo_cdhit_100': {},
#  'Dpo_cdhit_101': {'KL7': 0.5934187524296431, 'KL8': 0.9932279909706546},
#  'Dpo_cdhit_102': {'KL8': 0.9785553047404063,
#   'KL143': 0.919568822553897,
#   'KL9': 0.6444122190597255,
#   'KL14': 0.6316655236629177,
#   'KL70': 0.8801561158642477,
#   'KL31': 0.5045522967017281},
#  'Dpo_cdhit_103': {},
#  'Dpo_cdhit_104': {'KL123': 0.5058610644918217},
#  'Dpo_cdhit_105': {},
#  'Dpo_cdhit_106': {},
#  'Dpo_cdhit_107': {'KL136': 0.5042782782159234},
#  'Dpo_cdhit_108': {'KL14': 0.9609778705171993},
#  'Dpo_cdhit_109': {},
#  'Dpo_cdhit_110': {},
#  'Dpo_cdhit_111': {},
#  'Dpo_cdhit_112': {'KL127': 0.51748265273943},
#  'Dpo_cdhit_113': {'KL47': 0.6176931965095009},
#  'Dpo_cdhit_114': {},
#  'Dpo_cdhit_115': {},
#  'Dpo_cdhit_116': {},
#  'Dpo_cdhit_117': {},
#  'Dpo_cdhit_118': {'KL3': 0.7007388386485148},
#  'Dpo_cdhit_119': {},
#  'Dpo_cdhit_120': {'KL24': 0.7575537340839898},
#  'Dpo_cdhit_121': {'KL151': 0.8086564129928118, 'KL123': 0.6694617411230505},
#  'Dpo_cdhit_122': {'KL145': 0.7707916666666668, 'KL43': 0.5478265312287878},
#  'Dpo_cdhit_123': {},
#  'Dpo_cdhit_124': {},
#  'Dpo_cdhit_125': {},
#  'Dpo_cdhit_126': {},
#  'Dpo_cdhit_127': {},
#  'Dpo_cdhit_128': {},
#  'Dpo_cdhit_129': {},
#  'Dpo_cdhit_130': {},
#  'Dpo_cdhit_131': {},
#  'Dpo_cdhit_132': {},
#  'Dpo_cdhit_133': {},
#  'Dpo_cdhit_134': {'KL47': 0.6318704455307378},
#  'Dpo_cdhit_135': {},
#  'Dpo_cdhit_136': {},
#  'Dpo_cdhit_137': {'KL27': 0.6082875915757344},
#  'Dpo_cdhit_138': {},
#  'Dpo_cdhit_139': {},
#  'Dpo_cdhit_140': {'KL14': 0.7281722388078314},
#  'Dpo_cdhit_141': {'KL47': 0.9526144431276105},
#  'Dpo_cdhit_142': {'KL110': 0.5331845337632967, 'KL24': 0.5985419595810183},
#  'Dpo_cdhit_143': {},
#  'Dpo_cdhit_144': {},
#  'Dpo_cdhit_145': {'KL28': 0.6472699983844957},
#  'Dpo_cdhit_146': {'KL12': 0.9790069444444442},
#  'Dpo_cdhit_147': {},
#  'Dpo_cdhit_148': {},
#  'Dpo_cdhit_149': {'KL127': 0.5180803501413508},
#  'Dpo_cdhit_150': {},
#  'Dpo_cdhit_151': {'KL14': 0.9760688504422146},
#  'Dpo_cdhit_152': {'KL25': 0.6942803212410558},
#  'Dpo_cdhit_153': {},
#  'Dpo_cdhit_154': {},
#  'Dpo_cdhit_155': {},
#  'Dpo_cdhit_156': {'KL109': 0.8046602837998941},
#  'Dpo_cdhit_157': {},
#  'Dpo_cdhit_158': {'KL45': 0.8732002332570513, 'KL151': 0.8577443672328511},
#  'Dpo_cdhit_159': {'KL151': 0.8545794956526359},
#  'Dpo_cdhit_160': {'KL109': 0.6329183363322014},
#  'Dpo_cdhit_161': {},
#  'Dpo_cdhit_162': {'KL82': 0.5859232175502742},
#  'Dpo_cdhit_163': {},
#  'Dpo_cdhit_164': {'KL15': 0.5962897318226855},
#  'Dpo_cdhit_165': {'KL53': 0.9806249999999999},
#  'Dpo_cdhit_166': {'KL164': 1.0},
#  'Dpo_cdhit_167': {'KL109': 0.6547437320976276},
#  'Dpo_cdhit_168': {},
#  'Dpo_cdhit_169': {},
#  'Dpo_cdhit_170': {},
#  'Dpo_cdhit_171': {},
#  'Dpo_cdhit_172': {},
#  'Dpo_cdhit_173': {'KL9': 0.667891800986586},
#  'Dpo_cdhit_174': {'KL46': 0.9340463475534247},
#  'Dpo_cdhit_175': {'KL105': 0.5196502196193716,
#   'KL107': 0.7031794404596527,
#   'KL103': 1.0,
#   'KL108': 0.7570975485594876,
#   'KL47': 0.5348477456255889,
#   'KL64': 0.6186889443836232,
#   'KL52': 0.5151930480423418,
#   'KL15': 0.5589791715681167,
#   'KL24': 0.575354392756186,
#   'KL106': 0.6269351060780372,
#   'KL36': 0.6814082691177917},
#  'Dpo_cdhit_176': {},
#  'Dpo_cdhit_177': {},
#  'Dpo_cdhit_178': {},
#  'Dpo_cdhit_179': {'KL37': 0.8983974358974358, 'KL145': 0.9328125},
#  'Dpo_cdhit_180': {},
#  'Dpo_cdhit_181': {'KL13': 0.5240164519689914},
#  'Dpo_cdhit_182': {'KL15': 0.7938890377524203},
#  'Dpo_cdhit_183': {},
#  'Dpo_cdhit_184': {'KL112': 0.6688339051052155,
#   'KL107': 0.5856539043233394,
#   'KL106': 0.5717286843767281},
#  'Dpo_cdhit_185': {'KL27': 0.5327711240304418},
#  'Dpo_cdhit_186': {'KL17': 0.7199888099395653},
#  'Dpo_cdhit_187': {'KL13': 0.6109017355073832},
#  'Dpo_cdhit_188': {'KL58': 0.9178571428571431},
#  'Dpo_cdhit_189': {'KL46': 0.9411513586402467},
#  'Dpo_cdhit_190': {'KL142': 0.6557461069827379},
#  'Dpo_cdhit_191': {'KL119': 0.5282729499602568},
#  'Dpo_cdhit_192': {'KL30': 0.5181941305766264,
#   'KL23': 0.605609785217156,
#   'KL28': 0.6668821136546196},
#  'Dpo_cdhit_193': {},
#  'Dpo_cdhit_194': {'KL36': 0.7624261507251544},
#  'Dpo_cdhit_195': {},
#  'Dpo_cdhit_196': {'KL36': 0.8432479510176076},
#  'Dpo_cdhit_197': {},
#  'Dpo_cdhit_198': {},
#  'Dpo_cdhit_199': {},
#  'Dpo_cdhit_200': {'KL117': 0.555994798481007},
#  'Dpo_cdhit_201': {},
#  'Dpo_cdhit_202': {'KL47': 0.9361094157565177},
#  'Dpo_cdhit_203': {'KL74': 0.8281797604312426},
#  'Dpo_cdhit_204': {},
#  'Dpo_cdhit_205': {'KL13': 0.559160355509073},
#  'Dpo_cdhit_206': {'KL10': 0.6676825858179232},
#  'Dpo_cdhit_207': {},
#  'Dpo_cdhit_208': {},
#  'Dpo_cdhit_209': {'KL74': 0.6963236111780963},
#  'Dpo_cdhit_210': {},
#  'Dpo_cdhit_211': {'KL74': 0.7321964298466882},
#  'Dpo_cdhit_212': {},
#  'Dpo_cdhit_213': {},
#  'Dpo_cdhit_214': {'KL143': 0.9076285240464343},
#  'Dpo_cdhit_215': {'KL74': 0.7310670559713196},
#  'Dpo_cdhit_216': {},
#  'Dpo_cdhit_217': {'KL107': 0.8009435779032655},
#  'Dpo_cdhit_218': {'KL128': 0.995},
#  'Dpo_cdhit_219': {'KL38': 0.6177642047232605},
#  'Dpo_cdhit_220': {'KL61': 0.5373757559511972},
#  'Dpo_cdhit_221': {'KL107': 0.612313602219541, 'KL52': 0.6352039094463338},
#  'Dpo_cdhit_222': {},
#  'Dpo_cdhit_223': {'KL164': 0.565},
#  'Dpo_cdhit_224': {'KL67': 0.8921324714781743, 'KL17': 0.8850744950040433},
#  'Dpo_cdhit_225': {},
#  'Dpo_cdhit_226': {'KL46': 0.9163233501874942, 'KL149': 0.6497543628543805},
#  'Dpo_cdhit_227': {},
#  'Dpo_cdhit_228': {},
#  'Dpo_cdhit_229': {'KL107': 0.5305543416701874},
#  'Dpo_cdhit_230': {},
#  'Dpo_cdhit_231': {'KL16': 0.6045823130299225},
#  'Dpo_cdhit_232': {'KL38': 0.7384566517167761},
#  'Dpo_cdhit_233': {'KL19': 0.5020466042963604},
#  'Dpo_cdhit_234': {'KL114': 0.9698958333333334},
#  'Dpo_cdhit_235': {},
#  'Dpo_cdhit_236': {'KL128': 0.5233333333333333},
#  'Dpo_cdhit_237': {},
#  'Dpo_cdhit_238': {'KL46': 0.7196105777133794},
#  'Dpo_cdhit_239': {'KL81': 0.7534634453287602},
#  'Dpo_cdhit_240': {'KL24': 0.5313420476051623},
#  'Dpo_cdhit_241': {'KL62': 0.8684006506454754},
#  'Dpo_cdhit_242': {'KL142': 0.8001413767456547},
#  'Dpo_cdhit_243': {},
#  'Dpo_cdhit_244': {'KL81': 0.647427077383999},
#  'Dpo_cdhit_245': {'KL102': 0.7133696264829217},
#  'Dpo_cdhit_246': {},
#  'Dpo_cdhit_247': {'KL128': 0.6116666666666667},
#  'Dpo_cdhit_248': {'KL38': 0.810906031818418},
#  'Dpo_cdhit_249': {'KL52': 0.8565763150990422},
#  'Dpo_cdhit_250': {'KL29': 0.6484583333333334},
#  'Dpo_cdhit_251': {},
#  'Dpo_cdhit_252': {},
#  'Dpo_cdhit_253': {},
#  'Dpo_cdhit_254': {'KL64': 0.9028761238195169},
#  'Dpo_cdhit_255': {'KL56': 0.8572924833837531, 'KL53': 0.520584007366902},
#  'Dpo_cdhit_256': {'KL27': 0.5779856225295922},
#  'Dpo_cdhit_257': {'KL38': 0.7110291816689791},
#  'Dpo_cdhit_258': {'KL141': 0.5430266477451909},
#  'Dpo_cdhit_259': {},
#  'Dpo_cdhit_260': {'KL11': 0.7485893497183811,
#   'KL48': 0.5030928193819397,
#   'KL51': 0.7141164061706933,
#   'KL16': 0.6673942895659385},
#  'Dpo_cdhit_261': {'KL128': 0.5691666666666667},
#  'Dpo_cdhit_262': {'KL29': 0.5101212121212122},
#  'Dpo_cdhit_263': {'KL10': 0.5211872921841959},
#  'Dpo_cdhit_264': {'KL81': 0.681944604983204},
#  'Dpo_cdhit_265': {'KL67': 0.9126674107142858},
#  'Dpo_cdhit_266': {'KL34': 1.0, 'KL53': 0.7209838078588078},
#  'Dpo_cdhit_267': {'KL64': 0.5596456263051844},
#  'Dpo_cdhit_268': {'KL27': 0.5951705100493837},
#  'Dpo_cdhit_269': {'KL122': 0.5139454859770997},
#  'Dpo_cdhit_270': {'KL62': 0.6502129566685441,
#   'KL25': 0.581947170652711,
#   'KL5': 0.6482664971287325,
#   'KL117': 0.893153397009544},
#  'Dpo_cdhit_271': {'KL27': 0.5943009651291123},
#  'Dpo_cdhit_272': {},
#  'Dpo_cdhit_273': {},
#  'Dpo_cdhit_274': {},
#  'Dpo_cdhit_275': {'KL3': 0.7532242851418038},
#  'Dpo_cdhit_276': {},
#  'Dpo_cdhit_277': {'KL43': 0.6618999387978418},
#  'Dpo_cdhit_278': {'KL36': 0.9057506530145911},
#  'Dpo_cdhit_279': {'KL119': 0.5767573407199958},
#  'Dpo_cdhit_280': {'KL25': 0.5113381278515909},
#  'Dpo_cdhit_281': {'KL117': 0.5250970755407653},
#  'Dpo_cdhit_282': {},
#  'Dpo_cdhit_283': {'KL164': 0.58,
#   'KL9': 0.7432722457699402,
#   'KL149': 0.6960241340749741},
#  'Dpo_cdhit_284': {'KL66': 0.6575342465753424},
#  'Dpo_cdhit_285': {'KL56': 0.5541744447498411},
#  'Dpo_cdhit_286': {},
#  'Dpo_cdhit_287': {'KL117': 0.5474679817612568},
#  'Dpo_cdhit_288': {'KL29': 0.6000795454545454},
#  'Dpo_cdhit_289': {'KL64': 0.5061116732569234},
#  'Dpo_cdhit_290': {'KL127': 0.5659971782819453, 'KL159': 0.8462374000695165},
#  'Dpo_cdhit_291': {'KL17': 0.9585965487592638},
#  'Dpo_cdhit_292': {'KL29': 1.0},
#  'Dpo_cdhit_293': {'KL155': 0.5730912517770144},
#  'Dpo_cdhit_294': {'KL74': 0.5007258230373816},
#  'Dpo_cdhit_295': {'KL56': 0.61171317292349},
#  'Dpo_cdhit_296': {'KL29': 0.6},
#  'Dpo_cdhit_297': {'KL25': 0.8377605813541803, 'KL136': 0.5298351541291048},
#  'Dpo_cdhit_298': {},
#  'Dpo_cdhit_299': {'KL46': 0.9398272200698834},
#  'Dpo_cdhit_300': {'KL46': 0.9271218123998864},
#  'Dpo_cdhit_301': {'KL74': 0.8400796465430089},
#  'Dpo_cdhit_302': {'KL46': 0.9549599661907232},
#  'Dpo_cdhit_303': {'KL63': 0.640730488637703},
#  'Dpo_cdhit_304': {'KL107': 0.9396615069007466},
#  'Dpo_cdhit_305': {'KL11': 0.5390194572452628},
#  'Dpo_cdhit_306': {'KL122': 0.5651624495950403},
#  'Dpo_cdhit_307': {'KL34': 1.0},
#  'Dpo_cdhit_308': {'KL43': 0.6470717306767719},
#  'Dpo_cdhit_309': {'KL19': 0.7317806219286803},
#  'Dpo_cdhit_310': {'KL29': 1.0},
#  'Dpo_cdhit_311': {},
#  'Dpo_cdhit_312': {'KL74': 0.8025445272433877},
#  'Dpo_cdhit_313': {'KL28': 0.5036450048014474},
#  'Dpo_cdhit_314': {},
#  'Dpo_cdhit_315': {'KL47': 0.841507958730127},
#  'Dpo_cdhit_316': {'KL67': 0.5157699342757944, 'KL60': 0.6594442028764768},
#  'Dpo_cdhit_317': {},
#  'Dpo_cdhit_318': {'KL66': 0.8958904109589041},
#  'Dpo_cdhit_319': {'KL3': 0.6739129447959293, 'KL35': 0.7363276113935945},
#  'Dpo_cdhit_320': {},
#  'Dpo_cdhit_321': {'KL45': 0.6285886735047247},
#  'Dpo_cdhit_322': {'KL36': 0.8915598316646008},
#  'Dpo_cdhit_323': {'KL47': 0.9502903399584091},
#  'Dpo_cdhit_324': {'KL62': 0.5151499824417193},
#  'Dpo_cdhit_325': {'KL155': 0.8502724889761615},
#  'Dpo_cdhit_326': {'KL103': 0.9865819209039548},
#  'Dpo_cdhit_327': {'KL14': 0.957269996777839, 'KL31': 0.5873976074921603},
#  'Dpo_cdhit_328': {'KL74': 0.8069526733917524},
#  'Dpo_cdhit_329': {},
#  'Dpo_cdhit_330': {'KL45': 0.877582562332743},
#  'Dpo_cdhit_331': {'KL62': 0.9404203720627685},
#  'Dpo_cdhit_332': {'KL52': 0.9910988282200404},
#  'Dpo_cdhit_333': {'KL45': 0.8973735364950446, 'KL110': 0.6938749474920205},
#  'Dpo_cdhit_334': {'KL62': 0.8170269427343141,
#   'KL11': 0.7243210445468504,
#   'KL25': 0.6101546706988549,
#   'KL12': 0.7405863095238095,
#   'KL159': 0.8805439694125821,
#   'KL35': 0.5600167886379187,
#   'KL142': 0.7809620934620934,
#   'KL117': 0.8712283176697005,
#   'KL16': 0.6029057976305566},
#  'Dpo_cdhit_335': {},
#  'Dpo_cdhit_336': {'KL124': 0.971440129449838,
#   'KL30': 0.5189505945976137,
#   'KL35': 0.5646087718181372,
#   'KL21': 0.6221563070094778,
#   'KL31': 0.5061118161152754},
#  'Dpo_cdhit_337': {'KL21': 0.6277207343603919},
#  'Dpo_cdhit_338': {},
#  'Dpo_cdhit_339': {'KL36': 0.8903939414407255},
#  'Dpo_cdhit_340': {},
#  'Dpo_cdhit_341': {},
#  'Dpo_cdhit_342': {},
#  'Dpo_cdhit_343': {'KL23': 0.6062704980332106},
#  'Dpo_cdhit_344': {'KL36': 0.9311850456277775},
#  'Dpo_cdhit_345': {'KL29': 1.0},
#  'Dpo_cdhit_346': {'KL128': 0.5983333333333333},
#  'Dpo_cdhit_347': {},
#  'Dpo_cdhit_348': {'KL22': 0.998533724340176},
#  'Dpo_cdhit_349': {},
#  'Dpo_cdhit_350': {},
#  'Dpo_cdhit_351': {'KL43': 0.652530501148109},
#  'Dpo_cdhit_352': {'KL35': 0.6604321098363282},
#  'Dpo_cdhit_353': {'KL12': 0.9729513888888881},
#  'Dpo_cdhit_354': {},
#  'Dpo_cdhit_355': {'KL45': 0.8990798269795062},
#  'Dpo_cdhit_356': {'KL62': 0.9516151828670432},
#  'Dpo_cdhit_357': {},
#  'Dpo_cdhit_358': {'KL12': 0.984670138888889},
#  'Dpo_cdhit_359': {},
#  'Dpo_cdhit_360': {},
#  'Dpo_cdhit_361': {'KL17': 0.9613750307406861},
#  'Dpo_cdhit_362': {'KL17': 0.5912942222004937},
#  'Dpo_cdhit_363': {'KL53': 0.7589038125617072},
#  'Dpo_cdhit_364': {},
#  'Dpo_cdhit_365': {'KL34': 1.0},
#  'Dpo_cdhit_366': {},
#  'Dpo_cdhit_367': {'KL45': 0.5069881585629046},
#  'Dpo_cdhit_368': {'KL102': 0.7595689242773493},
#  'Dpo_cdhit_369': {'KL15': 0.6410074192312172, 'KL106': 0.8592657611655089},
#  'Dpo_cdhit_370': {},
#  'Dpo_cdhit_371': {},
#  'Dpo_cdhit_372': {'KL70': 0.7324737733469636},
#  'Dpo_cdhit_373': {'KL13': 0.5055486172690604},
#  'Dpo_cdhit_374': {'KL36': 0.8978103003639187},
#  'Dpo_cdhit_375': {'KL31': 0.5295531150085585},
#  'Dpo_cdhit_376': {'KL149': 0.6761776433757406},
#  'Dpo_cdhit_377': {'KL108': 0.915465502992507},
#  'Dpo_cdhit_378': {},
#  'Dpo_cdhit_379': {'KL63': 0.5936651240242289},
#  'Dpo_cdhit_380': {'KL105': 0.9472070806206612,
#   'KL60': 0.5676752051437962,
#   'KL53': 0.7510775693604643},
#  'Dpo_cdhit_381': {'KL57': 0.9837830687830688},
#  'Dpo_cdhit_382': {'KL159': 0.8613920750782061,
#   'KL46': 0.9323403927450781,
#   'KL114': 1.0},
#  'Dpo_cdhit_383': {'KL28': 0.6247519633482517},
#  'Dpo_cdhit_384': {'KL47': 0.9512301943877183},
#  'Dpo_cdhit_385': {},
#  'Dpo_cdhit_386': {'KL118': 0.83728569383283},
#  'Dpo_cdhit_387': {},
#  'Dpo_cdhit_388': {},
#  'Dpo_cdhit_389': {'KL45': 0.8817132302400281},
#  'Dpo_cdhit_390': {},
#  'Dpo_cdhit_391': {},
#  'Dpo_cdhit_392': {'KL126': 1.0},
#  'Dpo_cdhit_393': {'KL2': 0.631595178368303},
#  'Dpo_cdhit_394': {},
#  'Dpo_cdhit_395': {},
#  'Dpo_cdhit_396': {},
#  'Dpo_cdhit_397': {'KL27': 0.5815289702101354},
#  'Dpo_cdhit_398': {},
#  'Dpo_cdhit_399': {},
#  'Dpo_cdhit_400': {'KL164': 1.0},
#  'Dpo_cdhit_401': {},
#  'Dpo_cdhit_402': {},
#  'Dpo_cdhit_403': {},
#  'Dpo_cdhit_404': {'KL105': 0.949176875437131, 'KL12': 0.9749007936507933},
#  'Dpo_cdhit_405': {'KL53': 0.9962499999999999},
#  'Dpo_cdhit_406': {'KL25': 0.9041884457352335, 'KL111': 0.5271036491844302},
#  'Dpo_cdhit_407': {},
#  'Dpo_cdhit_408': {'KL12': 0.5463219246031742},
#  'Dpo_cdhit_409': {},
#  'Dpo_cdhit_410': {},
#  'Dpo_cdhit_411': {'KL128': 0.5308333333333334},
#  'Dpo_cdhit_412': {'KL159': 0.8667361835245043},
#  'Dpo_cdhit_413': {'KL18': 0.5219950433705082, 'KL46': 0.9370992998759905},
#  'Dpo_cdhit_414': {'KL28': 0.5163113541249362},
#  'Dpo_cdhit_415': {'KL127': 0.5311155296501194},
#  'Dpo_cdhit_416': {'KL105': 0.9400187629722876,
#   'KL107': 0.9302718261596238,
#   'KL108': 0.8752614925978809,
#   'KL47': 0.9547822547512068,
#   'KL64': 0.9197666937365114,
#   'KL15': 0.7458117515148741,
#   'KL21': 0.6732930026611516,
#   'KL123': 0.6810079286117688,
#   'KL24': 0.5270553063959,
#   'KL106': 0.8022728473974381,
#   'KL36': 0.908481109796506},
#  'Dpo_cdhit_417': {},
#  'Dpo_cdhit_418': {},
#  'Dpo_cdhit_419': {'KL45': 0.8837978993188171},
#  'Dpo_cdhit_420': {'KL143': 0.8908789386401327},
#  'Dpo_cdhit_421': {'KL110': 0.7253609541459549,
#   'KL37': 0.8910256410256411,
#   'KL106': 0.5033422025727726,
#   'KL22': 0.6990102639296187},
#  'Dpo_cdhit_422': {'KL153': 0.6772533820346321, 'KL169': 0.5154005204976111},
#  'Dpo_cdhit_423': {'KL36': 0.9057116790068018},
#  'Dpo_cdhit_424': {},
#  'Dpo_cdhit_425': {'KL60': 0.5108395790851286},
#  'Dpo_cdhit_426': {},
#  'Dpo_cdhit_427': {},
#  'Dpo_cdhit_428': {},
#  'Dpo_cdhit_429': {'KL57': 0.7383115816154295},
#  'Dpo_cdhit_430': {'KL70': 0.9216078911403072},
#  'Dpo_cdhit_431': {'KL38': 0.7297526608587692},
#  'Dpo_cdhit_432': {},
#  'Dpo_cdhit_433': {},
#  'Dpo_cdhit_434': {'KL63': 0.5032806186240651},
#  'Dpo_cdhit_435': {},
#  'Dpo_cdhit_436': {'KL63': 0.7217031120534949},
#  'Dpo_cdhit_437': {'KL118': 0.8733781353869138},
#  'Dpo_cdhit_438': {},
#  'Dpo_cdhit_439': {},
#  'Dpo_cdhit_440': {'KL63': 0.6918033847575928},
#  'Dpo_cdhit_441': {},
#  'Dpo_cdhit_442': {'KL46': 0.947659453503864},
#  'Dpo_cdhit_443': {'KL111': 0.634947843707239},
#  'Dpo_cdhit_444': {'KL139': 1.0},
#  'Dpo_cdhit_445': {},
#  'Dpo_cdhit_446': {},
#  'Dpo_cdhit_447': {'KL8': 1.0,
#   'KL37': 0.8878205128205128,
#   'KL108': 0.6040012974408686,
#   'KL13': 0.5698765092767701,
#   'KL22': 0.9980591842175421},
#  'Dpo_cdhit_448': {'KL169': 0.5425106011255254},
#  'Dpo_cdhit_449': {'KL57': 0.9982456140350877, 'KL122': 0.5002337563484773},
#  'Dpo_cdhit_450': {},
#  'Dpo_cdhit_451': {},
#  'Dpo_cdhit_452': {'KL118': 0.8268342858352212},
#  'Dpo_cdhit_453': {'KL16': 0.5752871838710885},
#  'Dpo_cdhit_454': {'KL36': 0.9290450855081879},
#  'Dpo_cdhit_455': {'KL60': 0.5229068975427117},
#  'Dpo_cdhit_456': {'KL139': 1.0},
#  'Dpo_cdhit_457': {'KL45': 0.601150308363467},
#  'Dpo_cdhit_458': {'KL46': 0.9337327793093303},
#  'Dpo_cdhit_459': {},
#  'Dpo_cdhit_460': {'KL105': 0.9366280912581036, 'KL9': 0.7104172084974419},
#  'Dpo_cdhit_461': {},
#  'Dpo_cdhit_462': {'KL64': 0.950090108672657},
#  'Dpo_cdhit_463': {},
#  'Dpo_cdhit_464': {'KL70': 0.8763692612718952},
#  'Dpo_cdhit_465': {},
#  'Dpo_cdhit_466': {},
#  'Dpo_cdhit_467': {},
#  'Dpo_cdhit_468': {'KL139': 0.813986013986014},
#  'Dpo_cdhit_469': {},
#  'Dpo_cdhit_470': {'KL151': 0.8199783364541292},
#  'Dpo_cdhit_471': {'KL45': 0.8007601583889457,
#   'KL2': 0.6861177746601058,
#   'KL17': 0.6303996901591071,
#   'KL58': 0.5662698412698415,
#   'KL47': 0.5648978744015929,
#   'KL64': 0.742579245185601,
#   'KL102': 0.5140599914279956},
#  'Dpo_cdhit_472': {'KL25': 0.7344929729980777,
#   'KL111': 0.533762469812941,
#   'KL46': 0.5631279905860507},
#  'Dpo_cdhit_473': {'KL106': 0.8950728112216628},
#  'Dpo_cdhit_474': {},
#  'Dpo_cdhit_475': {},
#  'Dpo_cdhit_476': {'KL123': 0.6860350407063649},
#  'Dpo_cdhit_477': {'KL1': 0.5097420208872768},
#  'Dpo_cdhit_478': {'KL145': 0.6338124999999998},
#  'Dpo_cdhit_479': {'KL5': 0.5954865425236477},
#  'Dpo_cdhit_480': {'KL25': 0.9042255363434458},
#  'Dpo_cdhit_481': {'KL10': 0.5871519008525805},
#  'Dpo_cdhit_482': {},
#  'Dpo_cdhit_483': {},
#  'Dpo_cdhit_484': {'KL70': 0.742546900070368},
#  'Dpo_cdhit_485': {'KL12': 0.9742981150793646},
#  'Dpo_cdhit_486': {'KL153': 0.8523051497113997},
#  'Dpo_cdhit_487': {'KL25': 0.5528836950744459},
#  'Dpo_cdhit_488': {'KL123': 0.711262670619547},
#  'Dpo_cdhit_489': {'KL25': 0.8454285214338325,
#   'KL51': 0.5756294405113925,
#   'KL24': 0.7268075470176056,
#   'KL16': 0.6183858322589706},
#  'Dpo_cdhit_490': {'KL8': 0.9943566591422122},
#  'Dpo_cdhit_491': {},
#  'Dpo_cdhit_492': {},
#  'Dpo_cdhit_493': {'KL111': 0.5833007100448309},
#  'Dpo_cdhit_494': {},
#  'Dpo_cdhit_495': {},
#  'Dpo_cdhit_496': {'KL37': 0.9051282051282051, 'KL22': 0.9989803888553695},
#  'Dpo_cdhit_497': {'KL43': 0.6228591500633173},
#  'Dpo_cdhit_498': {'KL2': 0.6891650375835873, 'KL18': 0.6641883519206966},
#  'Dpo_cdhit_499': {},
#  'Dpo_cdhit_500': {'KL15': 0.7591158333082382},
#  'Dpo_cdhit_501': {'KL48': 0.5675088102903976},
#  'Dpo_cdhit_502': {'KL9': 0.6815942125410519},
#  'Dpo_cdhit_503': {},
#  'Dpo_cdhit_504': {},
#  'Dpo_cdhit_505': {},
#  'Dpo_cdhit_506': {},
#  'Dpo_cdhit_507': {'KL17': 0.8904136979189066},
#  'Dpo_cdhit_508': {'KL151': 0.5987065085723603},
#  'Dpo_cdhit_509': {},
#  'Dpo_cdhit_510': {},
#  'Dpo_cdhit_511': {'KL142': 0.6370713288494034},
#  'Dpo_cdhit_512': {},
#  'Dpo_cdhit_513': {},
#  'Dpo_cdhit_514': {'KL46': 0.9163714565158562},
#  'Dpo_cdhit_515': {'KL25': 0.8788397161858837},
#  'Dpo_cdhit_516': {'KL108': 0.8522240370033741},
#  'Dpo_cdhit_517': {'KL17': 0.9502932440010844},
#  'Dpo_cdhit_518': {},
#  'Dpo_cdhit_519': {'KL45': 0.8632105075573745,
#   'KL136': 0.5311409718453519,
#   'KL30': 0.6360526786665802,
#   'KL14': 0.9511720785711593},
#  'Dpo_cdhit_520': {'KL157': 0.5392394057169201,
#   'KL109': 0.6039809667244731,
#   'KL70': 0.5971492613360427,
#   'KL29': 1.0,
#   'KL74': 0.7029366560147464,
#   'KL152': 0.5386669823688783},
#  'Dpo_cdhit_521': {},
#  'Dpo_cdhit_522': {},
#  'Dpo_cdhit_523': {'KL5': 0.6128775670062448},
#  'Dpo_cdhit_524': {'KL81': 0.6014862574863522,
#   'KL67': 0.8559686569940476,
#   'KL60': 0.6131789988457688,
#   'KL8': 0.9887133182844243,
#   'KL126': 1.0},
#  'Dpo_cdhit_525': {'KL57': 0.9709090909090908},
#  'Dpo_cdhit_526': {'KL110': 0.5312880401317123},
#  'Dpo_cdhit_527': {'KL70': 0.8933809817048205},
#  'Dpo_cdhit_528': {'KL18': 0.9950433705080544},
#  'Dpo_cdhit_529': {'KL28': 0.7713672137380623},
#  'Dpo_cdhit_530': {'KL82': 0.5813528336380256},
#  'Dpo_cdhit_531': {'KL60': 0.5174076657407638,
#   'KL30': 0.513232364023683,
#   'KL159': 0.8733924226624952,
#   'KL64': 0.6941584982596103,
#   'KL14': 0.9544408350904142},
#  'Dpo_cdhit_532': {'KL151': 0.8003248732669362, 'KL19': 0.7679893213122669},
#  'Dpo_cdhit_533': {'KL47': 0.6405816378288502},
#  'Dpo_cdhit_534': {},
#  'Dpo_cdhit_535': {},
#  'Dpo_cdhit_536': {'KL2': 0.5200862860139925},
#  'Dpo_cdhit_537': {},
#  'Dpo_cdhit_538': {'KL107': 0.5990513795678905,
#   'KL139': 0.5,
#   'KL35': 0.5551176210914988,
#   'KL14': 0.9709522918615608,
#   'KL15': 0.5222411026723299,
#   'KL21': 0.5809705091592868,
#   'KL106': 0.624450849157837,
#   'KL36': 0.9298065899007556},
#  'Dpo_cdhit_539': {},
#  'Dpo_cdhit_540': {'KL141': 0.5272311573636077},
#  'Dpo_cdhit_541': {'KL102': 0.7359507097234214},
#  'Dpo_cdhit_542': {},
#  'Dpo_cdhit_543': {},
#  'Dpo_cdhit_544': {'KL128': 0.6533333333333334},
#  'Dpo_cdhit_545': {'KL18': 0.9882280049566294},
#  'Dpo_cdhit_546': {'KL21': 0.6701720820979189},
#  'Dpo_cdhit_547': {},
#  'Dpo_cdhit_548': {},
#  'Dpo_cdhit_549': {'KL64': 0.5790618929868447},
#  'Dpo_cdhit_550': {},
#  'Dpo_cdhit_551': {'KL29': 0.545},
#  'Dpo_cdhit_552': {'KL28': 0.6645359623320425},
#  'Dpo_cdhit_553': {'KL14': 0.9478671584706584},
#  'Dpo_cdhit_554': {},
#  'Dpo_cdhit_555': {'KL122': 0.621728581015254},
#  'Dpo_cdhit_556': {},
#  'Dpo_cdhit_557': {},
#  'Dpo_cdhit_558': {'KL35': 0.791070316937964},
#  'Dpo_cdhit_559': {'KL105': 0.9319706334868219},
#  'Dpo_cdhit_560': {'KL153': 0.8131245039682536},
#  'Dpo_cdhit_561': {'KL2': 0.6387441356165524},
#  'Dpo_cdhit_562': {},
#  'Dpo_cdhit_563': {'KL7': 0.5198999226585},
#  'Dpo_cdhit_564': {},
#  'Dpo_cdhit_565': {},
#  'Dpo_cdhit_566': {'KL38': 0.6137981999637205},
#  'Dpo_cdhit_567': {'KL128': 0.99},
#  'Dpo_cdhit_568': {'KL38': 0.5054608051747422, 'KL21': 0.7689637700890368},
#  'Dpo_cdhit_569': {'KL62': 0.9570650403939049, 'KL54': 0.64093327299756},
#  'Dpo_cdhit_570': {'KL17': 0.5888295915786869},
#  'Dpo_cdhit_571': {'KL53': 0.9610997474747475},
#  'Dpo_cdhit_572': {},
#  'Dpo_cdhit_573': {},
#  'Dpo_cdhit_574': {},
#  'Dpo_cdhit_575': {'KL149': 0.6897676404722327},
#  'Dpo_cdhit_576': {'KL105': 0.9556971759566142, 'KL12': 0.9519816468253961},
#  'Dpo_cdhit_577': {'KL25': 0.6246030637542084},
#  'Dpo_cdhit_578': {'KL2': 0.5041892646811488, 'KL29': 1.0},
#  'Dpo_cdhit_579': {'KL28': 0.5823696323202401},
#  'Dpo_cdhit_580': {'KL34': 1.0,
#   'KL11': 0.7329590373783915,
#   'KL18': 0.9727385377943,
#   'KL103': 0.5,
#   'KL51': 0.883620697561797,
#   'KL149': 0.555020705018343},
#  'Dpo_cdhit_581': {'KL116': 0.5347575365628097, 'KL110': 0.683112409219073},
#  'Dpo_cdhit_582': {},
#  'Dpo_cdhit_583': {'KL39': 0.7266750736409484},
#  'Dpo_cdhit_584': {'KL31': 0.6731782351710089},
#  'Dpo_cdhit_585': {'KL46': 0.9550978376108726},
#  'Dpo_cdhit_586': {'KL2': 0.6751802370622282},
#  'Dpo_cdhit_587': {},
#  'Dpo_cdhit_588': {},
#  'Dpo_cdhit_589': {'KL2': 0.684466679921928},
#  'Dpo_cdhit_590': {'KL117': 0.5509055787860173},
#  'Dpo_cdhit_591': {'KL22': 0.6567827526694635},
#  'Dpo_cdhit_592': {'KL155': 0.5219646946110593},
#  'Dpo_cdhit_593': {'KL25': 0.8577781177968481},
#  'Dpo_cdhit_594': {'KL30': 0.7092306788157682},
#  'Dpo_cdhit_595': {'KL3': 0.5111462002445865},
#  'Dpo_cdhit_596': {'KL3': 0.7189731664830779},
#  'Dpo_cdhit_597': {'KL17': 0.637903505343583},
#  'Dpo_cdhit_598': {},
#  'Dpo_cdhit_599': {},
#  'Dpo_cdhit_600': {'KL52': 0.9288814370253764},
#  'Dpo_cdhit_601': {'KL30': 0.6275141482027402},
#  'Dpo_cdhit_602': {},
#  'Dpo_cdhit_603': {'KL110': 0.735213679614466},
#  'Dpo_cdhit_604': {'KL157': 0.5623779529362499},
#  'Dpo_cdhit_605': {'KL108': 0.8506124140767011, 'KL10': 0.6785528108352722},
#  'Dpo_cdhit_606': {'KL13': 0.6043492052609218},
#  'Dpo_cdhit_607': {'KL64': 0.9343812082832613},
#  'Dpo_cdhit_608': {'KL103': 0.9872881355932204},
#  'Dpo_cdhit_609': {},
#  'Dpo_cdhit_610': {'KL110': 0.750367117561144},
#  'Dpo_cdhit_611': {},
#  'Dpo_cdhit_612': {'KL2': 0.6526287621052751},
#  'Dpo_cdhit_613': {'KL34': 1.0,
#   'KL60': 0.5032105713730922,
#   'KL57': 0.9737928153717628,
#   'KL56': 0.6322883025263973,
#   'KL1': 0.5541120252421945,
#   'KL53': 0.6398995310245311,
#   'KL14': 0.952448128346338,
#   'KL61': 0.5734632594049043,
#   'KL114': 0.9760416666666667,
#   'KL16': 0.583648122376284},
#  'Dpo_cdhit_614': {'KL74': 0.6527666255615219},
#  'Dpo_cdhit_615': {},
#  'Dpo_cdhit_616': {},
#  'Dpo_cdhit_617': {'KL70': 0.8813027188904601},
#  'Dpo_cdhit_618': {'KL24': 0.8941957614923483},
#  'Dpo_cdhit_619': {'KL164': 0.63},
#  'Dpo_cdhit_620': {},
#  'Dpo_cdhit_621': {'KL105': 0.600739646998965},
#  'Dpo_cdhit_622': {'KL30': 0.6722809604251135},
#  'Dpo_cdhit_623': {'KL61': 0.7159330739647485},
#  'Dpo_cdhit_624': {'KL117': 0.8633543677469048},
#  'Dpo_cdhit_625': {'KL2': 0.615087090231654},
#  'Dpo_cdhit_626': {'KL18': 0.9807930607187114, 'KL30': 0.6486357443284311},
#  'Dpo_cdhit_627': {},
#  'Dpo_cdhit_628': {'KL145': 0.971875},
#  'Dpo_cdhit_629': {'KL51': 0.6348766133723035},
#  'Dpo_cdhit_630': {'KL5': 0.6446815394310282},
#  'Dpo_cdhit_631': {'KL153': 0.6311100288600286, 'KL74': 0.5094871404367257},
#  'Dpo_cdhit_632': {'KL29': 0.9966666666666666},
#  'Dpo_cdhit_633': {'KL17': 0.7987491466595227, 'KL57': 0.9716402116402115},
#  'Dpo_cdhit_634': {},
#  'Dpo_cdhit_635': {},
#  'Dpo_cdhit_636': {'KL28': 0.6608749697645878},
#  'Dpo_cdhit_637': {'KL11': 0.7148366615463383},
#  'Dpo_cdhit_638': {'KL25': 0.5853189030258203,
#   'KL137': 0.9095999999999996,
#   'KL110': 0.6610244373594757,
#   'KL123': 0.682380802678873,
#   'KL114': 0.9788541666666666,
#   'KL19': 0.6931634655725588},
#  'Dpo_cdhit_639': {},
#  'Dpo_cdhit_640': {'KL117': 0.5352522238656859},
#  'Dpo_cdhit_641': {},
#  'Dpo_cdhit_642': {},
#  'Dpo_cdhit_643': {'KL139': 1.0},
#  'Dpo_cdhit_644': {'KL46': 0.9268489479771687},
#  'Dpo_cdhit_645': {},
#  'Dpo_cdhit_646': {'KL70': 0.8870939901315299},
#  'Dpo_cdhit_647': {'KL9': 0.7061729323992016},
#  'Dpo_cdhit_648': {'KL157': 0.6252235464612763},
#  'Dpo_cdhit_649': {'KL60': 0.5662496192945035},
#  'Dpo_cdhit_650': {'KL24': 0.884414853985881},
#  'Dpo_cdhit_651': {'KL14': 0.9759081872681186},
#  'Dpo_cdhit_652': {'KL66': 0.689041095890411, 'KL74': 0.6920250246510266},
#  'Dpo_cdhit_653': {'KL2': 0.5144098253127009},
#  'Dpo_cdhit_654': {'KL102': 0.5206148609177765},
#  'Dpo_cdhit_655': {},
#  'Dpo_cdhit_656': {},
#  'Dpo_cdhit_657': {},
#  'Dpo_cdhit_658': {'KL142': 0.6258668581863766,
#   'KL5': 0.6539563096534937,
#   'KL22': 0.9977191267513849},
#  'Dpo_cdhit_659': {'KL56': 0.604703049742732},
#  'Dpo_cdhit_660': {'KL52': 0.6486952721801207},
#  'Dpo_cdhit_661': {},
#  'Dpo_cdhit_662': {},
#  'Dpo_cdhit_663': {'KL34': 1.0,
#   'KL25': 0.6513468012753256,
#   'KL109': 0.6261854543152289,
#   'KL53': 0.6631644882894884,
#   'KL70': 0.8948554918510293,
#   'KL29': 0.5,
#   'KL74': 0.5056616816264529},
#  'Dpo_cdhit_664': {'KL56': 0.7143205156101977},
#  'Dpo_cdhit_665': {'KL141': 0.7869875433617173},
#  'Dpo_cdhit_666': {'KL23': 0.5949222793539373},
#  'Dpo_cdhit_667': {},
#  'Dpo_cdhit_668': {},
#  'Dpo_cdhit_669': {},
#  'Dpo_cdhit_670': {},
#  'Dpo_cdhit_671': {'KL29': 1.0},
#  'Dpo_cdhit_672': {},
#  'Dpo_cdhit_673': {'KL110': 0.6672680624179218, 'KL141': 0.8665957111321347},
#  'Dpo_cdhit_674': {},
#  'Dpo_cdhit_675': {},
#  'Dpo_cdhit_676': {'KL70': 0.8878475811944775, 'KL21': 0.6739516818124685},
#  'Dpo_cdhit_677': {'KL53': 0.9804038461538461},
#  'Dpo_cdhit_678': {},
#  'Dpo_cdhit_679': {'KL109': 0.6455075869084654},
#  'Dpo_cdhit_680': {},
#  'Dpo_cdhit_681': {},
#  'Dpo_cdhit_682': {},
#  'Dpo_cdhit_683': {},
#  'Dpo_cdhit_684': {'KL8': 0.9932279909706546},
#  'Dpo_cdhit_685': {'KL58': 0.5986111111111114},
#  'Dpo_cdhit_686': {},
#  'Dpo_cdhit_687': {},
#  'Dpo_cdhit_688': {},
#  'Dpo_cdhit_689': {'KL51': 0.6835463433012764,
#   'KL141': 0.5468976663513085,
#   'KL117': 0.8776632624415617},
#  'Dpo_cdhit_690': {'KL117': 0.8715946773816137},
#  'Dpo_cdhit_691': {'KL12': 0.9742113095238092},
#  'Dpo_cdhit_692': {'KL57': 0.9752994531145791},
#  'Dpo_cdhit_693': {},
#  'Dpo_cdhit_694': {'KL29': 0.9954545454545455},
#  'Dpo_cdhit_695': {'KL116': 0.6456442847228139},
#  'Dpo_cdhit_696': {'KL137': 0.9156888888888884},
#  'Dpo_cdhit_697': {},
#  'Dpo_cdhit_698': {},
#  'Dpo_cdhit_699': {'KL67': 0.8564546130952374},
#  'Dpo_cdhit_700': {'KL64': 0.5439154696282712},
#  'Dpo_cdhit_701': {'KL63': 0.6501192236370598},
#  'Dpo_cdhit_702': {},
#  'Dpo_cdhit_703': {},
#  'Dpo_cdhit_704': {'KL107': 0.7536884301608106},
#  'Dpo_cdhit_705': {},
#  'Dpo_cdhit_706': {'KL17': 0.565179007117252},
#  'Dpo_cdhit_707': {},
#  'Dpo_cdhit_708': {'KL112': 0.7364443698461227},
#  'Dpo_cdhit_709': {},
#  'Dpo_cdhit_710': {},
#  'Dpo_cdhit_711': {'KL1': 0.530170155641169},
#  'Dpo_cdhit_712': {'KL128': 0.9875},
#  'Dpo_cdhit_713': {},
#  'Dpo_cdhit_714': {'KL118': 0.5069966010223027},
#  'Dpo_cdhit_715': {},
#  'Dpo_cdhit_716': {},
#  'Dpo_cdhit_717': {'KL35': 0.6072352422474327,
#   'KL64': 0.5560035665920272,
#   'KL114': 0.9654166666666667},
#  'Dpo_cdhit_718': {},
#  'Dpo_cdhit_719': {},
#  'Dpo_cdhit_720': {},
#  'Dpo_cdhit_721': {},
#  'Dpo_cdhit_722': {'KL30': 0.6865708764249311,
#   'KL37': 0.6125000000000003,
#   'KL19': 0.5118369637083784,
#   'KL22': 0.8507646638145171},
#  'Dpo_cdhit_723': {},
#  'Dpo_cdhit_724': {'KL46': 0.6892137168548079},
#  'Dpo_cdhit_725': {},
#  'Dpo_cdhit_726': {},
#  'Dpo_cdhit_727': {},
#  'Dpo_cdhit_728': {'KL151': 0.8737120790742122, 'KL143': 0.9563847429519071},
#  'Dpo_cdhit_729': {},
#  'Dpo_cdhit_730': {},
#  'Dpo_cdhit_731': {},
#  'Dpo_cdhit_732': {},
#  'Dpo_cdhit_733': {'KL17': 0.8673288090322286},
#  'Dpo_cdhit_734': {},
#  'Dpo_cdhit_735': {'KL110': 0.7260959116301641},
#  'Dpo_cdhit_736': {},
#  'Dpo_cdhit_737': {'KL35': 0.5992111838969426, 'KL21': 0.7333258941798624},
#  'Dpo_cdhit_738': {},
#  'Dpo_cdhit_739': {'KL34': 0.5,
#   'KL57': 0.7010554524840238,
#   'KL30': 0.7858057536334975,
#   'KL5': 0.5181980316285951,
#   'KL61': 0.5178786232577776},
#  'Dpo_cdhit_740': {'KL139': 0.5454545454545454,
#   'KL8': 0.5082768999247553,
#   'KL114': 0.5445833333333332},
#  'Dpo_cdhit_741': {},
#  'Dpo_cdhit_742': {},
#  'Dpo_cdhit_743': {'KL57': 0.978915343915344,
#   'KL9': 0.677053414143135,
#   'KL118': 0.5276108254450975,
#   'KL64': 0.5848955465047759},
#  'Dpo_cdhit_744': {'KL25': 0.8328735771174769},
#  'Dpo_cdhit_745': {},
#  'Dpo_cdhit_746': {'KL8': 0.989841986455982},
#  'Dpo_cdhit_747': {},
#  'Dpo_cdhit_748': {'KL45': 0.8410856871294004},
#  'Dpo_cdhit_749': {},
#  'Dpo_cdhit_750': {},
#  'Dpo_cdhit_751': {'KL16': 0.6132329309878081},
#  'Dpo_cdhit_752': {},
#  'Dpo_cdhit_753': {},
#  'Dpo_cdhit_754': {'KL143': 0.912603648424544},
#  'Dpo_cdhit_755': {'KL25': 0.8218284889077013},
#  'Dpo_cdhit_756': {},
#  'Dpo_cdhit_757': {},
#  'Dpo_cdhit_758': {},
#  'Dpo_cdhit_759': {'KL74': 0.5455862389364645},
#  'Dpo_cdhit_760': {'KL2': 0.5625608748349792,
#   'KL47': 0.7813700656299122,
#   'KL64': 0.5233890339676571},
#  'Dpo_cdhit_761': {'KL118': 0.8736284801826326},
#  'Dpo_cdhit_762': {'KL102': 0.736972444555183},
#  'Dpo_cdhit_763': {},
#  'Dpo_cdhit_764': {'KL110': 0.720824906058316},
#  'Dpo_cdhit_765': {'KL64': 0.7357695104031743},
#  'Dpo_cdhit_766': {'KL2': 0.5193609333827834},
#  'Dpo_cdhit_767': {'KL105': 0.9160828363426899},
#  'Dpo_cdhit_768': {'KL62': 0.6132423559819725},
#  'Dpo_cdhit_769': {'KL117': 0.8798304530512406},
#  'Dpo_cdhit_770': {},
#  'Dpo_cdhit_771': {'KL28': 0.7303197122171734},
#  'Dpo_cdhit_772': {'KL46': 0.9350558383871723, 'KL106': 0.8665226601910655},
#  'Dpo_cdhit_773': {},
#  'Dpo_cdhit_774': {'KL82': 0.5630712979890311},
#  'Dpo_cdhit_775': {},
#  'Dpo_cdhit_776': {},
#  'Dpo_cdhit_777': {},
#  'Dpo_cdhit_778': {'KL57': 0.9884944684944685},
#  'Dpo_cdhit_779': {},
#  'Dpo_cdhit_780': {},
#  'Dpo_cdhit_781': {},
#  'Dpo_cdhit_782': {},
#  'Dpo_cdhit_783': {},
#  'Dpo_cdhit_784': {},
#  'Dpo_cdhit_785': {},
#  'Dpo_cdhit_786': {'KL15': 0.5922439258938114},
#  'Dpo_cdhit_787': {'KL107': 0.765497389037762,
#   'KL51': 0.6139914531048705,
#   'KL106': 0.6716442223185597},
#  'Dpo_cdhit_788': {'KL164': 1.0},
#  'Dpo_cdhit_789': {},
#  'Dpo_cdhit_790': {'KL145': 0.877125, 'KL141': 0.538174077578051},
#  'Dpo_cdhit_791': {},
#  'Dpo_cdhit_792': {},
#  'Dpo_cdhit_793': {},
#  'Dpo_cdhit_794': {'KL119': 0.5986112079569901},
#  'Dpo_cdhit_795': {'KL30': 0.5036471737211717,
#   'KL82': 0.9524680073126143,
#   'KL23': 0.6057344497001496},
#  'Dpo_cdhit_796': {'KL25': 0.7794116641035058},
#  'Dpo_cdhit_797': {},
#  'Dpo_cdhit_798': {'KL46': 0.9088265005927686},
#  'Dpo_cdhit_799': {},
#  'Dpo_cdhit_800': {},
#  'Dpo_cdhit_801': {},
#  'Dpo_cdhit_802': {},
#  'Dpo_cdhit_803': {'KL45': 0.8730790855774717,
#   'KL64': 0.5193489286193537,
#   'KL46': 0.9263483942753012},
#  'Dpo_cdhit_804': {'KL14': 0.9217552231367747},
#  'Dpo_cdhit_805': {},
#  'Dpo_cdhit_806': {'KL137': 0.9295999999999996,
#   'KL17': 0.5595259797873628,
#   'KL14': 0.5748623779958356,
#   'KL22': 0.624395833625653},
#  'Dpo_cdhit_807': {'KL5': 0.640216026107041},
#  'Dpo_cdhit_808': {},
#  'Dpo_cdhit_809': {},
#  'Dpo_cdhit_810': {},
#  'Dpo_cdhit_811': {'KL25': 0.8275234292920169},
#  'Dpo_cdhit_812': {'KL105': 0.9209996543191193},
#  'Dpo_cdhit_813': {'KL2': 0.73718334015395, 'KL21': 0.7756773254472666},
#  'Dpo_cdhit_814': {'KL108': 0.8600868592737995,
#   'KL51': 0.9193883108633548,
#   'KL19': 0.6607231493439238},
#  'Dpo_cdhit_815': {},
#  'Dpo_cdhit_816': {'KL60': 0.55083141661268},
#  'Dpo_cdhit_817': {},
#  'Dpo_cdhit_818': {},
#  'Dpo_cdhit_819': {'KL25': 0.8042563041884996},
#  'Dpo_cdhit_820': {'KL145': 0.8442500000000002},
#  'Dpo_cdhit_821': {},
#  'Dpo_cdhit_822': {},
#  'Dpo_cdhit_823': {'KL109': 0.6624053886229208},
#  'Dpo_cdhit_824': {'KL2': 0.6708860463105734,
#   'KL17': 0.7548289223600626,
#   'KL151': 0.5125060253395268,
#   'KL58': 0.529166666666667,
#   'KL113': 0.6451463804438632,
#   'KL51': 0.957845466661051,
#   'KL21': 0.6552437383055015,
#   'KL16': 0.5013357652753418},
#  'Dpo_cdhit_825': {},
#  'Dpo_cdhit_826': {'KL103': 0.9865819209039548},
#  'Dpo_cdhit_827': {'KL153': 0.6460928030303027},
#  'Dpo_cdhit_828': {'KL107': 0.654758504377615, 'KL15': 0.6818483134767874},
#  'Dpo_cdhit_829': {},
#  'Dpo_cdhit_830': {},
#  'Dpo_cdhit_831': {},
#  'Dpo_cdhit_832': {'KL62': 0.6168586181967486,
#   'KL107': 0.9204329031768315,
#   'KL51': 0.6108433785567187,
#   'KL24': 0.5133881820464766},
#  'Dpo_cdhit_833': {},
#  'Dpo_cdhit_834': {'KL30': 0.6821484545015934, 'KL82': 0.9588665447897623},
#  'Dpo_cdhit_835': {'KL29': 1.0},
#  'Dpo_cdhit_836': {},
#  'Dpo_cdhit_837': {'KL55': 0.501499488665006,
#   'KL159': 0.5458811261730965,
#   'KL142': 0.5999904544356417,
#   'KL70': 0.646430152602696,
#   'KL43': 0.6049066242783027,
#   'KL126': 0.5475},
#  'Dpo_cdhit_838': {'KL29': 1.0},
#  'Dpo_cdhit_839': {'KL107': 0.7006689761951125, 'KL106': 0.5209861961215932},
#  'Dpo_cdhit_840': {},
#  'Dpo_cdhit_841': {},
#  'Dpo_cdhit_842': {'KL17': 0.958283717373429, 'KL30': 0.553222144887479},
#  'Dpo_cdhit_843': {'KL117': 0.8635300550664982},
#  'Dpo_cdhit_844': {'KL34': 1.0, 'KL158': 0.5595019841269849},
#  'Dpo_cdhit_845': {},
#  'Dpo_cdhit_846': {},
#  'Dpo_cdhit_847': {},
#  'Dpo_cdhit_848': {'KL124': 0.6619741100323624},
#  'Dpo_cdhit_849': {'KL3': 0.5375353068904749},
#  'Dpo_cdhit_850': {'KL62': 0.9036503586988089},
#  'Dpo_cdhit_851': {'KL151': 0.8230082869968389,
#   'KL110': 0.7024455527407811,
#   'KL8': 0.989841986455982,
#   'KL1': 0.5737134243268939,
#   'KL102': 0.7024172259237808,
#   'KL22': 0.8575895216580506,
#   'KL16': 0.6152676280365441},
#  'Dpo_cdhit_852': {'KL25': 0.5620082330439509, 'KL8': 0.6044394281414597},
#  'Dpo_cdhit_853': {'KL2': 0.5201521647854105,
#   'KL12': 0.9650446428571425,
#   'KL113': 0.5562938142457592,
#   'KL51': 0.969854478467723,
#   'KL13': 0.5394514354627353,
#   'KL114': 0.9754166666666667},
#  'Dpo_cdhit_854': {},
#  'Dpo_cdhit_855': {'KL66': 0.673972602739726},
#  'Dpo_cdhit_856': {},
#  'Dpo_cdhit_857': {},
#  'Dpo_cdhit_858': {'KL15': 0.5120204091388763},
#  'Dpo_cdhit_859': {'KL67': 0.8397507440476187},
#  'Dpo_cdhit_860': {'KL19': 0.6701365674039736},
#  'Dpo_cdhit_861': {'KL64': 0.6141702419490449},
#  'Dpo_cdhit_862': {},
#  'Dpo_cdhit_863': {},
#  'Dpo_cdhit_864': {'KL119': 0.5353772960785348},
#  'Dpo_cdhit_865': {'KL25': 0.833366948098367},
#  'Dpo_cdhit_866': {'KL124': 0.591990291262136,
#   'KL21': 0.7139830370320087,
#   'KL31': 0.5137828605975784},
#  'Dpo_cdhit_867': {'KL17': 0.9452050188402364},
#  'Dpo_cdhit_868': {},
#  'Dpo_cdhit_869': {},
#  'Dpo_cdhit_870': {'KL51': 0.5911005131459871},
#  'Dpo_cdhit_871': {},
#  'Dpo_cdhit_872': {'KL17': 0.9080841973865732},
#  'Dpo_cdhit_873': {'KL62': 0.8154464293655249},
#  'Dpo_cdhit_874': {},
#  'Dpo_cdhit_875': {'KL114': 0.9770833333333333},
#  'Dpo_cdhit_876': {'KL105': 0.950830621010669},
#  'Dpo_cdhit_877': {},
#  'Dpo_cdhit_878': {},
#  'Dpo_cdhit_879': {'KL25': 0.8259234331972665},
#  'Dpo_cdhit_880': {},
#  'Dpo_cdhit_881': {},
#  'Dpo_cdhit_882': {'KL113': 0.5634139697068757,
#   'KL108': 0.8920433922167839,
#   'KL35': 0.5829157623422329,
#   'KL54': 0.6658690219029911,
#   'KL63': 0.7504865850211123,
#   'KL114': 1.0},
#  'Dpo_cdhit_883': {'KL30': 0.849724060340851},
#  'Dpo_cdhit_884': {'KL63': 0.6385840866594714},
#  'Dpo_cdhit_885': {'KL102': 0.6864324401357493},
#  'Dpo_cdhit_886': {},
#  'Dpo_cdhit_887': {'KL123': 0.5386761045095068},
#  'Dpo_cdhit_888': {},
#  'Dpo_cdhit_889': {'KL126': 1.0},
#  'Dpo_cdhit_890': {},
#  'Dpo_cdhit_891': {'KL17': 0.7376430104752748},
#  'Dpo_cdhit_892': {'KL63': 0.7313329581548215},
#  'Dpo_cdhit_893': {},
#  'Dpo_cdhit_894': {},
#  'Dpo_cdhit_895': {},
#  'Dpo_cdhit_896': {},
#  'Dpo_cdhit_897': {'KL63': 0.6386630257025415},
#  'Dpo_cdhit_898': {'KL46': 0.9344706513910859},
#  'Dpo_cdhit_899': {},
#  'Dpo_cdhit_900': {'KL5': 0.6334930340117866},
#  'Dpo_cdhit_901': {'KL45': 0.5908895814888974},
#  'Dpo_cdhit_902': {'KL17': 0.7990395336886309},
#  'Dpo_cdhit_903': {},
#  'Dpo_cdhit_904': {},
#  'Dpo_cdhit_905': {},
#  'Dpo_cdhit_906': {},
#  'Dpo_cdhit_907': {'KL102': 0.6998201135342307},
#  'Dpo_cdhit_908': {'KL2': 0.6874015025481509,
#   'KL110': 0.6711850207610559,
#   'KL51': 0.589902671456391},
#  'Dpo_cdhit_909': {'KL109': 0.6457406770718455},
#  'Dpo_cdhit_910': {'KL17': 0.7789535266282673,
#   'KL8': 0.9954853273137697,
#   'KL127': 0.5202653018700514,
#   'KL30': 0.5204914005491844,
#   'KL16': 0.6181355263917647},
#  'Dpo_cdhit_911': {},
#  'Dpo_cdhit_912': {'KL18': 0.5244733581164809},
#  'Dpo_cdhit_913': {'KL145': 0.8756458333333335},
#  'Dpo_cdhit_914': {'KL5': 0.6290378568351993},
#  'Dpo_cdhit_915': {},
#  'Dpo_cdhit_916': {},
#  'Dpo_cdhit_917': {},
#  'Dpo_cdhit_918': {'KL9': 0.697289307294887},
#  'Dpo_cdhit_919': {},
#  'Dpo_cdhit_920': {'KL112': 0.6509833398298822,
#   'KL2': 0.5537305415179518,
#   'KL51': 0.6526951760126279,
#   'KL64': 0.7488595004598961,
#   'KL145': 0.6245416666666666,
#   'KL14': 0.9564967149682095,
#   'KL24': 0.7759868293953118},
#  'Dpo_cdhit_921': {'KL34': 1.0},
#  'Dpo_cdhit_922': {},
#  'Dpo_cdhit_923': {},
#  'Dpo_cdhit_924': {},
#  'Dpo_cdhit_925': {'KL7': 0.5622697461654758,
#   'KL2': 0.6279615743745294,
#   'KL57': 0.9962406015037595,
#   'KL103': 0.9823446327683616,
#   'KL46': 0.9166738280687885},
#  'Dpo_cdhit_926': {'KL25': 0.8491983408162301,
#   'KL105': 0.9417314054454484,
#   'KL47': 0.5865472127009925,
#   'KL46': 0.899005568158254},
#  'Dpo_cdhit_927': {'KL64': 0.8030645115088643},
#  'Dpo_cdhit_928': {'KL62': 0.5959796223342594},
#  'Dpo_cdhit_929': {'KL149': 0.6259437574516684},
#  'Dpo_cdhit_930': {'KL53': 0.6282810186889134},
#  'Dpo_cdhit_931': {'KL38': 0.5114319091691847},
#  'Dpo_cdhit_932': {},
#  'Dpo_cdhit_933': {},
#  'Dpo_cdhit_934': {},
#  'Dpo_cdhit_935': {},
#  'Dpo_cdhit_936': {'KL105': 0.5021412191027586,
#   'KL107': 0.5595688692172972,
#   'KL106': 0.5475071182579478},
#  'Dpo_cdhit_937': {'KL109': 0.6069293441046687},
#  'Dpo_cdhit_938': {},
#  'Dpo_cdhit_939': {},
#  'Dpo_cdhit_940': {},
#  'Dpo_cdhit_941': {},
#  'Dpo_cdhit_942': {'KL2': 0.6059719323001885},
#  'Dpo_cdhit_943': {'KL53': 0.6774401015651016},
#  'Dpo_cdhit_944': {'KL14': 0.500412153210029},
#  'Dpo_cdhit_945': {},
#  'Dpo_cdhit_946': {'KL17': 0.5828163200597793},
#  'Dpo_cdhit_947': {},
#  'Dpo_cdhit_948': {'KL30': 0.5326573549692794, 'KL29': 0.9975},
#  'Dpo_cdhit_949': {},
#  'Dpo_cdhit_950': {},
#  'Dpo_cdhit_951': {'KL25': 0.5196361233052761},
#  'Dpo_cdhit_952': {},
#  'Dpo_cdhit_953': {},
#  'Dpo_cdhit_954': {},
#  'Dpo_cdhit_955': {'KL21': 0.7128880941929638},
#  'Dpo_cdhit_956': {'KL51': 0.7864356827355479},
#  'Dpo_cdhit_957': {},
#  'Dpo_cdhit_958': {'KL17': 0.6055385131772008},
#  'Dpo_cdhit_959': {},
#  'Dpo_cdhit_960': {'KL2': 0.5292433169456133},
#  'Dpo_cdhit_961': {},
#  'Dpo_cdhit_962': {},
#  'Dpo_cdhit_963': {},
#  'Dpo_cdhit_964': {'KL61': 0.6152247489858664, 'KL21': 0.7074858105997812},
#  'Dpo_cdhit_965': {},
#  'Dpo_cdhit_966': {},
#  'Dpo_cdhit_967': {'KL157': 0.564904015014604},
#  'Dpo_cdhit_968': {},
#  'Dpo_cdhit_969': {'KL64': 0.5295656360041479},
#  'Dpo_cdhit_970': {},
#  'Dpo_cdhit_971': {},
#  'Dpo_cdhit_972': {'KL2': 0.5834062424597952},
#  'Dpo_cdhit_973': {},
#  'Dpo_cdhit_974': {},
#  'Dpo_cdhit_975': {},
#  'Dpo_cdhit_976': {'KL9': 0.6813429877240239},
#  'Dpo_cdhit_977': {},
#  'Dpo_cdhit_978': {},
#  'Dpo_cdhit_979': {},
#  'Dpo_cdhit_980': {'KL17': 0.6298350708620986},
#  'Dpo_cdhit_981': {},
#  'Dpo_cdhit_982': {},
#  'Dpo_cdhit_983': {},
#  'Dpo_cdhit_984': {},
#  'Dpo_cdhit_985': {'KL47': 0.5422138575274573},
#  'Dpo_cdhit_986': {},
#  'Dpo_cdhit_987': {},
#  'Dpo_cdhit_988': {}}

# %% [markdown]
# ***
# ## Make the predictions :

# %%
path_tmp =  "/media/concha-eloko/Linux/PPT_clean/Seqbased_model/tmp"
labels_blast=["qseqid", "sseqid", "pident", "length", "mismatch", "gapopen", "qstart", "qend", "sstart", "send", "evalue", "bitscore"]

def tmp_fasta_file(record , path_tmp) :
    name_file = "_".join(record.description.split(" "))
    path_fasta = f"{path_tmp}/{name_file}.fasta"
    length_seq = len(record.seq)
    with open(path_fasta, "w") as outfile :
        outfile.write(f">{record.description}\n{str(record.seq)}")
    return path_fasta , length_seq

def blast_seq(path_fasta, path_DB, path_tmp) :
    file_name = path_fasta.split("/")[-1]
    command = f"blastp -query {path_fasta} -db {path_DB} -out {path_tmp}/{file_name}.blast_out -outfmt 6 -evalue 1e-10"
    blastp_sub = subprocess.Popen(command ,shell = True, stdout = subprocess.PIPE, stderr = subprocess.STDOUT)
    out , err = blastp_sub.communicate()
    return f"{path_tmp}/{file_name}.blast_out"

def get_best_candidate(path_blast_out, length_seq, bitscore = 75) : 
    winner = 0
    labels_blast=["qseqid", "sseqid", "pident", "length", "mismatch", "gapopen", "qstart", "qend", "sstart", "send", "evalue", "bitscore"]
    blast_df = pd.read_csv(path_blast_out, sep = "\t", names = labels_blast)
    if len(blast_df) > 0 :
        row = blast_df.iloc[0] 
        if row["bitscore"] > bitscore and length_seq/int(row["length"])> 0.8:
            winner = dico_cluster_r[row["sseqid"]]
        else :
            winner = "No hits"
    else :
        winner = "No hits"
    return winner

def get_winner(record , path_tmp) :
    path_func , len_func = tmp_fasta_file(record, path_tmp)
    path_blast_out_func = blast_seq(path_func , path_db, path_tmp)
    winner = get_best_candidate(path_blast_out_func, len_func)
    return winner

# %% [markdown]
# > Ferriol :

# %%
path_seq = "/media/concha-eloko/Linux/77_strains_phage_project/rbp_work"

dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_seq}/77_phages_Dpo_domains.2406.multi.fasta", "fasta") if len(record.seq) >0}
set_records = [record for record in SeqIO.parse(f"{path_seq}/77_phages_Dpo_domains.2406.multi.fasta", "fasta") if len(record.seq) > 0]


ferriol_winners = []
for record in tqdm(set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        results = dico_pred_correct_name.get(winner, {})
        a = (record.description.split(",")[0] , winner, results)
    else :
        results = "Null"
    a = (record.description.split(",")[0] , winner, results)
    ferriol_winners.append(a)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 145/145 [00:06<00:00, 23.17it/s]

# %%
ferriol_winners
# Out:
# [('K10PH82C1__cds_49', 'No hits', 'Null'),
#  ('K13PH07C1L__cds_10', 'Dpo_cdhit_595', {'KL3': 0.5111462002445865}),
#  ('K13PH07C1L__cds_11', 'Dpo_cdhit_62', {'KL13': 0.5272369948063018}),
#  ('K13PH07C1L__cds_12', 'Dpo_cdhit_965', {}),
#  ('K15PH90__cds_54', 'No hits', 'Null'),
#  ('K18PH07C1__cds_243',
#   'Dpo_cdhit_626',
#   {'KL18': 0.9807930607187114, 'KL30': 0.6486357443284311}),
#  ('K18PH07C1__cds_245', 'Dpo_cdhit_379', {'KL63': 0.5936651240242289}),
#  ('K22PH164C1__cds_11', 'No hits', 'Null'),
#  ('K30lambda2_2__cds_152', 'No hits', 'Null'),
#  ('K30lambda2_2__cds_20', 'No hits', 'Null'),
#  ('K32PH164C1__cds_151', 'No hits', 'Null'),
#  ('K32PH164C1__cds_20', 'No hits', 'Null'),
#  ('K34PH164__cds_24', 'No hits', 'Null'),
#  ('K41P2__cds_227', 'No hits', 'Null'),
#  ('K49PH164C2__cds_24', 'No hits', 'Null'),
#  ('K65PH164__cds_198', 'No hits', 'Null'),
#  ('K70PH128C1__cds_24', 'No hits', 'Null'),
#  ('K7PH164C4__cds_151', 'No hits', 'Null'),
#  ('K7PH164C4__cds_20', 'No hits', 'Null'),
#  ('K17alfa62__cds_66_A_281-682', 'Dpo_cdhit_88', {}),
#  ('K14PH164C1__cds_24_A_4_221_871.pdb',
#   'Dpo_cdhit_92',
#   {'KL64': 0.6702590696691522}),
#  ('K64PH164C4__cds_24_A_4_178_852.pdb',
#   'Dpo_cdhit_56',
#   {'KL64': 0.9037259998449553}),
#  ('K40PH129C1__cds_56_A_4_239_860.pdb', 'No hits', 'Null'),
#  ('K51PH129C1__cds_9_A_1_92_787.pdb',
#   'Dpo_cdhit_47',
#   {'KL51': 0.9638243750057931}),
#  ('K15PH90__cds_55_A.pdb', 'Dpo_cdhit_182', {'KL15': 0.7938890377524203}),
#  ('K21lambda1__cds_28_A.pdb',
#   'Dpo_cdhit_336',
#   {'KL124': 0.971440129449838,
#    'KL30': 0.5189505945976137,
#    'KL35': 0.5646087718181372,
#    'KL21': 0.6221563070094778,
#    'KL31': 0.5061118161152754}),
#  ('K26PH128C1__cds_50_A_1_97_595.pdb', 'Dpo_cdhit_87', {}),
#  ('K35PH164C3__cds_48_A_4_282_728.pdb',
#   'Dpo_cdhit_352',
#   {'KL35': 0.6604321098363282}),
#  ('K37PH164C1__cds_47_A_1_1_307.pdb', 'Dpo_cdhit_599', {}),
#  ('K38PH09C2__cds_24_A_4_178_672.pdb', 'Dpo_cdhit_76', {}),
#  ('K27PH129C1__cds_48_A_7_200_648.pdb',
#   'Dpo_cdhit_268',
#   {'KL27': 0.5951705100493837}),
#  ('K5lambda5__cds_198_A_3_173_674.pdb',
#   'Dpo_cdhit_104',
#   {'KL123': 0.5058610644918217}),
#  ('K41P2__cds_11_A_7_188_506.pdb', 'Dpo_cdhit_274', {}),
#  ('K43PH164C1__cds_40_A_3_296_718.pdb', 'Dpo_cdhit_311', {}),
#  ('K11PH164C1__cds_46_A_1_1_416.pdb',
#   'Dpo_cdhit_429',
#   {'KL57': 0.7383115816154295}),
#  ('K17alfa62__cds_64_A_3_129_548.pdb',
#   'Dpo_cdhit_362',
#   {'KL17': 0.5912942222004937}),
#  ('K2PH164C1__cds_23_A_6_269_664.pdb', 'No hits', 'Null'),
#  ('K2alfa62__cds_23_A_6_269_671.pdb', 'No hits', 'Null'),
#  ('K56PH164C1__cds_48_A_5_293_702.pdb', 'No hits', 'Null'),
#  ('K82P1__cds_45_A_5_292_704.pdb', 'No hits', 'Null'),
#  ('K66PH128C1__cds_59_A_4_252_713.pdb',
#   'Dpo_cdhit_284',
#   {'KL66': 0.6575342465753424}),
#  ('K23PH08C2__cds_233_A_2_76_514.pdb', 'Dpo_cdhit_235', {}),
#  ('K60PH164C1__cds_96_A_6_321_703.pdb', 'Dpo_cdhit_9', {}),
#  ('K56PH164C1__cds_49_A_3_110_475.pdb',
#   'Dpo_cdhit_295',
#   {'KL56': 0.61171317292349}),
#  ('K74PH129C2__cds_52_A_2_34_431.pdb', 'Dpo_cdhit_391', {}),
#  ('K8PH128__cds_46_A_5_294_719.pdb', 'No hits', 'Null'),
#  ('K44PH129C1__cds_9_A_2_39_391.pdb', 'Dpo_cdhit_599', {}),
#  ('K22PH164C1__cds_10_A_1_1_368.pdb', 'Dpo_cdhit_599', {}),
#  ('K24PH164C1__cds_8_A_2_85_402.pdb',
#   'Dpo_cdhit_71',
#   {'KL112': 0.7797781306684983,
#    'KL48': 0.5854146520575353,
#    'KL39': 0.6602983248255738,
#    'KL8': 0.6666666666666659,
#    'KL21': 0.7394041356865866,
#    'KL24': 0.8104974796418947,
#    'KL28': 0.6286225729028304}),
#  ('K48PH164C1__cds_49_A_3_306_628.pdb',
#   'Dpo_cdhit_261',
#   {'KL128': 0.5691666666666667}),
#  ('K25PH129C1__cds_60_A_5_311_671.pdb',
#   'Dpo_cdhit_487',
#   {'KL25': 0.5528836950744459}),
#  ('K39PH122C2__cds_55_A_5_286_658.pdb',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('K39PH122C2__cds_8_A_4_33_387.pdb',
#   'Dpo_cdhit_595',
#   {'KL3': 0.5111462002445865}),
#  ('K13PH07C1S__cds_10_A_7_32_375.pdb',
#   'Dpo_cdhit_595',
#   {'KL3': 0.5111462002445865}),
#  ('K61PH164C1__cds_9_A_1_1_387.pdb', 'Dpo_cdhit_513', {}),
#  ('K46PH129__cds_24_A_8_222_596.pdb',
#   'Dpo_cdhit_269',
#   {'KL122': 0.5139454859770997}),
#  ('K60PH164C1__cds_94_A_3_119_467.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K5lambda5__cds_196_A_4_457_808.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K43PH164C1__cds_41_A_3_32_385.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K57lambda1_2__cds_92_A_3_120_506.pdb',
#   'Dpo_cdhit_429',
#   {'KL57': 0.7383115816154295}),
#  ('K61PH164C1__cds_10_A_3_80_443.pdb',
#   'Dpo_cdhit_508',
#   {'KL151': 0.5987065085723603}),
#  ('K71PH129C1__cds_55_A_5_295_682.pdb',
#   'Dpo_cdhit_389',
#   {'KL45': 0.8817132302400281}),
#  ('K45PH128C2__cds_237_A_3_76_463.pdb',
#   'Dpo_cdhit_389',
#   {'KL45': 0.8817132302400281}),
#  ('K80PH1317b__cds_54_A_2_36_354.pdb', 'Dpo_cdhit_639', {}),
#  ('K80PH1317a__cds_54_A_2_36_354.pdb', 'Dpo_cdhit_639', {}),
#  ('K82P1__cds_46_A_2_94_449.pdb',
#   'Dpo_cdhit_488',
#   {'KL123': 0.711262670619547}),
#  ('K11PH164C1__cds_45_A_5_356_700.pdb',
#   'Dpo_cdhit_464',
#   {'KL70': 0.8763692612718952}),
#  ('K45PH128C2__cds_239_A_1_186_411.pdb',
#   'Dpo_cdhit_884',
#   {'KL63': 0.6385840866594714}),
#  ('K4PH164__cds_22_A_1_53_402.pdb', 'Dpo_cdhit_730', {}),
#  ('K53PH164C2__cds_24_A_4_200_777.pdb', 'Dpo_cdhit_58', {}),
#  ('K54lambda1_1_1__cds_238_A_1_78_646.pdb',
#   'Dpo_cdhit_120',
#   {'KL24': 0.7575537340839898}),
#  ('K57lambda1_2__cds_93_A_4_251_900.pdb', 'Dpo_cdhit_230', {}),
#  ('K58PH129C2__cds_47_A_2_38_516.pdb',
#   'Dpo_cdhit_188',
#   {'KL58': 0.9178571428571431}),
#  ('K16PH164C3__cds_48_A_3_292_776.pdb',
#   'Dpo_cdhit_231',
#   {'KL16': 0.6045823130299225}),
#  ('K17alfa61__cds_23_A_4_179_630.pdb', 'No hits', 'Null'),
#  ('K1PH164C1__cds_8_A_2_69_559.pdb', 'No hits', 'Null'),
#  ('K44PH129C1__cds_10_A_3_35_538.pdb',
#   'Dpo_cdhit_190',
#   {'KL142': 0.6557461069827379}),
#  ('K63PH128__cds_22_A_5_260_714.pdb',
#   'Dpo_cdhit_303',
#   {'KL63': 0.640730488637703}),
#  ('K5lambda5__cds_199_A_2_109_658.pdb', 'No hits', 'Null'),
#  ('K10PH82C1__cds_50_A_5_301_819.pdb', 'No hits', 'Null'),
#  ('K74PH129C2__cds_51_A_3_291_808.pdb', 'Dpo_cdhit_14', {}),
#  ('K26PH128C1__cds_49_A_3_291_808.pdb', 'Dpo_cdhit_14', {}),
#  ('K65PH164__cds_12_A_5_181_627.pdb', 'Dpo_cdhit_274', {}),
#  ('K6PH25C3__cds_23_A_3_206_691.pdb', 'Dpo_cdhit_198', {}),
#  ('K80PH1317a__cds_52_A_5_302_576.pdb', 'Dpo_cdhit_246', {}),
#  ('K80PH1317a__cds_53_A.pdb', 'Dpo_cdhit_14', {}),
#  ('K80PH1317b__cds_52_A_5_302_606.pdb', 'Dpo_cdhit_246', {}),
#  ('K2PH164C2__cds_24_A_6_274_608.pdb',
#   'Dpo_cdhit_625',
#   {'KL2': 0.615087090231654}),
#  ('K10PH82C1__cds_51_A_2_38_368.pdb', 'Dpo_cdhit_611', {}),
#  ('K13PH07C1S__cds_11_A_2_93_430.pdb', 'Dpo_cdhit_521', {}),
#  ('K37PH164C1__cds_48_A_2_37_367.pdb', 'Dpo_cdhit_521', {}),
#  ('K54lambda2__cds_23_A_7_214_582.pdb', 'No hits', 'Null'),
#  ('K5lambda5__cds_200_A_2_111_443.pdb', 'Dpo_cdhit_180', {}),
#  ('K80PH1317b__cds_53_A.pdb', 'Dpo_cdhit_14', {}),
#  ('K10PH82C1 cds_45', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K11PH164C1 cds_39', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K12P1_1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K13PH07C1L cds_54', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K13PH07C1S cds_53', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K15PH90 cds_49', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K16PH164C3 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K19PH14C4P1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K1PH164C1 cds_53', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K2069PH1 cds_25', 'No hits', 'Null'),
#  ('K22PH164C1 cds_50', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K24PH164C1 cds_55', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K25PH129C1 cds_56', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K26PH128C1 cds_44', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K27PH129C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K35PH164C3 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K37PH164C1 cds_41', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K39PH122C2 cds_50', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K40PH129C1 cds_52', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K42PH8 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K42PH8 cds_48', 'Dpo_cdhit_144', {}),
#  ('K43PH164C1 cds_35', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K44PH129C1 cds_45', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K48PH164C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K51PH129C1 cds_56', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K56PH164C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K58PH129C2 cds_40', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K59PH2 cds_46', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K61PH164C1 cds_52', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K66PH128C1 cds_55', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K71PH129C1 cds_51', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K72PH164C2 cds_51', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K74PH129C2 cds_46', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K80PH1317a cds_47', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K80PH1317b cds_47', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K82P1 cds_40', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K8PH128 cds_41', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K72PH164C2 cds_55', 'Dpo_cdhit_243', {}),
#  ('K33PH14C2 cds_55', 'No hits', 'Null'),
#  ('K33PH14C2 cds_25', 'No hits', 'Null'),
#  ('K31PH164 cds_25', 'No hits', 'Null'),
#  ('K52PH129C1 cds_25', 'No hits', 'Null'),
#  ('K69PH164C2 cds_24', 'No hits', 'Null'),
#  ('K28PH129 cds_24', 'No hits', 'Null'),
#  ('K2064PH2 cds_25', 'No hits', 'Null'),
#  ('K2069PH1 cds_25', 'No hits', 'Null'),
#  ('K19PH14C4P1 cds_48', 'No hits', 'Null'),
#  ('K50PH164C1 cds_28', 'No hits', 'Null'),
#  ('K29PH164C1 cds_25', 'No hits', 'Null'),
#  ('K62PH164C2 cds_25', 'No hits', 'Null'),
#  ('K9PH25C2 cds_76', 'Dpo_cdhit_775', {})]

# %% [markdown]
# > Beamud :

# %%
bea_winners = []

path_bea = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Bea"
path_domains_bea = f"{path_bea}/DepoScope_predictions.bea.domains.0709.fasta"

bea_dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_domains_bea}", "fasta") if len(record.seq) >0}
bea_set_records = [record for record in SeqIO.parse(f"{path_domains_bea}", "fasta") if len(record.seq) > 0]

for record in tqdm(bea_set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        results = dico_pred_correct_name.get(winner, {})
        a = (record.description.split(",")[0] , winner, results)
    else :
        results = "Null"
    a = (record.description.split(",")[0] , winner, results)
    bea_winners.append(a)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 71/71 [00:02<00:00, 24.93it/s]

# %% [markdown]
# > Towndsend :

# %%
towndsend_winners = []

path_towndsend = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Townsed"
path_domains_towndsend = f"{path_towndsend}/DepoScope_predictions.Townsed.domains.0909.fasta"

towndsend_dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_domains_towndsend}", "fasta") if len(record.seq) >0}
towndsend_set_records = [record for record in SeqIO.parse(f"{path_domains_towndsend}", "fasta") if len(record.seq) > 0]

for record in tqdm(towndsend_set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        results = dico_pred_correct_name.get(winner, {})
        a = (record.description.split(",")[0] , winner, results)
    else :
        results = "Null"
    a = (record.description.split(",")[0] , winner, results)
    towndsend_winners.append(a)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:01<00:00, 25.19it/s]

# %% [markdown]
# > Compile the results :

# %%
TropiSeq_results = ferriol_winners + towndsend_winners + bea_winners
TropiSeq_results
# Out:
# [('K10PH82C1__cds_49', 'No hits', 'Null'),
#  ('K13PH07C1L__cds_10', 'Dpo_cdhit_595', {'KL3': 0.5111462002445865}),
#  ('K13PH07C1L__cds_11', 'Dpo_cdhit_62', {'KL13': 0.5272369948063018}),
#  ('K13PH07C1L__cds_12', 'Dpo_cdhit_965', {}),
#  ('K15PH90__cds_54', 'No hits', 'Null'),
#  ('K18PH07C1__cds_243',
#   'Dpo_cdhit_626',
#   {'KL18': 0.9807930607187114, 'KL30': 0.6486357443284311}),
#  ('K18PH07C1__cds_245', 'Dpo_cdhit_379', {'KL63': 0.5936651240242289}),
#  ('K22PH164C1__cds_11', 'No hits', 'Null'),
#  ('K30lambda2_2__cds_152', 'No hits', 'Null'),
#  ('K30lambda2_2__cds_20', 'No hits', 'Null'),
#  ('K32PH164C1__cds_151', 'No hits', 'Null'),
#  ('K32PH164C1__cds_20', 'No hits', 'Null'),
#  ('K34PH164__cds_24', 'No hits', 'Null'),
#  ('K41P2__cds_227', 'No hits', 'Null'),
#  ('K49PH164C2__cds_24', 'No hits', 'Null'),
#  ('K65PH164__cds_198', 'No hits', 'Null'),
#  ('K70PH128C1__cds_24', 'No hits', 'Null'),
#  ('K7PH164C4__cds_151', 'No hits', 'Null'),
#  ('K7PH164C4__cds_20', 'No hits', 'Null'),
#  ('K17alfa62__cds_66_A_281-682', 'Dpo_cdhit_88', {}),
#  ('K14PH164C1__cds_24_A_4_221_871.pdb',
#   'Dpo_cdhit_92',
#   {'KL64': 0.6702590696691522}),
#  ('K64PH164C4__cds_24_A_4_178_852.pdb',
#   'Dpo_cdhit_56',
#   {'KL64': 0.9037259998449553}),
#  ('K40PH129C1__cds_56_A_4_239_860.pdb', 'No hits', 'Null'),
#  ('K51PH129C1__cds_9_A_1_92_787.pdb',
#   'Dpo_cdhit_47',
#   {'KL51': 0.9638243750057931}),
#  ('K15PH90__cds_55_A.pdb', 'Dpo_cdhit_182', {'KL15': 0.7938890377524203}),
#  ('K21lambda1__cds_28_A.pdb',
#   'Dpo_cdhit_336',
#   {'KL124': 0.971440129449838,
#    'KL30': 0.5189505945976137,
#    'KL35': 0.5646087718181372,
#    'KL21': 0.6221563070094778,
#    'KL31': 0.5061118161152754}),
#  ('K26PH128C1__cds_50_A_1_97_595.pdb', 'Dpo_cdhit_87', {}),
#  ('K35PH164C3__cds_48_A_4_282_728.pdb',
#   'Dpo_cdhit_352',
#   {'KL35': 0.6604321098363282}),
#  ('K37PH164C1__cds_47_A_1_1_307.pdb', 'Dpo_cdhit_599', {}),
#  ('K38PH09C2__cds_24_A_4_178_672.pdb', 'Dpo_cdhit_76', {}),
#  ('K27PH129C1__cds_48_A_7_200_648.pdb',
#   'Dpo_cdhit_268',
#   {'KL27': 0.5951705100493837}),
#  ('K5lambda5__cds_198_A_3_173_674.pdb',
#   'Dpo_cdhit_104',
#   {'KL123': 0.5058610644918217}),
#  ('K41P2__cds_11_A_7_188_506.pdb', 'Dpo_cdhit_274', {}),
#  ('K43PH164C1__cds_40_A_3_296_718.pdb', 'Dpo_cdhit_311', {}),
#  ('K11PH164C1__cds_46_A_1_1_416.pdb',
#   'Dpo_cdhit_429',
#   {'KL57': 0.7383115816154295}),
#  ('K17alfa62__cds_64_A_3_129_548.pdb',
#   'Dpo_cdhit_362',
#   {'KL17': 0.5912942222004937}),
#  ('K2PH164C1__cds_23_A_6_269_664.pdb', 'No hits', 'Null'),
#  ('K2alfa62__cds_23_A_6_269_671.pdb', 'No hits', 'Null'),
#  ('K56PH164C1__cds_48_A_5_293_702.pdb', 'No hits', 'Null'),
#  ('K82P1__cds_45_A_5_292_704.pdb', 'No hits', 'Null'),
#  ('K66PH128C1__cds_59_A_4_252_713.pdb',
#   'Dpo_cdhit_284',
#   {'KL66': 0.6575342465753424}),
#  ('K23PH08C2__cds_233_A_2_76_514.pdb', 'Dpo_cdhit_235', {}),
#  ('K60PH164C1__cds_96_A_6_321_703.pdb', 'Dpo_cdhit_9', {}),
#  ('K56PH164C1__cds_49_A_3_110_475.pdb',
#   'Dpo_cdhit_295',
#   {'KL56': 0.61171317292349}),
#  ('K74PH129C2__cds_52_A_2_34_431.pdb', 'Dpo_cdhit_391', {}),
#  ('K8PH128__cds_46_A_5_294_719.pdb', 'No hits', 'Null'),
#  ('K44PH129C1__cds_9_A_2_39_391.pdb', 'Dpo_cdhit_599', {}),
#  ('K22PH164C1__cds_10_A_1_1_368.pdb', 'Dpo_cdhit_599', {}),
#  ('K24PH164C1__cds_8_A_2_85_402.pdb',
#   'Dpo_cdhit_71',
#   {'KL112': 0.7797781306684983,
#    'KL48': 0.5854146520575353,
#    'KL39': 0.6602983248255738,
#    'KL8': 0.6666666666666659,
#    'KL21': 0.7394041356865866,
#    'KL24': 0.8104974796418947,
#    'KL28': 0.6286225729028304}),
#  ('K48PH164C1__cds_49_A_3_306_628.pdb',
#   'Dpo_cdhit_261',
#   {'KL128': 0.5691666666666667}),
#  ('K25PH129C1__cds_60_A_5_311_671.pdb',
#   'Dpo_cdhit_487',
#   {'KL25': 0.5528836950744459}),
#  ('K39PH122C2__cds_55_A_5_286_658.pdb',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('K39PH122C2__cds_8_A_4_33_387.pdb',
#   'Dpo_cdhit_595',
#   {'KL3': 0.5111462002445865}),
#  ('K13PH07C1S__cds_10_A_7_32_375.pdb',
#   'Dpo_cdhit_595',
#   {'KL3': 0.5111462002445865}),
#  ('K61PH164C1__cds_9_A_1_1_387.pdb', 'Dpo_cdhit_513', {}),
#  ('K46PH129__cds_24_A_8_222_596.pdb',
#   'Dpo_cdhit_269',
#   {'KL122': 0.5139454859770997}),
#  ('K60PH164C1__cds_94_A_3_119_467.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K5lambda5__cds_196_A_4_457_808.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K43PH164C1__cds_41_A_3_32_385.pdb',
#   'Dpo_cdhit_528',
#   {'KL18': 0.9950433705080544}),
#  ('K57lambda1_2__cds_92_A_3_120_506.pdb',
#   'Dpo_cdhit_429',
#   {'KL57': 0.7383115816154295}),
#  ('K61PH164C1__cds_10_A_3_80_443.pdb',
#   'Dpo_cdhit_508',
#   {'KL151': 0.5987065085723603}),
#  ('K71PH129C1__cds_55_A_5_295_682.pdb',
#   'Dpo_cdhit_389',
#   {'KL45': 0.8817132302400281}),
#  ('K45PH128C2__cds_237_A_3_76_463.pdb',
#   'Dpo_cdhit_389',
#   {'KL45': 0.8817132302400281}),
#  ('K80PH1317b__cds_54_A_2_36_354.pdb', 'Dpo_cdhit_639', {}),
#  ('K80PH1317a__cds_54_A_2_36_354.pdb', 'Dpo_cdhit_639', {}),
#  ('K82P1__cds_46_A_2_94_449.pdb',
#   'Dpo_cdhit_488',
#   {'KL123': 0.711262670619547}),
#  ('K11PH164C1__cds_45_A_5_356_700.pdb',
#   'Dpo_cdhit_464',
#   {'KL70': 0.8763692612718952}),
#  ('K45PH128C2__cds_239_A_1_186_411.pdb',
#   'Dpo_cdhit_884',
#   {'KL63': 0.6385840866594714}),
#  ('K4PH164__cds_22_A_1_53_402.pdb', 'Dpo_cdhit_730', {}),
#  ('K53PH164C2__cds_24_A_4_200_777.pdb', 'Dpo_cdhit_58', {}),
#  ('K54lambda1_1_1__cds_238_A_1_78_646.pdb',
#   'Dpo_cdhit_120',
#   {'KL24': 0.7575537340839898}),
#  ('K57lambda1_2__cds_93_A_4_251_900.pdb', 'Dpo_cdhit_230', {}),
#  ('K58PH129C2__cds_47_A_2_38_516.pdb',
#   'Dpo_cdhit_188',
#   {'KL58': 0.9178571428571431}),
#  ('K16PH164C3__cds_48_A_3_292_776.pdb',
#   'Dpo_cdhit_231',
#   {'KL16': 0.6045823130299225}),
#  ('K17alfa61__cds_23_A_4_179_630.pdb', 'No hits', 'Null'),
#  ('K1PH164C1__cds_8_A_2_69_559.pdb', 'No hits', 'Null'),
#  ('K44PH129C1__cds_10_A_3_35_538.pdb',
#   'Dpo_cdhit_190',
#   {'KL142': 0.6557461069827379}),
#  ('K63PH128__cds_22_A_5_260_714.pdb',
#   'Dpo_cdhit_303',
#   {'KL63': 0.640730488637703}),
#  ('K5lambda5__cds_199_A_2_109_658.pdb', 'No hits', 'Null'),
#  ('K10PH82C1__cds_50_A_5_301_819.pdb', 'No hits', 'Null'),
#  ('K74PH129C2__cds_51_A_3_291_808.pdb', 'Dpo_cdhit_14', {}),
#  ('K26PH128C1__cds_49_A_3_291_808.pdb', 'Dpo_cdhit_14', {}),
#  ('K65PH164__cds_12_A_5_181_627.pdb', 'Dpo_cdhit_274', {}),
#  ('K6PH25C3__cds_23_A_3_206_691.pdb', 'Dpo_cdhit_198', {}),
#  ('K80PH1317a__cds_52_A_5_302_576.pdb', 'Dpo_cdhit_246', {}),
#  ('K80PH1317a__cds_53_A.pdb', 'Dpo_cdhit_14', {}),
#  ('K80PH1317b__cds_52_A_5_302_606.pdb', 'Dpo_cdhit_246', {}),
#  ('K2PH164C2__cds_24_A_6_274_608.pdb',
#   'Dpo_cdhit_625',
#   {'KL2': 0.615087090231654}),
#  ('K10PH82C1__cds_51_A_2_38_368.pdb', 'Dpo_cdhit_611', {}),
#  ('K13PH07C1S__cds_11_A_2_93_430.pdb', 'Dpo_cdhit_521', {}),
#  ('K37PH164C1__cds_48_A_2_37_367.pdb', 'Dpo_cdhit_521', {}),
#  ('K54lambda2__cds_23_A_7_214_582.pdb', 'No hits', 'Null'),
#  ('K5lambda5__cds_200_A_2_111_443.pdb', 'Dpo_cdhit_180', {}),
#  ('K80PH1317b__cds_53_A.pdb', 'Dpo_cdhit_14', {}),
#  ('K10PH82C1 cds_45', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K11PH164C1 cds_39', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K12P1_1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K13PH07C1L cds_54', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K13PH07C1S cds_53', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K15PH90 cds_49', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K16PH164C3 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K19PH14C4P1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K1PH164C1 cds_53', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K2069PH1 cds_25', 'No hits', 'Null'),
#  ('K22PH164C1 cds_50', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K24PH164C1 cds_55', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K25PH129C1 cds_56', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K26PH128C1 cds_44', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K27PH129C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K35PH164C3 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K37PH164C1 cds_41', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K39PH122C2 cds_50', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K40PH129C1 cds_52', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K42PH8 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K42PH8 cds_48', 'Dpo_cdhit_144', {}),
#  ('K43PH164C1 cds_35', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K44PH129C1 cds_45', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K48PH164C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K51PH129C1 cds_56', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K56PH164C1 cds_43', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K58PH129C2 cds_40', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K59PH2 cds_46', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K61PH164C1 cds_52', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K66PH128C1 cds_55', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K71PH129C1 cds_51', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K72PH164C2 cds_51', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K74PH129C2 cds_46', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K80PH1317a cds_47', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K80PH1317b cds_47', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K82P1 cds_40', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K8PH128 cds_41', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('K72PH164C2 cds_55', 'Dpo_cdhit_243', {}),
#  ('K33PH14C2 cds_55', 'No hits', 'Null'),
#  ('K33PH14C2 cds_25', 'No hits', 'Null'),
#  ('K31PH164 cds_25', 'No hits', 'Null'),
#  ('K52PH129C1 cds_25', 'No hits', 'Null'),
#  ('K69PH164C2 cds_24', 'No hits', 'Null'),
#  ('K28PH129 cds_24', 'No hits', 'Null'),
#  ('K2064PH2 cds_25', 'No hits', 'Null'),
#  ('K2069PH1 cds_25', 'No hits', 'Null'),
#  ('K19PH14C4P1 cds_48', 'No hits', 'Null'),
#  ('K50PH164C1 cds_28', 'No hits', 'Null'),
#  ('K29PH164C1 cds_25', 'No hits', 'Null'),
#  ('K62PH164C2 cds_25', 'No hits', 'Null'),
#  ('K9PH25C2 cds_76', 'Dpo_cdhit_775', {}),
#  ('EHPPICDA_00095', 'Dpo_cdhit_274', {}),
#  ('DIMCIIMF_00039', 'No hits', 'Null'),
#  ('DIMCIIMF_00240', 'Dpo_cdhit_274', {}),
#  ('OBHDAGOG_00029', 'No hits', 'Null'),
#  ('LCALLHIG_00050',
#   'Dpo_cdhit_319',
#   {'KL3': 0.6739129447959293, 'KL35': 0.7363276113935945}),
#  ('HIIECEMK_00043', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('HIIECEMK_00054', 'Dpo_cdhit_62', {'KL13': 0.5272369948063018}),
#  ('GCLPFEGH_00240', 'Dpo_cdhit_274', {}),
#  ('IPGJFKPH_00198', 'Dpo_cdhit_274', {}),
#  ('POFPNCPI_00246', 'Dpo_cdhit_274', {}),
#  ('INMBNBLA_00138', 'Dpo_cdhit_274', {}),
#  ('INMBNBLA_00202', 'No hits', 'Null'),
#  ('OPBIHMGG_00067',
#   'Dpo_cdhit_319',
#   {'KL3': 0.6739129447959293, 'KL35': 0.7363276113935945}),
#  ('BLCJPOBP_00041', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('FADJDIKG_00019', 'No hits', 'Null'),
#  ('FADJDIKG_00083', 'Dpo_cdhit_274', {}),
#  ('PP187_gp225', 'Dpo_cdhit_232', {'KL38': 0.7384566517167761}),
#  ('PP187_gp227', 'Dpo_cdhit_355', {'KL45': 0.8990798269795062}),
#  ('PP187_gp230', 'Dpo_cdhit_764', {'KL110': 0.720824906058316}),
#  ('PP187_gp233',
#   'Dpo_cdhit_652',
#   {'KL66': 0.689041095890411, 'KL74': 0.6920250246510266}),
#  ('PP187_gp235', 'Dpo_cdhit_611', {}),
#  ('PP187_gp237', 'Dpo_cdhit_272', {}),
#  ('PP187_gp239', 'Dpo_cdhit_231', {'KL16': 0.6045823130299225}),
#  ('KBDEFBCI_00052', 'Dpo_cdhit_352', {'KL35': 0.6604321098363282}),
#  ('KBDEFBCI_00054',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('KBDEFBCI_00056',
#   'Dpo_cdhit_179',
#   {'KL37': 0.8983974358974358, 'KL145': 0.9328125}),
#  ('KBDEFBCI_00058',
#   'Dpo_cdhit_413',
#   {'KL18': 0.5219950433705082, 'KL46': 0.9370992998759905}),
#  ('LLOFRUDD_00039', 'No hits', 'Null'),
#  ('DJLANJJD_00238', 'Dpo_cdhit_274', {}),
#  ('NEBGPKAL_00001', 'No hits', 'Null'),
#  ('NEBGPKAL_00013', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('EKPIEFBL_00113', 'No hits', 'Null'),
#  ('EKPIEFBL_00177', 'Dpo_cdhit_274', {}),
#  ('EONHMLJF_00087', 'No hits', 'Null'),
#  ('NJHLHPIG_00055', 'Dpo_cdhit_352', {'KL35': 0.6604321098363282}),
#  ('NJHLHPIG_00057',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('NJHLHPIG_00059', 'No hits', 'Null'),
#  ('NJHLHPIG_00061',
#   'Dpo_cdhit_413',
#   {'KL18': 0.5219950433705082, 'KL46': 0.9370992998759905}),
#  ('PFOEGONH_00078',
#   'Dpo_cdhit_319',
#   {'KL3': 0.6739129447959293, 'KL35': 0.7363276113935945}),
#  ('NBNDMPCG_00161', 'Dpo_cdhit_352', {'KL35': 0.6604321098363282}),
#  ('NBNDMPCG_00163', 'Dpo_cdhit_589', {'KL2': 0.684466679921928}),
#  ('NBNDMPCG_00165', 'No hits', 'Null'),
#  ('NBNDMPCG_00166', 'Dpo_cdhit_53', {'KL14': 0.950674383458824}),
#  ('NBNDMPCG_00168', 'Dpo_cdhit_375', {'KL31': 0.5295531150085585}),
#  ('S13c_00055', 'Dpo_cdhit_106', {}),
#  ('S10a_00097',
#   'Dpo_cdhit_406',
#   {'KL25': 0.9041884457352335, 'KL111': 0.5271036491844302}),
#  ('A1o_00041', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1o_00045',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('A1c_00034', 'No hits', 'Null'),
#  ('A1c_00046', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1d_00009', 'Dpo_cdhit_213', {}),
#  ('A1d_00013', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1q_00010',
#   'Dpo_cdhit_676',
#   {'KL70': 0.8878475811944775, 'KL21': 0.6739516818124685}),
#  ('A1q_00019',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('A1q_00023', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1r_00009',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('A1r_00013', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('P4a_00011', 'Dpo_cdhit_635', {}),
#  ('P4a_00013', 'Dpo_cdhit_306', {'KL122': 0.5651624495950403}),
#  ('A1f_00012',
#   'Dpo_cdhit_71',
#   {'KL112': 0.7797781306684983,
#    'KL48': 0.5854146520575353,
#    'KL39': 0.6602983248255738,
#    'KL8': 0.6666666666666659,
#    'KL21': 0.7394041356865866,
#    'KL24': 0.8104974796418947,
#    'KL28': 0.6286225729028304}),
#  ('A1f_00024', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1g_00045', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1g_00057', 'No hits', 'Null'),
#  ('A3b_00016', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A3b_00021', 'Dpo_cdhit_594', {'KL30': 0.7092306788157682}),
#  ('A1j_00002', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1j_00040', 'Dpo_cdhit_31', {}),
#  ('A1j_00049', 'Dpo_cdhit_82', {}),
#  ('A2a_00010', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A2a_00049', 'Dpo_cdhit_31', {}),
#  ('A1m_00045', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1m_00049',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('D7b_00043', 'Dpo_cdhit_547', {}),
#  ('A1n_00050', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1p_00055', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A3d_00036', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A3d_00041', 'Dpo_cdhit_43', {}),
#  ('A3d_00042', 'Dpo_cdhit_513', {}),
#  ('S13a_00036', 'Dpo_cdhit_441', {}),
#  ('A3c_00039', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A3c_00044', 'Dpo_cdhit_464', {'KL70': 0.8763692612718952}),
#  ('A3c_00045', 'Dpo_cdhit_513', {}),
#  ('A1l_00005', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1l_00058', 'Dpo_cdhit_954', {}),
#  ('A3a_00002', 'Dpo_cdhit_38', {}),
#  ('A3a_00045', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A2b_00008', 'Dpo_cdhit_31', {}),
#  ('A2b_00022', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('M5a_00170', 'Dpo_cdhit_286', {}),
#  ('M5a_00175', 'No hits', 'Null'),
#  ('A1b_00036', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1b_00048', 'Dpo_cdhit_61', {}),
#  ('A1e_00012',
#   'Dpo_cdhit_71',
#   {'KL112': 0.7797781306684983,
#    'KL48': 0.5854146520575353,
#    'KL39': 0.6602983248255738,
#    'KL8': 0.6666666666666659,
#    'KL21': 0.7394041356865866,
#    'KL24': 0.8104974796418947,
#    'KL28': 0.6286225729028304}),
#  ('A1e_00024', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('S11a_00036',
#   'Dpo_cdhit_406',
#   {'KL25': 0.9041884457352335, 'KL111': 0.5271036491844302}),
#  ('A1a_00002', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1a_00014', 'Dpo_cdhit_508', {'KL151': 0.5987065085723603}),
#  ('P4b_00023', 'Dpo_cdhit_306', {'KL122': 0.5651624495950403}),
#  ('P4b_00025', 'Dpo_cdhit_635', {}),
#  ('S13e_00021',
#   'Dpo_cdhit_297',
#   {'KL25': 0.8377605813541803, 'KL136': 0.5298351541291048}),
#  ('S13d_00057', 'Dpo_cdhit_53', {'KL14': 0.950674383458824}),
#  ('A1h_00009', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1h_00013', 'Dpo_cdhit_501', {'KL48': 0.5675088102903976}),
#  ('A1h_00021', 'Dpo_cdhit_586', {'KL2': 0.6751802370622282}),
#  ('A1k_00014',
#   'Dpo_cdhit_421',
#   {'KL110': 0.7253609541459549,
#    'KL37': 0.8910256410256411,
#    'KL106': 0.5033422025727726,
#    'KL22': 0.6990102639296187}),
#  ('A1k_00018', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('D7c_00007', 'Dpo_cdhit_73', {}),
#  ('S13b_00058', 'Dpo_cdhit_303', {'KL63': 0.640730488637703}),
#  ('M5b_00086', 'Dpo_cdhit_479', {'KL5': 0.5954865425236477}),
#  ('M12a_00031', 'Dpo_cdhit_468', {'KL139': 0.813986013986014}),
#  ('A2a_b_00022', 'Dpo_cdhit_31', {}),
#  ('A2a_b_00036', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1i_00037', 'Dpo_cdhit_762', {'KL102': 0.736972444555183}),
#  ('A1i_00041', 'Dpo_cdhit_501', {'KL48': 0.5675088102903976}),
#  ('A1i_00049', 'Dpo_cdhit_31', {})]

# %%
with open("/media/concha-eloko/Linux/PPT_clean/Seqbased_model.results.bit75.2406.tsv" , "w") as outfile :
    for prot in TropiSeq_results :
        prot_name = prot[0].split("_A")[0]
        if prot[1] == "No hits" :
            outfile.write(f"{prot_name}\tNo_hits\n")
        elif prot[2] == {} :
            outfile.write(f"{prot_name}\tNo_associations\n")
        else :
            try :
                hits = [f"{kltype}:{round(score,3)}" for kltype, score in prot[2].items()]
                outfile.write(f"{prot_name}\t")
                outfile.write(" ; ".join(hits))
                outfile.write("\n")
            except Exception as e :
                print(prot, e)

# %% [markdown]
# ***
# ### Predictions :

# %%
predictions_Seqbased_df = pd.read_csv("/media/concha-eloko/Linux/PPT_clean/Seqbased_model.results.bit75.2406.tsv", sep = "\t", names = ["protein", "predicitons"])
predictions_Seqbased_df
# Out:
#                 protein      predicitons
# 0     K10PH82C1__cds_49          No_hits
# 1    K13PH07C1L__cds_10        KL3:0.511
# 2    K13PH07C1L__cds_11       KL13:0.527
# 3    K13PH07C1L__cds_12  No_associations
# 4       K15PH90__cds_54          No_hits
# ..                  ...              ...
# 255         A2a_b_00022  No_associations
# 256         A2a_b_00036      KL102:0.737
# 257           A1i_00037      KL102:0.737
# 258           A1i_00041       KL48:0.568
# 259           A1i_00049  No_associations
#
# [260 rows x 2 columns]
