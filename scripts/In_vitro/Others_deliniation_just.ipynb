# %%
import nglview as nv
import os
import numpy as np
import tqdm
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
def view_pdb(file) : 
    view = nv.show_structure_file(file , ext="pdb" , gui=False)
    #view.add_label("position")
    #view.add_label("res")
    return view

n = 0

# %%
path_project = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd/others_esmfold"

for i, file in enumerate(os.listdir(path_project)) :
    if i == n and file != "Others_2nd.multi.fasta":
        view.close()
        view = view_pdb(f"{path_project}/{file}")
        #view.render_image(trim=True)
        print(file)
        n += 1 
        break
view
# Out:
# NGLWidget(n_components=1)

# %%
view.close()

# %%
path_project = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd"

from Bio import SeqIO
import pandas as pd 
from tqdm import tqdm

delim_dpo = pd.read_csv(f"{path_project}/Dpos_deliniations.tsv", sep = "\t", names = ["Dpo", "Boundaries"]).fillna("None")

# %%
delim_dpo
# Out:
#                                   Dpo Boundaries
# 0   ON881905.1_prot_UTN90143.1_15.pdb    450-881
# 1   MZ571827.1_prot_UEW68150.1_60.pdb    260-542
# 2   MT197176.1_prot_QJI52623.1_49.pdb    311-649
# 3   OM032871.1_prot_UKL59188.1_41.pdb    294-593
# 4   MZ571832.1_prot_UEP19667.1_22.pdb    293-577
# 5   MZ612130.1_prot_QYC51043.1_10.pdb    187-523
# 6   MZ322895.1_prot_QWY13631.1_35.pdb    107-628
# 7   ON146449.1_prot_UPW35150.1_13.pdb    301-585
# 8    MZ571833.1_prot_UEW68243.1_1.pdb    285-582
# 9   MT197175.1_prot_QIW86428.1_58.pdb     74-589
# 10  MZ571827.1_prot_UEW68146.1_56.pdb    328-649
# 11  MT197175.1_prot_QIW86415.1_45.pdb    294-576
# 12  MZ571831.1_prot_UEW68236.1_80.pdb    246-707
# 13  MT197175.1_prot_QIW86419.1_49.pdb    313-643
# 14   ON146449.1_prot_UPW35138.1_1.pdb    121-412
# 15  MZ571832.1_prot_UEP19662.1_17.pdb    316-787
# 16  MT197176.1_prot_QJI52618.1_44.pdb    294-514
# 17  MT197176.1_prot_QJI52632.1_58.pdb    123-416
# 18   MZ571834.1_prot_UEP19705.1_4.pdb    294-585

# %%
#with open(f"{path_project}/Others_2nd.dpos_domains.multi.fasta", "w") as outfile : 
    for index,multi_faa in tqdm(enumerate(os.listdir(path_project))) :
        if multi_faa.count("Klebsiella_phage") > 0 : 
            fastas = SeqIO.parse(f"{path_project}/{multi_faa}" , "fasta")
            for index_seq, record in enumerate(fastas) :
                name = record.description.split("|")[1].split(" [")[0]
                if f"{name}.pdb" in delim_dpo["Dpo"].tolist() : 
                    protein_seq = str(record.seq)
                    if delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0] != "None" : 
                        start = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[0])
                        end = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[1])
                        #name = name.replace("_","")
                        #name = name.replace(".","")
                        #print(name)
                        outfile.write(f">{index}__{index_seq}\n{record.seq[start:end]}\n")
                        #outfile.write(f">{name}__{str(start)}_{str(end)}\n{record.seq[start:end]}\n")
                        print(index ,index_seq , name, sep = "\t")
# Out:
# 16it [00:00, 29.50it/s]
# 1	34	MZ322895.1_prot_QWY13631.1_35
# 2	0	ON146449.1_prot_UPW35138.1_1
# 2	12	ON146449.1_prot_UPW35150.1_13
# 3	79	MZ571831.1_prot_UEW68236.1_80
# 4	9	MZ612130.1_prot_QYC51043.1_10
# 5	44	MT197175.1_prot_QIW86415.1_45
# 5	48	MT197175.1_prot_QIW86419.1_49
# 5	57	MT197175.1_prot_QIW86428.1_58
# 7	16	MZ571832.1_prot_UEP19662.1_17
# 7	21	MZ571832.1_prot_UEP19667.1_22
# 8	3	MZ571834.1_prot_UEP19705.1_4
# 9	14	ON881905.1_prot_UTN90143.1_15
# 10	43	MT197176.1_prot_QJI52618.1_44
# 10	48	MT197176.1_prot_QJI52623.1_49
# 10	57	MT197176.1_prot_QJI52632.1_58
# 13	55	MZ571827.1_prot_UEW68146.1_56
# 13	59	MZ571827.1_prot_UEW68150.1_60
# 14	40	OM032871.1_prot_UKL59188.1_41
# 15	0	MZ571833.1_prot_UEW68243.1_1

# %%
path_project = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd"
from Bio import SeqIO
import pandas as pd 
from tqdm import tqdm

with open(f"{path_project}/Others_2nd.dpos_domains.clean_name.multi.fasta", "w") as outfile : 
    for index,multi_faa in tqdm(enumerate(os.listdir(path_project))) :
        if multi_faa.count("Klebsiella_phage") > 0 : 
            fastas = SeqIO.parse(f"{path_project}/{multi_faa}" , "fasta")
            for index_seq, record in enumerate(fastas) :
                name = record.description.split("|")[1].split(" [")[0]
                if f"{name}.pdb" in delim_dpo["Dpo"].tolist() : 
                    protein_seq = str(record.seq)
                    if delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0] != "None" : 
                        start = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[0])
                        end = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[1])
                        #name = name.replace("_","")
                        #name = name.replace(".","")
                        #print(name)
                        outfile.write(f">{name}\n{record.seq[start:end]}\n")
                        #outfile.write(f">{name}__{str(start)}_{str(end)}\n{record.seq[start:end]}\n")
                        print(index ,index_seq , name, sep = "\t")
# Out:
# 18it [00:00, 392.14it/s]
# 1	34	MZ322895.1_prot_QWY13631.1_35
# 2	0	ON146449.1_prot_UPW35138.1_1
# 2	12	ON146449.1_prot_UPW35150.1_13
# 3	79	MZ571831.1_prot_UEW68236.1_80
# 4	9	MZ612130.1_prot_QYC51043.1_10
# 5	44	MT197175.1_prot_QIW86415.1_45
# 5	48	MT197175.1_prot_QIW86419.1_49
# 5	57	MT197175.1_prot_QIW86428.1_58
# 7	16	MZ571832.1_prot_UEP19662.1_17
# 7	21	MZ571832.1_prot_UEP19667.1_22
# 8	3	MZ571834.1_prot_UEP19705.1_4
# 9	14	ON881905.1_prot_UTN90143.1_15
# 10	43	MT197176.1_prot_QJI52618.1_44
# 10	48	MT197176.1_prot_QJI52623.1_49
# 10	57	MT197176.1_prot_QJI52632.1_58
# 13	55	MZ571827.1_prot_UEW68146.1_56
# 13	59	MZ571827.1_prot_UEW68150.1_60
# 15	40	OM032871.1_prot_UKL59188.1_41
# 17	0	MZ571833.1_prot_UEW68243.1_1

# %%
path_project_ori = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Others"

from Bio import SeqIO
import pandas as pd 
from tqdm import tqdm

delim_dpo = pd.read_csv(f"{path_project_ori}/Dpos_deliniations.tsv", sep = "\t", names = ["Dpo", "Boundaries"]).fillna("None")

#with open(f"{path_project}/Others_2nd.dpos_domains.clean_name.multi.fasta", "a+") as outfile : 
    for index,multi_faa in tqdm(enumerate(os.listdir(path_project_ori))) :
        if multi_faa.count("sequence") > 0 : 
            fastas = SeqIO.parse(f"{path_project_ori}/{multi_faa}" , "fasta")
            for index_seq, record in enumerate(fastas) :
                name = record.description.split("|")[1].split(" [")[0]
                if f"{name}.pdb" in delim_dpo["Dpo"].tolist() : 
                    protein_seq = str(record.seq)
                    if delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0] != "None" : 
                        start = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[0])
                        end = int(delim_dpo[delim_dpo['Dpo'] == f"{name}.pdb"]["Boundaries"].values[0].split("-")[1])
                        #name = name.replace("_","")
                        #name = name.replace(".","")
                        #print(name)
                        outfile.write(f">{name}\n{record.seq[start:end]}\n")
                        #outfile.write(f">{name}__{str(start)}_{str(end)}\n{record.seq[start:end]}\n")
                        print(index ,index_seq , name, sep = "\t")
# Out:
# 38it [00:00, 79.31it/s]
# 1	49	NC_029099.1_prot_YP_009226011.1_50
# 3	1	MW655991.1_prot_QUU29414.1_2
# 5	54	AB897757.1_prot_BAQ02835.1_55
# 5	55	AB897757.1_prot_BAQ02836.1_56
# 5	56	AB897757.1_prot_BAQ02837.1_57
# 5	57	AB897757.1_prot_BAQ02838.1_58
# 5	58	AB897757.1_prot_BAQ02839.1_59
# 5	59	AB897757.1_prot_BAQ02840.1_60
# 5	60	AB897757.1_prot_BAQ02841.1_61
# 5	61	AB897757.1_prot_BAQ02842.1_62
# 5	62	AB897757.1_prot_BAQ02843.1_63
# 5	63	AB897757.1_prot_BAQ02844.1_64
# 6	23	AB716666.1_prot_BAP15736.1_24
# 6	33	AB716666.1_prot_BAP15746.1_34
# 8	56	NC_013649.2_prot_YP_003347651.1_57
# 9	31	MH844531.1_prot_AYP28213.1_32
# 12	36	MT966873.1_prot_QOV05496.1_37
# 12	41	MT966873.1_prot_QOV05501.1_42
# 12	42	MT966873.1_prot_QOV05502.1_43
# 17	23	NC_025418.1_prot_YP_009098375.1_24
# 17	33	NC_025418.1_prot_YP_009098385.1_34
# 22	261	MN781108.1_prot_QGZ15323.1_262
# 25	0	ON146449.1_prot_UPW35138.1_1
# 25	12	ON146449.1_prot_UPW35150.1_13
# 28	37	MT966872.1_prot_QOV05454.1_38
# 31	36	MK903728.1_prot_QDF14639.1_37
# 31	41	MK903728.1_prot_QDF14644.1_42
# 31	42	MK903728.1_prot_QDF14645.1_43
# 32	40	NC_031246.1_prot_YP_009302745.1_41
# 32	51	NC_031246.1_prot_YP_009302756.1_52
# 33	261	MN781108.1_prot_QGZ15323.1_262
# 35	37	MT542697.1_prot_QKY78347.1_38
# 35	43	MT542697.1_prot_QKY78353.1_44
# 37	29	MZ826764.1_prot_UCR74082.1_30
# 37	30	MZ826764.1_prot_UCR74083.1_31
# 37	31	MZ826764.1_prot_UCR74084.1_32
# 37	32	MZ826764.1_prot_UCR74085.1_33

# %%
rsync -avzhe ssh \
/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd/Others_2nd.dpos_domains.multi.fasta \
conchae@garnatxa.srv.cpd:/home/conchae/PhageDepo_pdb/

rsync -avzhe ssh \
conchae@garnatxa.srv.cpd:/home/conchae/PhageDepo_pdb/Others_2nd.dpos_domains.multi.fasta.esm2_out \
/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd

# %%
import torch
import os 
import pandas as pd
from tqdm import tqdm 


path_esm = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd/Others_2nd.dpos_domains.multi.fasta.esm2_out"

embeddings_esm = {}
for file in tqdm(os.listdir(path_esm)) :
    path_file = f"{path_esm}/{file}"
    index = file.split(".")[0]
    embb = torch.load(f"{path_file}")["mean_representations"][33].tolist()
    embeddings_esm[index] = embb
    
with open(f"/media/concha-eloko/Linux/PPT_clean/in_vitro/Others_2nd_phages.esm2.embedding.csv" , "w") as outfile :
    for index in tqdm(embeddings_esm) :
        outfile.write(f"{index},")
        for _,  emb in enumerate(embeddings_esm[index]) :
            outfile.write(f"{emb},")
        outfile.write("\n")
# Out:
# 100%|██████████████████████████████████████████| 19/19 [00:00<00:00, 210.63it/s]
# 100%|██████████████████████████████████████████| 19/19 [00:00<00:00, 449.08it/s]

# %%
import pandas as pd 
import os 

path_project = "/media/concha-eloko/Linux/PPT_clean/in_vitro"

others_embeddings_2nd = pd.read_csv(f"{path_project_org}/Others_2nd_phages.esm2.embedding.csv", sep = "," , header = None)
others_embeddings_2nd = others_embeddings_2nd.drop([1281] , axis = 1)
others_embeddings_2nd.set_index([0], inplace = True)

namesother_df = pd.read_csv(f"{path_project_org}/Others_2nd/index_others_2nd.tsv", sep = "\t" , names = ["index_phage", "index_prot","prot_name"])
new_index = []
for _,index in enumerate(others_embeddings_2nd.index) : 
    i_phage = int(index.split("__")[0])
    i_prot = int(index.split("__")[1])
    prot = namesother_df[(namesother_df["index_phage"] == i_phage) & (namesother_df["index_prot"] == i_prot)]["prot_name"].values[0]
    new_index.append(prot)

others_embeddings_2nd.index = new_index
others_embeddings_2nd.index.name = 0
others_embeddings_2nd
# Out:
#                                    1         2         3         4     \
# 0
# MT197175.1_prot_QIW86419.1_49 -0.033249  0.026863  0.010394 -0.033757
# MZ571827.1_prot_UEW68150.1_60  0.043389 -0.007390 -0.034529  0.051915
# MZ571832.1_prot_UEP19667.1_22  0.014661 -0.044640 -0.053037  0.071892
# MZ571834.1_prot_UEP19705.1_4   0.029913  0.067052 -0.002139 -0.025809
# MT197176.1_prot_QJI52618.1_44  0.046949  0.087361 -0.057974  0.001274
# MZ571831.1_prot_UEW68236.1_80 -0.017715  0.086784 -0.010990 -0.005939
# MT197175.1_prot_QIW86415.1_45  0.040717 -0.008238 -0.037205  0.056451
# OM032871.1_prot_UKL59188.1_41  0.028851  0.069197  0.001080 -0.023892
# MZ571827.1_prot_UEW68146.1_56 -0.034261  0.043210  0.023713 -0.028201
# MT197176.1_prot_QJI52623.1_49 -0.036599  0.029752  0.009905 -0.034136
# MT197175.1_prot_QIW86428.1_58  0.040710  0.055237  0.000931  0.003272
# MZ612130.1_prot_QYC51043.1_10  0.045586 -0.002096  0.002647  0.046595
# MZ571833.1_prot_UEW68243.1_1   0.032345  0.066284  0.001712 -0.026046
# MZ322895.1_prot_QWY13631.1_35  0.047149  0.004595 -0.011110  0.030222
# ON881905.1_prot_UTN90143.1_15  0.018305  0.061533  0.011808  0.050097
# ON146449.1_prot_UPW35150.1_13  0.043269 -0.008411 -0.038078  0.059760
# MT197176.1_prot_QJI52632.1_58 -0.003627  0.043421  0.015114 -0.031604
# MZ571832.1_prot_UEP19662.1_17 -0.026156  0.080093 -0.036442 -0.006496
# ON146449.1_prot_UPW35138.1_1   0.000010  0.049588  0.012179 -0.031572
#
#                                    5         6         7         8     \
# 0
# MT197175.1_prot_QIW86419.1_49 -0.093022  0.054646  0.024560 -0.064399
# MZ571827.1_prot_UEW68150.1_60 -0.130973  0.043155  0.101923 -0.160135
# MZ571832.1_prot_UEP19667.1_22 -0.147953  0.067988  0.094800 -0.173666
# MZ571834.1_prot_UEP19705.1_4  -0.092178  0.025355 -0.010188 -0.039549
# MT197176.1_prot_QJI52618.1_44 -0.181722  0.025292  0.042239 -0.088773
# MZ571831.1_prot_UEW68236.1_80 -0.071466  0.001489  0.041878 -0.059489
# MT197175.1_prot_QIW86415.1_45 -0.127842  0.043286  0.102273 -0.161604
# OM032871.1_prot_UKL59188.1_41 -0.098651  0.022939 -0.005762 -0.044870
# MZ571827.1_prot_UEW68146.1_56 -0.101086  0.050770  0.033849 -0.064932
# MT197176.1_prot_QJI52623.1_49 -0.088646  0.047161  0.022850 -0.062773
# MT197175.1_prot_QIW86428.1_58 -0.101929  0.001587 -0.000791 -0.048953
# MZ612130.1_prot_QYC51043.1_10 -0.106307  0.026082 -0.049319 -0.062165
# MZ571833.1_prot_UEW68243.1_1  -0.098403  0.022650 -0.002405 -0.047448
# MZ322895.1_prot_QWY13631.1_35 -0.141884  0.027425 -0.035282 -0.054255
# ON881905.1_prot_UTN90143.1_15 -0.117094  0.012289  0.039459 -0.081906
# ON146449.1_prot_UPW35150.1_13 -0.131160  0.044487  0.097687 -0.164412
# MT197176.1_prot_QJI52632.1_58 -0.077613  0.042725  0.004765 -0.063763
# MZ571832.1_prot_UEP19662.1_17 -0.076456  0.025128  0.047048 -0.068732
# ON146449.1_prot_UPW35138.1_1  -0.071096  0.049582  0.001430 -0.053605
#
#                                    9         10    ...      1271      1272  \
# 0                                                  ...
# MT197175.1_prot_QIW86419.1_49  0.111696  0.050051  ... -0.057186 -0.004799
# MZ571827.1_prot_UEW68150.1_60  0.078240 -0.005301  ...  0.014161  0.013286
# MZ571832.1_prot_UEP19667.1_22  0.009079  0.000337  ...  0.018109 -0.029525
# MZ571834.1_prot_UEP19705.1_4   0.091135  0.012864  ...  0.013414  0.044044
# MT197176.1_prot_QJI52618.1_44  0.021864  0.061506  ...  0.005887 -0.048361
# MZ571831.1_prot_UEW68236.1_80  0.091258  0.019424  ... -0.012343  0.042995
# MT197175.1_prot_QIW86415.1_45  0.076069 -0.000572  ...  0.016458  0.010754
# OM032871.1_prot_UKL59188.1_41  0.089229  0.011988  ...  0.012758  0.037059
# MZ571827.1_prot_UEW68146.1_56  0.133813  0.063935  ... -0.052790  0.010226
# MT197176.1_prot_QJI52623.1_49  0.108355  0.051912  ... -0.048856  0.000875
# MT197175.1_prot_QIW86428.1_58  0.072100  0.025886  ... -0.019633  0.003449
# MZ612130.1_prot_QYC51043.1_10 -0.014154  0.004740  ...  0.085795 -0.022514
# MZ571833.1_prot_UEW68243.1_1   0.094154  0.012069  ...  0.012069  0.040671
# MZ322895.1_prot_QWY13631.1_35 -0.013765 -0.003897  ...  0.105854 -0.022709
# ON881905.1_prot_UTN90143.1_15  0.048843  0.024318  ... -0.060689 -0.066389
# ON146449.1_prot_UPW35150.1_13  0.069129  0.002166  ...  0.016819  0.006759
# MT197176.1_prot_QJI52632.1_58  0.104855  0.079185  ... -0.015502  0.051878
# MZ571832.1_prot_UEP19662.1_17  0.058766  0.063797  ... -0.010090  0.015377
# ON146449.1_prot_UPW35138.1_1   0.099370  0.073080  ... -0.008183  0.054838
#
#                                    1273      1274      1275      1276  \
# 0
# MT197175.1_prot_QIW86419.1_49  0.136267 -0.012018  0.045904  0.047881
# MZ571827.1_prot_UEW68150.1_60  0.026911  0.026157 -0.032077 -0.023531
# MZ571832.1_prot_UEP19667.1_22  0.020592  0.008301 -0.063031 -0.022550
# MZ571834.1_prot_UEP19705.1_4   0.122627  0.001984  0.045130  0.067727
# MT197176.1_prot_QJI52618.1_44 -0.054927  0.014885 -0.049263  0.042138
# MZ571831.1_prot_UEW68236.1_80  0.125249 -0.014235  0.014578  0.049386
# MT197175.1_prot_QIW86415.1_45  0.027688  0.026783 -0.035670 -0.025949
# OM032871.1_prot_UKL59188.1_41  0.118540  0.000565  0.043218  0.067885
# MZ571827.1_prot_UEW68146.1_56  0.149530  0.009012  0.045962  0.036526
# MT197176.1_prot_QJI52623.1_49  0.139184 -0.005325  0.039940  0.042835
# MT197175.1_prot_QIW86428.1_58  0.091227  0.004856  0.080526  0.026635
# MZ612130.1_prot_QYC51043.1_10  0.041192  0.038308 -0.009500  0.017472
# MZ571833.1_prot_UEW68243.1_1   0.116256 -0.000308  0.041966  0.065532
# MZ322895.1_prot_QWY13631.1_35  0.046782  0.076867 -0.018171  0.021287
# ON881905.1_prot_UTN90143.1_15  0.064901  0.088301  0.093789 -0.006236
# ON146449.1_prot_UPW35150.1_13  0.029460  0.028801 -0.040706 -0.024662
# MT197176.1_prot_QJI52632.1_58  0.116515 -0.010273  0.014627 -0.010115
# MZ571832.1_prot_UEP19662.1_17  0.107386  0.007904  0.022271  0.057286
# ON146449.1_prot_UPW35138.1_1   0.114030 -0.010772  0.014575 -0.005518
#
#                                    1277      1278      1279      1280
# 0
# MT197175.1_prot_QIW86419.1_49  0.022797 -0.095218  0.083700  0.116344
# MZ571827.1_prot_UEW68150.1_60  0.029702 -0.040739 -0.121798  0.118590
# MZ571832.1_prot_UEP19667.1_22  0.034509 -0.073832 -0.131599  0.145214
# MZ571834.1_prot_UEP19705.1_4   0.035083 -0.060426  0.076030  0.071484
# MT197176.1_prot_QJI52618.1_44 -0.023730 -0.098956 -0.123862  0.191002
# MZ571831.1_prot_UEW68236.1_80  0.037316 -0.066434  0.050055  0.052106
# MT197175.1_prot_QIW86415.1_45  0.029619 -0.045053 -0.123670  0.123515
# OM032871.1_prot_UKL59188.1_41  0.040106 -0.064819  0.078508  0.065129
# MZ571827.1_prot_UEW68146.1_56  0.026841 -0.083453  0.074505  0.111717
# MT197176.1_prot_QJI52623.1_49  0.028825 -0.098021  0.077210  0.123902
# MT197175.1_prot_QIW86428.1_58  0.031044 -0.095110  0.081206  0.076159
# MZ612130.1_prot_QYC51043.1_10  0.098157 -0.053887 -0.046206 -0.013304
# MZ571833.1_prot_UEW68243.1_1   0.039256 -0.066988  0.077117  0.070087
# MZ322895.1_prot_QWY13631.1_35  0.133053 -0.046846 -0.022763  0.014701
# ON881905.1_prot_UTN90143.1_15  0.053823 -0.108959  0.026813  0.109766
# ON146449.1_prot_UPW35150.1_13  0.036979 -0.039539 -0.120556  0.122151
# MT197176.1_prot_QJI52632.1_58  0.022284 -0.078725  0.064553  0.090045
# MZ571832.1_prot_UEP19662.1_17  0.015095 -0.081128  0.050535  0.036232
# ON146449.1_prot_UPW35138.1_1   0.015372 -0.085300  0.064876  0.103000
#
# [19 rows x 1280 columns]

# %%
import pandas as pd 
import os 

path_project_org = "/media/concha-eloko/Linux/PPT_clean/in_vitro"

others_embeddings = pd.read_csv(f"{path_project_org}/Others_phages.esm2.embedding.csv", sep = "," , header = None)
others_embeddings = others_embeddings.drop([1281] , axis = 1)
others_embeddings.set_index([0], inplace = True)

namesother_df = pd.read_csv(f"{path_project_org}/Others/index_others.tsv", sep = "\t" , names = ["index_phage", "index_prot","prot_name"])
new_index = []
for _,index in enumerate(others_embeddings.index) : 
    i_phage = int(index.split("__")[0])
    i_prot = int(index.split("__")[1])
    prot = namesother_df[(namesother_df["index_phage"] == i_phage) & (namesother_df["index_prot"] == i_prot)]["prot_name"].values[0]
    new_index.append(prot)

others_embeddings.index = new_index
others_embeddings.index.name = 0
# Out:
#                                         1         2         3         4     \
# 0
# NC_025418.1_prot_YP_009098385.1_34 -0.034347  0.023348  0.015016 -0.027898
# NC_029099.1_prot_YP_009226011.1_50  0.018297  0.040493 -0.013773 -0.007963
# MT966873.1_prot_QOV05502.1_43       0.018386  0.014588  0.021574 -0.000521
# NC_013649.2_prot_YP_003347651.1_57  0.010830  0.031390 -0.007675 -0.040679
# AB716666.1_prot_BAP15736.1_24       0.043144 -0.009100 -0.034960  0.056230
# MK903728.1_prot_QDF14645.1_43       0.023176  0.010373  0.012069 -0.008828
# NC_031246.1_prot_YP_009302756.1_52 -0.030381  0.025787  0.009855 -0.031848
# MZ826764.1_prot_UCR74083.1_31       0.018840  0.072161  0.013396  0.003150
# MW655991.1_prot_QUU29414.1_2        0.045209  0.080681 -0.008443 -0.019103
# AB897757.1_prot_BAQ02839.1_59       0.007837  0.031753  0.011143  0.005219
# NC_031246.1_prot_YP_009302745.1_41  0.040717 -0.008238 -0.037205  0.056451
# AB897757.1_prot_BAQ02841.1_61       0.009266  0.013210  0.052653  0.032842
# MZ826764.1_prot_UCR74085.1_33      -0.020196  0.068626  0.000043 -0.010544
# NC_025418.1_prot_YP_009098375.1_24  0.043144 -0.009100 -0.034960  0.056230
# AB897757.1_prot_BAQ02844.1_64       0.079360  0.031016  0.014658  0.115919
# MK903728.1_prot_QDF14639.1_37       0.013214 -0.045561 -0.053702  0.070956
# AB897757.1_prot_BAQ02843.1_63       0.021494  0.060552  0.042212 -0.000790
# AB897757.1_prot_BAQ02838.1_58       0.034489  0.033818  0.010828  0.013758
# MT542697.1_prot_QKY78353.1_44       0.005638  0.032907 -0.009253 -0.002631
# MZ826764.1_prot_UCR74084.1_32       0.017781  0.028073  0.026244 -0.020003
# ON146449.1_prot_UPW35150.1_13       0.043269 -0.008411 -0.038078  0.059760
# MK903728.1_prot_QDF14644.1_42      -0.005461  0.020703  0.057163 -0.005838
# AB716666.1_prot_BAP15746.1_34      -0.031407  0.026753  0.017837 -0.026201
# MT542697.1_prot_QKY78347.1_38       0.034544 -0.046080 -0.055836  0.073083
# MZ826764.1_prot_UCR74082.1_30      -0.008956  0.030103  0.014972 -0.056160
# MT966873.1_prot_QOV05496.1_37       0.010038 -0.045685 -0.055653  0.061844
# MN781108.1_prot_QGZ15323.1_262      0.075526  0.005296  0.003018  0.016921
# AB897757.1_prot_BAQ02840.1_60       0.042001  0.060603  0.015210  0.004516
# AB897757.1_prot_BAQ02837.1_57       0.040355  0.029805  0.023218  0.007629
# AB897757.1_prot_BAQ02836.1_56       0.003524  0.067293  0.033314 -0.056280
# ON146449.1_prot_UPW35138.1_1       -0.004009  0.040560 -0.009493 -0.032283
# MH844531.1_prot_AYP28213.1_32       0.046916  0.088159 -0.000934 -0.024904
# AB897757.1_prot_BAQ02842.1_62       0.061863  0.040416  0.011293  0.035747
# MT966873.1_prot_QOV05501.1_42       0.005117  0.039319  0.045960 -0.049692
# AB897757.1_prot_BAQ02835.1_55       0.040158  0.082303  0.010390  0.017956
# MN781108.1_prot_QGZ15323.1_262      0.075526  0.005296  0.003018  0.016921
# MT966872.1_prot_QOV05454.1_38       0.004876  0.031148 -0.013354 -0.002409
#
#                                         5         6         7         8     \
# 0
# NC_025418.1_prot_YP_009098385.1_34 -0.080356  0.076239  0.042055 -0.095709
# NC_029099.1_prot_YP_009226011.1_50 -0.070584  0.001886  0.004620 -0.087347
# MT966873.1_prot_QOV05502.1_43      -0.077781  0.012065  0.005141 -0.071457
# NC_013649.2_prot_YP_003347651.1_57 -0.057371 -0.005628  0.003471 -0.094184
# AB716666.1_prot_BAP15736.1_24      -0.123851  0.046627  0.097184 -0.159881
# MK903728.1_prot_QDF14645.1_43      -0.075488  0.001540 -0.002295 -0.066814
# NC_031246.1_prot_YP_009302756.1_52 -0.084225  0.081263  0.045987 -0.102523
# MZ826764.1_prot_UCR74083.1_31      -0.151668  0.041043 -0.018544 -0.054340
# MW655991.1_prot_QUU29414.1_2       -0.084513  0.013202  0.013670 -0.036699
# AB897757.1_prot_BAQ02839.1_59      -0.135794 -0.005367  0.051008 -0.084133
# NC_031246.1_prot_YP_009302745.1_41 -0.127842  0.043286  0.102273 -0.161604
# AB897757.1_prot_BAQ02841.1_61      -0.073092  0.001006  0.035704 -0.092368
# MZ826764.1_prot_UCR74085.1_33      -0.072097 -0.003332  0.028940 -0.059818
# NC_025418.1_prot_YP_009098375.1_24 -0.123851  0.046627  0.097184 -0.159881
# AB897757.1_prot_BAQ02844.1_64      -0.030464 -0.003755 -0.006830 -0.133903
# MK903728.1_prot_QDF14639.1_37      -0.147845  0.070613  0.095552 -0.174561
# AB897757.1_prot_BAQ02843.1_63      -0.087214  0.016225  0.041814 -0.043861
# AB897757.1_prot_BAQ02838.1_58      -0.106102 -0.018346  0.041958 -0.096304
# MT542697.1_prot_QKY78353.1_44      -0.124217  0.050476  0.005117 -0.087175
# MZ826764.1_prot_UCR74084.1_32      -0.112649  0.031763  0.017928 -0.080234
# ON146449.1_prot_UPW35150.1_13      -0.131160  0.044487  0.097687 -0.164412
# MK903728.1_prot_QDF14644.1_42      -0.095309  0.021323  0.030988 -0.123428
# AB716666.1_prot_BAP15746.1_34      -0.082220  0.083563  0.045304 -0.102287
# MT542697.1_prot_QKY78347.1_38      -0.124336  0.072437  0.069198 -0.180649
# MZ826764.1_prot_UCR74082.1_30      -0.101801  0.001211  0.012941 -0.025982
# MT966873.1_prot_QOV05496.1_37      -0.148701  0.068566  0.094844 -0.170316
# MN781108.1_prot_QGZ15323.1_262     -0.138177  0.029308 -0.038393 -0.026633
# AB897757.1_prot_BAQ02840.1_60      -0.126533 -0.006245 -0.003104 -0.056456
# AB897757.1_prot_BAQ02837.1_57      -0.106563 -0.004749 -0.022488 -0.049845
# AB897757.1_prot_BAQ02836.1_56      -0.098291 -0.040574  0.046276 -0.048550
# ON146449.1_prot_UPW35138.1_1       -0.068221  0.051710 -0.007763 -0.074648
# MH844531.1_prot_AYP28213.1_32      -0.084585  0.008202  0.021155 -0.042258
# AB897757.1_prot_BAQ02842.1_62      -0.111623  0.001388 -0.015636 -0.081375
# MT966873.1_prot_QOV05501.1_42      -0.082495  0.029364  0.041278 -0.084913
# AB897757.1_prot_BAQ02835.1_55      -0.120206 -0.011988  0.006180 -0.035205
# MN781108.1_prot_QGZ15323.1_262     -0.138177  0.029308 -0.038393 -0.026633
# MT966872.1_prot_QOV05454.1_38      -0.119367  0.046396  0.006891 -0.092373
#
#                                         9         10    ...      1271  \
# 0                                                       ...
# NC_025418.1_prot_YP_009098385.1_34  0.035269  0.006119  ...  0.023533
# NC_029099.1_prot_YP_009226011.1_50  0.072146  0.076061  ...  0.042868
# MT966873.1_prot_QOV05502.1_43       0.089763  0.041767  ...  0.035410
# NC_013649.2_prot_YP_003347651.1_57  0.047946  0.046877  ...  0.026264
# AB716666.1_prot_BAP15736.1_24       0.081871 -0.003064  ...  0.016950
# MK903728.1_prot_QDF14645.1_43       0.086006  0.042304  ...  0.036544
# NC_031246.1_prot_YP_009302756.1_52  0.044074 -0.001147  ...  0.022237
# MZ826764.1_prot_UCR74083.1_31       0.067439 -0.004516  ...  0.064134
# MW655991.1_prot_QUU29414.1_2        0.083001  0.002771  ...  0.014410
# AB897757.1_prot_BAQ02839.1_59       0.082686  0.038012  ... -0.024925
# NC_031246.1_prot_YP_009302745.1_41  0.076069 -0.000572  ...  0.016458
# AB897757.1_prot_BAQ02841.1_61       0.052244  0.042147  ...  0.035455
# MZ826764.1_prot_UCR74085.1_33       0.101578  0.026309  ... -0.000873
# NC_025418.1_prot_YP_009098375.1_24  0.081871 -0.003064  ...  0.016950
# AB897757.1_prot_BAQ02844.1_64       0.109182  0.159639  ... -0.019348
# MK903728.1_prot_QDF14639.1_37       0.010007  0.000019  ...  0.015247
# AB897757.1_prot_BAQ02843.1_63       0.105973  0.033453  ... -0.000400
# AB897757.1_prot_BAQ02838.1_58       0.075949  0.062023  ...  0.026522
# MT542697.1_prot_QKY78353.1_44       0.086316  0.016957  ...  0.037034
# MZ826764.1_prot_UCR74084.1_32       0.087605  0.055504  ... -0.001092
# ON146449.1_prot_UPW35150.1_13       0.069129  0.002166  ...  0.016819
# MK903728.1_prot_QDF14644.1_42       0.070946  0.031657  ... -0.007632
# AB716666.1_prot_BAP15746.1_34       0.049809  0.002161  ...  0.021038
# MT542697.1_prot_QKY78347.1_38      -0.005928 -0.025151  ...  0.053477
# MZ826764.1_prot_UCR74082.1_30       0.082134  0.023740  ...  0.031291
# MT966873.1_prot_QOV05496.1_37       0.010496 -0.002088  ...  0.015311
# MN781108.1_prot_QGZ15323.1_262      0.023276 -0.034873  ...  0.083656
# AB897757.1_prot_BAQ02840.1_60       0.067686  0.115826  ...  0.010106
# AB897757.1_prot_BAQ02837.1_57       0.052512  0.089622  ...  0.037222
# AB897757.1_prot_BAQ02836.1_56       0.058977  0.024144  ... -0.002060
# ON146449.1_prot_UPW35138.1_1        0.101359  0.088092  ... -0.027223
# MH844531.1_prot_AYP28213.1_32       0.086313 -0.003137  ...  0.010022
# AB897757.1_prot_BAQ02842.1_62       0.051759  0.054687  ...  0.081951
# MT966873.1_prot_QOV05501.1_42       0.085718  0.030862  ... -0.028929
# AB897757.1_prot_BAQ02835.1_55       0.049503  0.023413  ...  0.045844
# MN781108.1_prot_QGZ15323.1_262      0.023276 -0.034873  ...  0.083656
# MT966872.1_prot_QOV05454.1_38       0.089383  0.016398  ...  0.035253
#
#                                         1272      1273      1274      1275  \
# 0
# NC_025418.1_prot_YP_009098385.1_34  0.001364  0.077270  0.012855 -0.008513
# NC_029099.1_prot_YP_009226011.1_50  0.037848  0.101484  0.018096  0.002869
# MT966873.1_prot_QOV05502.1_43       0.030719  0.098420  0.033683  0.009985
# NC_013649.2_prot_YP_003347651.1_57  0.039920  0.113341 -0.002912 -0.004148
# AB716666.1_prot_BAP15736.1_24       0.018673  0.025980  0.035958 -0.037824
# MK903728.1_prot_QDF14645.1_43       0.030662  0.093922  0.021278  0.010939
# NC_031246.1_prot_YP_009302756.1_52  0.001937  0.088900  0.011215 -0.007063
# MZ826764.1_prot_UCR74083.1_31       0.003406  0.102453  0.042068  0.029047
# MW655991.1_prot_QUU29414.1_2        0.026337  0.090563  0.009828  0.017021
# AB897757.1_prot_BAQ02839.1_59      -0.000377  0.122477 -0.009581  0.022313
# NC_031246.1_prot_YP_009302745.1_41  0.010754  0.027688  0.026783 -0.035670
# AB897757.1_prot_BAQ02841.1_61      -0.002290  0.073294  0.004407 -0.000843
# MZ826764.1_prot_UCR74085.1_33       0.050426  0.126536  0.001422  0.011928
# NC_025418.1_prot_YP_009098375.1_24  0.018673  0.025980  0.035958 -0.037824
# AB897757.1_prot_BAQ02844.1_64      -0.012088  0.082351  0.135257  0.063793
# MK903728.1_prot_QDF14639.1_37      -0.029432  0.022013  0.006170 -0.064464
# AB897757.1_prot_BAQ02843.1_63       0.043519  0.130052  0.014267  0.040805
# AB897757.1_prot_BAQ02838.1_58       0.034232  0.093871  0.008529  0.003339
# MT542697.1_prot_QKY78353.1_44       0.045331  0.116791  0.019137  0.014348
# MZ826764.1_prot_UCR74084.1_32      -0.018095  0.112872 -0.010277  0.033922
# ON146449.1_prot_UPW35150.1_13       0.006759  0.029460  0.028801 -0.040706
# MK903728.1_prot_QDF14644.1_42       0.005851  0.107518 -0.025672  0.008477
# AB716666.1_prot_BAP15746.1_34       0.002641  0.086882  0.014666 -0.010382
# MT542697.1_prot_QKY78347.1_38      -0.009578  0.047745  0.029489 -0.053843
# MZ826764.1_prot_UCR74082.1_30       0.009982  0.100496  0.009298  0.041968
# MT966873.1_prot_QOV05496.1_37      -0.028762  0.015380  0.008959 -0.060235
# MN781108.1_prot_QGZ15323.1_262      0.014456  0.000577  0.052962 -0.006660
# AB897757.1_prot_BAQ02840.1_60      -0.010087  0.070596  0.053746  0.028963
# AB897757.1_prot_BAQ02837.1_57       0.014527  0.082434  0.013484  0.024743
# AB897757.1_prot_BAQ02836.1_56       0.002952  0.100321  0.022874  0.047691
# ON146449.1_prot_UPW35138.1_1        0.053323  0.110350 -0.037578  0.031047
# MH844531.1_prot_AYP28213.1_32       0.024396  0.086830  0.007554  0.017371
# AB897757.1_prot_BAQ02842.1_62       0.057802  0.095059  0.037103  0.002583
# MT966873.1_prot_QOV05501.1_42       0.023174  0.097044  0.004069  0.019102
# AB897757.1_prot_BAQ02835.1_55       0.011976  0.120322  0.043367  0.027047
# MN781108.1_prot_QGZ15323.1_262      0.014456  0.000577  0.052962 -0.006660
# MT966872.1_prot_QOV05454.1_38       0.046843  0.114251  0.013400  0.013367
#
#                                         1276      1277      1278      1279  \
# 0
# NC_025418.1_prot_YP_009098385.1_34  0.072102  0.049917 -0.085625  0.019097
# NC_029099.1_prot_YP_009226011.1_50  0.033552  0.075552 -0.083361  0.025799
# MT966873.1_prot_QOV05502.1_43       0.013877  0.034163 -0.059480  0.022797
# NC_013649.2_prot_YP_003347651.1_57  0.048235  0.084940 -0.083238  0.019559
# AB716666.1_prot_BAP15736.1_24      -0.027213  0.028701 -0.037570 -0.121534
# MK903728.1_prot_QDF14645.1_43       0.000706  0.029708 -0.062703  0.016923
# NC_031246.1_prot_YP_009302756.1_52  0.085473  0.050315 -0.074520  0.029399
# MZ826764.1_prot_UCR74083.1_31       0.136823  0.026999 -0.069048  0.046625
# MW655991.1_prot_QUU29414.1_2        0.070165  0.015899 -0.063195  0.028067
# AB897757.1_prot_BAQ02839.1_59       0.009437  0.052586 -0.090701  0.051707
# NC_031246.1_prot_YP_009302745.1_41 -0.025949  0.029619 -0.045053 -0.123670
# AB897757.1_prot_BAQ02841.1_61       0.037144  0.054781 -0.065878  0.022081
# MZ826764.1_prot_UCR74085.1_33       0.056178  0.020921 -0.055779  0.052412
# NC_025418.1_prot_YP_009098375.1_24 -0.027213  0.028701 -0.037570 -0.121534
# AB897757.1_prot_BAQ02844.1_64      -0.171437  0.102750 -0.025872 -0.026624
# MK903728.1_prot_QDF14639.1_37      -0.022824  0.034020 -0.076426 -0.131710
# AB897757.1_prot_BAQ02843.1_63       0.048787  0.035522 -0.065459  0.015130
# AB897757.1_prot_BAQ02838.1_58       0.024400  0.078224 -0.041067  0.041382
# MT542697.1_prot_QKY78353.1_44       0.017754  0.048126 -0.077419  0.056451
# MZ826764.1_prot_UCR74084.1_32       0.037954  0.027255 -0.097426  0.066609
# ON146449.1_prot_UPW35150.1_13      -0.024662  0.036979 -0.039539 -0.120556
# MK903728.1_prot_QDF14644.1_42       0.071746  0.002071 -0.055910  0.008732
# AB716666.1_prot_BAP15746.1_34       0.075594  0.047802 -0.077742  0.025106
# MT542697.1_prot_QKY78347.1_38      -0.001101  0.018999 -0.110031 -0.166978
# MZ826764.1_prot_UCR74082.1_30       0.071623  0.013591 -0.099541  0.083210
# MT966873.1_prot_QOV05496.1_37      -0.023665  0.033313 -0.075716 -0.129769
# MN781108.1_prot_QGZ15323.1_262      0.051752  0.093374 -0.017811 -0.034449
# AB897757.1_prot_BAQ02840.1_60      -0.001893  0.068673 -0.045444  0.029797
# AB897757.1_prot_BAQ02837.1_57       0.027976  0.023474 -0.071483  0.085756
# AB897757.1_prot_BAQ02836.1_56       0.087515  0.028447 -0.114587  0.057867
# ON146449.1_prot_UPW35138.1_1        0.016435  0.013005 -0.100817  0.053510
# MH844531.1_prot_AYP28213.1_32       0.072482  0.020957 -0.055659  0.032450
# AB897757.1_prot_BAQ02842.1_62       0.016320  0.073799 -0.060336  0.047441
# MT966873.1_prot_QOV05501.1_42       0.051053  0.027288 -0.088399  0.017080
# AB897757.1_prot_BAQ02835.1_55       0.127120  0.021330 -0.098096  0.047646
# MN781108.1_prot_QGZ15323.1_262      0.051752  0.093374 -0.017811 -0.034449
# MT966872.1_prot_QOV05454.1_38       0.020971  0.043485 -0.080452  0.060625
#
#                                         1280
# 0
# NC_025418.1_prot_YP_009098385.1_34  0.094144
# NC_029099.1_prot_YP_009226011.1_50  0.028155
# MT966873.1_prot_QOV05502.1_43       0.041875
# NC_013649.2_prot_YP_003347651.1_57  0.044707
# AB716666.1_prot_BAP15736.1_24       0.118953
# MK903728.1_prot_QDF14645.1_43       0.052734
# NC_031246.1_prot_YP_009302756.1_52  0.106660
# MZ826764.1_prot_UCR74083.1_31       0.030168
# MW655991.1_prot_QUU29414.1_2        0.061598
# AB897757.1_prot_BAQ02839.1_59       0.076879
# NC_031246.1_prot_YP_009302745.1_41  0.123515
# AB897757.1_prot_BAQ02841.1_61       0.055743
# MZ826764.1_prot_UCR74085.1_33       0.060466
# NC_025418.1_prot_YP_009098375.1_24  0.118953
# AB897757.1_prot_BAQ02844.1_64       0.058659
# MK903728.1_prot_QDF14639.1_37       0.146586
# AB897757.1_prot_BAQ02843.1_63       0.062971
# AB897757.1_prot_BAQ02838.1_58      -0.002340
# MT542697.1_prot_QKY78353.1_44       0.033582
# MZ826764.1_prot_UCR74084.1_32       0.090717
# ON146449.1_prot_UPW35150.1_13       0.122151
# MK903728.1_prot_QDF14644.1_42       0.090330
# AB716666.1_prot_BAP15746.1_34       0.101700
# MT542697.1_prot_QKY78347.1_38       0.182224
# MZ826764.1_prot_UCR74082.1_30       0.053183
# MT966873.1_prot_QOV05496.1_37       0.146845
# MN781108.1_prot_QGZ15323.1_262      0.014116
# AB897757.1_prot_BAQ02840.1_60       0.016311
# AB897757.1_prot_BAQ02837.1_57       0.066270
# AB897757.1_prot_BAQ02836.1_56       0.067300
# ON146449.1_prot_UPW35138.1_1        0.089199
# MH844531.1_prot_AYP28213.1_32       0.064742
# AB897757.1_prot_BAQ02842.1_62      -0.000688
# MT966873.1_prot_QOV05501.1_42       0.081144
# AB897757.1_prot_BAQ02835.1_55      -0.004337
# MN781108.1_prot_QGZ15323.1_262      0.014116
# MT966872.1_prot_QOV05454.1_38       0.039005
#
# [37 rows x 1280 columns]

# %%
others_full_df = pd.concat([others_embeddings , others_embeddings_2nd], axis = 0)

# %%
others_full_df.to_csv(f"{path_project_org}/Others_all.esm2.embedding.csv", sep = "," , header = None)
