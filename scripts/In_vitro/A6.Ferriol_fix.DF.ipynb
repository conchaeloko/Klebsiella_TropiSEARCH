# %%
# Ground modules
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from itertools import product
import random
from collections import Counter
import warnings
import logging
from multiprocessing.pool import ThreadPool

# %%
HR = {'K10PH82C1': ['K10'],
 'K11PH164C1': ['K11', 'K57'],
 'K12P1_1': ['K12', 'K28', 'K69'],
 'K13PH07C1L': ['K13'],
 'K13PH07C1S': ['K13'],
 'K14PH164C1': ['K14'],
 'K15PH90': ['K15'],
 'K16PH164C3': ['K16'],
 'K17alfa61': ['K17'],
 'K17alfa62': ['K17', 'K62'],
 'K18PH07C1': ['K18'],
 'K19PH14C4P1': ['K11', 'K19', 'K28', 'K69'],
 'K1PH164C1': ['K1'],
 'K1lambda5': ['K1', 'K54'],
 'K2064PH2': ['K11', 'K14', 'K20', 'K27', 'K28', 'K33', 'K35', 'K60', 'K62', 'K63', 'K64', 'K69', 'K70', 'K74'],
 'K2069PH1': ['K20', 'K27', 'K28', 'K33', 'K35', 'K62', 'K64', 'K69', 'K70'],
 'K2069PH2': ['K20', 'K62', 'K64', 'K69', 'K70', 'K72'],
 'K21lambda1': ['K21'],
 'K22PH164C1': ['K22', 'K37'],
 'K23PH08C2': ['K23', 'K54', 'K58'],
 'K24PH164C1': ['K24'],
 'K25PH129C1': ['K25'],
 'K26PH128C1': ['K26', 'K74'],
 'K27PH129C1': ['K27'],
 'K28PH129': ['K28', 'K69'],
 'K29PH164C1': ['K24', 'K29', 'K62', 'K69', 'K79'],
 'K2PH164C1': ['K2'],
 'K2PH164C2': ['K2'],
 'K2alfa62': ['K2'],
 'K30lambda2_2': ['K7', 'K11', 'K13', 'K14', 'K21', 'K26', 'K29', 'K30', 'K31', 'K32', 'K35', 'K36', 'K47', 'K56', 'K64', 'K65', 'K67', 'K68'],
 'K31PH164': ['K31', 'K37'],
 'K32PH164C1': ['K32', 'K56'],
 'K33PH14C2': ['K11', 'K28', 'K33'],
 'K34PH164': ['K11', 'K34', 'K49', 'K60', 'K64', 'K68', 'K69'],
 'K35PH164C3': ['K30', 'K35', 'K36'],
 'K36PH128C2B': ['K30', 'K36', 'K59'],
 'K37PH164C1': ['K2', 'K37'],
 'K38PH09C2': ['K38'],
 'K39PH122C2': ['K36', 'K39'],
 'K3PH164': ['K2', 'K3'],
 'K40PH129C1': ['K40'],
 'K41P2': ['K39', 'K41'],
 'K42PH8': ['K36', 'K42'],
 'K43PH164C1': ['K36', 'K43'],
 'K44PH129C1': ['K37', 'K44'],
 'K45PH128C2': ['K45', 'K71'],
 'K46PH129': ['K46'],
 'K47PH6': ['K47'],
 'K48PH164C1': ['K48'],
 'K49PH164C2': ['K11', 'K49', 'K53', 'K56', 'K60'],
 'K4PH164': ['K4', 'K52'],
 'K50PH164C1': ['K43', 'K50', 'K69'],
 'K51PH129C1': ['K51'],
 'K52PH129C1': ['K28', 'K39', 'K52', 'K62', 'K69'],
 'K53PH164C2': ['K53'],
 'K54lambda1_1_1': ['K24', 'K54', 'K58'],
 'K54lambda2': ['K54'],
 'K55P2_1': ['K55'],
 'K56PH164C1': ['K56'],
 'K57lambda1_2': ['K57', 'K68'],
 'K58PH129C2': ['K58'],
 'K59PH2': ['K30', 'K36', 'K59'],
 'K5lambda5': ['K5'],
 'K60PH164C1': ['K18', 'K60'],
 'K61PH164C1': ['K61', 'K67'],
 'K62PH164C2': ['K29', 'K62', 'K79'],
 'K63PH128': ['K63'],
 'K64PH164C4': ['K64'],
 'K65PH164': ['K7', 'K27', 'K29', 'K32', 'K35', 'K36', 'K50', 'K59', 'K62', 'K65', 'K69', 'K70', 'K72', 'K79', 'K80'],
 'K66PH128C1': ['K66'],
 'K68QB': ['K7', 'K29', 'K32', 'K35', 'K56', 'K64', 'K68'],
 'K69PH164C2': ['K28', 'K69'],
 'K6PH25C3': ['K6', 'K7'],
 'K70PH128C1': ['K11', 'K19', 'K29', 'K49', 'K69', 'K70'],
 'K71PH129C1': ['K71'],
 'K72PH164C2': ['K72'],
 'K74PH129C2': ['K74'],
 'K79PH164C1': ['K79'],
 'K7PH164C2': ['K7'],
 'K7PH164C3': ['K7'],
 'K7PH164C4': ['K7', 'K21', 'K27', 'K29', 'K30', 'K31', 'K35', 'K36', 'K39', 'K52', 'K56', 'K64', 'K65', 'K69', 'K70'],
 'K80P2': ['K80'],
 'K81P1': ['K81'],
 'K82P1': ['K82'],
 'K8PH128': ['K1', 'K8'],
 'K9PH25C2': ['K9']}

# %%
import pandas as pd 
import os 

path_project = "/media/concha-eloko/Linux/77_strains_phage_project"
path_Dpo_domain_org = "/media/concha-eloko/Linux/depolymerase_building/clean_77_phages_depo"

dpo_embeddings = pd.read_csv(f"{path_project}/rbp_work/Dpo_domains_77.esm2.embedding.1512.csv", sep = "," , header = None)
dpo_embeddings = dpo_embeddings.drop([1281] , axis = 1)
dpo_embeddings.set_index([0], inplace = True)

sorted(dpo_embeddings.index.tolist())
# Out:
# ['K10PH82C1__cds_50_Dpo_domain',
#  'K10PH82C1__cds_51_Dpo_domain',
#  'K10PH82C1_cds_45__66-159;312-596',
#  'K11PH164C1__cds_45_Dpo_domain',
#  'K11PH164C1__cds_46_Dpo_domain',
#  'K11PH164C1_cds_39__47-144;247-577',
#  'K12P1_1_cds_43__49-139;294-578',
#  'K13PH07C1L_cds_54__47-145;248-583',
#  'K13PH07C1S__cds_10_Dpo_domain',
#  'K13PH07C1S__cds_11_Dpo_domain',
#  'K13PH07C1S_cds_53__47-145;248-583',
#  'K14PH164C1__cds_24_Dpo_domain',
#  'K15PH90__cds_55_Dpo_domain',
#  'K15PH90_cds_49__49-140;294-578',
#  'K16PH164C3__cds_48_Dpo_domain',
#  'K16PH164C3_cds_43__75-145;261-591',
#  'K17alfa61__cds_23_Dpo_domain',
#  'K17alfa62__cds_64_Dpo_domain',
#  'K17alfa62_cds_66__281-682',
#  'K19PH14C4P1_cds_43__47-145;256-586',
#  'K19PH14C4P1_cds_48__312-504',
#  'K1PH164C1__cds_8_Dpo_domain',
#  'K1PH164C1_cds_53__49-139;294-578',
#  'K2064PH2_cds_25__349-756',
#  'K2069PH1_cds_25__349-756',
#  'K21lambda1__cds_28_Dpo_domain',
#  'K22PH164C1__cds_10_Dpo_domain',
# ...

# %%
import pandas as pd 
import os 

path_project = "/media/concha-eloko/Linux/77_strains_phage_project"
path_Dpo_domain_org = "/media/concha-eloko/Linux/depolymerase_building/clean_77_phages_depo"

dpo_embeddings = pd.read_csv(f"{path_project}/rbp_work/Dpo_domains_77.esm2.embedding.1512.csv", sep = "," , header = None)
dpo_embeddings = dpo_embeddings.drop([1281] , axis = 1)
dpo_embeddings.set_index([0], inplace = True)
dpo_embeddings.index = [x if x.count("__cds") > 0 else x.replace("_cds", "__cds") for x in dpo_embeddings.index]
dpo_embeddings.index = [x.replace("__CDS","__cds") if x.count("__CDS") > 0 else x for x in dpo_embeddings.index]
dpo_embeddings.index = ['__'.join(x.split("__")[0:-1])+'_Dpo_domain' if x.count("_Dpo_domain") == 0 else x for x in dpo_embeddings.index]

# %%
dpo_embeddings
# Out:
#                                    1         2         3         4     \
# K15PH90__cds_55_Dpo_domain    -0.028760  0.046677 -0.010773  0.028452
# K80PH1317b__cds_54_Dpo_domain  0.007689  0.036850 -0.006928 -0.056424
# K64PH164C4__cds_24_Dpo_domain  0.015762  0.062429 -0.003427 -0.003609
# K5lambda5__cds_196_Dpo_domain  0.040111  0.046436 -0.012045 -0.043877
# K11PH164C1__cds_46_Dpo_domain  0.017319  0.077582 -0.001212 -0.030026
# ...                                 ...       ...       ...       ...
# K24PH164C1__cds_55_Dpo_domain  0.039957 -0.007577 -0.037035  0.054355
# K42PH8__cds_43_Dpo_domain      0.015222 -0.034378 -0.049853  0.063044
# K10PH82C1__cds_45_Dpo_domain   0.017037 -0.028448 -0.066188  0.038587
# K44PH129C1__cds_45_Dpo_domain  0.010439 -0.023608 -0.016569  0.054134
# K29PH164C1__cds_25_Dpo_domain  0.032060  0.072230  0.006656  0.059065
#
#                                    5         6         7         8     \
# ...

# %%
missing_dpo = pd.read_csv(f"{path_project}/missed_dpo.77_phages.domains.24062024.esm2.embedding.csv", sep = ",", header = None, index_col = 0)

# %%
missing_dpo.index = [str(x) +'_Dpo_domain' for x in missing_dpo.index]

# %%
missing_dpo
# Out:
#                                       1         2         3         4     \
# K15PH90__cds_54_Dpo_domain        0.020510  0.012826 -0.038734  0.054898
# K7PH164C4__cds_20_Dpo_domain      0.074317  0.044336 -0.034949  0.062534
# K32PH164C1__cds_20_Dpo_domain     0.013327  0.101308 -0.016764  0.008642
# K18PH07C1__cds_245_Dpo_domain    -0.018251  0.003489  0.023381 -0.007395
# K13PH07C1L__cds_11_Dpo_domain     0.049178  0.051163  0.022950 -0.021801
# K22PH164C1__cds_11_Dpo_domain    -0.015741  0.018912 -0.005069 -0.038698
# K30lambda2_2__cds_152_Dpo_domain -0.002630  0.009162 -0.028090  0.026961
# K10PH82C1__cds_49_Dpo_domain     -0.019922 -0.033588 -0.045421 -0.022164
# K65PH164__cds_198_Dpo_domain      0.027901 -0.002302 -0.043486  0.078076
# K13PH07C1L__cds_12_Dpo_domain     0.026347  0.047993 -0.002456 -0.001667
# K41P2__cds_227_Dpo_domain         0.037184  0.013928 -0.046005  0.083191
# K13PH07C1L__cds_10_Dpo_domain     0.027208  0.064628 -0.007593 -0.023615
# ...

# %%
full_df = pd.concat([missing_dpo, dpo_embeddings], axis = 0)

# %%
full_df.to_csv(f"{path_project}/rbp_work/Dpo_domains_77.esm2.embedding.2406.csv", sep = "," , header = None, index = True)

# %%
full_df_test = pd.read_csv(f"{path_project}/rbp_work/Dpo_domains_77.esm2.embedding.2406.csv", sep = "," , header = None)
full_df_test
# Out:
#                               0         1         2         3         4     \
# 0       K15PH90__cds_54_Dpo_domain  0.020510  0.012826 -0.038734  0.054898
# 1     K7PH164C4__cds_20_Dpo_domain  0.074317  0.044336 -0.034949  0.062534
# 2    K32PH164C1__cds_20_Dpo_domain  0.013327  0.101308 -0.016764  0.008642
# 3    K18PH07C1__cds_245_Dpo_domain -0.018251  0.003489  0.023381 -0.007395
# 4    K13PH07C1L__cds_11_Dpo_domain  0.049178  0.051163  0.022950 -0.021801
# ..                             ...       ...       ...       ...       ...
# 138  K24PH164C1__cds_55_Dpo_domain  0.039957 -0.007577 -0.037035  0.054355
# 139      K42PH8__cds_43_Dpo_domain  0.015222 -0.034378 -0.049853  0.063044
# 140   K10PH82C1__cds_45_Dpo_domain  0.017037 -0.028448 -0.066188  0.038587
# 141  K44PH129C1__cds_45_Dpo_domain  0.010439 -0.023608 -0.016569  0.054134
# 142  K29PH164C1__cds_25_Dpo_domain  0.032060  0.072230  0.006656  0.059065
#
# ...

# %%
depoed_phages = {dpo.split("__cds")[0] for dpo in dpo_embeddings.index}
phage_dpo = {dpo : dpo.split("__cds")[0] for dpo in dpo_embeddings.index}

# %%
ferriol_df = pd.read_csv(f"/media/concha-eloko/Linux/PPT_clean/in_vitro/in_vitro_DFs/ferriol_fine_tuning.df", sep = "\t", header = 0)
ferriol_df["Target"] = ferriol_df["Target"].apply(lambda x : x.replace("K", "KL"))
pool_ferriol = set([kltype.strip() for kltypes in ferriol_df["Target"] for kltype in kltypes.split(",") if kltype.count("wzi") == 0 if kltype.count("pass") == 0])

# %%
ferriol_df
# Out:
#         Phages                          Protein          Target
# 0    K10PH82C1                K10PH82C1__cds_50            KL10
# 1    K10PH82C1                K10PH82C1__cds_51            KL10
# 2   K11PH164C1               K11PH164C1__cds_45      KL11, KL57
# 3   K11PH164C1               K11PH164C1__cds_46      KL11, KL57
# 4   K13PH07C1S               K13PH07C1S__cds_10            KL13
# ..         ...                              ...             ...
# 88     K15PH90  K15PH90__cds_49__49-140;294-578            KL15
# 89     K12P1_1  K12P1_1__cds_43__49-139;294-578  KL12,KL28,KL69
# 90    K31PH164        K31PH164__cds_25__345-748       KL31,KL37
# 91    K28PH129        K28PH129__cds_24__442-837       KL28,KL69
# 92      K59PH2   K59PH2__cds_46__47-159;376-676  KL30,KL36,KL59
#
# [93 rows x 3 columns]

# %%
for phage in depoed_phages :
    if phage != "K42PH8_Dpo_domain" : 
        if phage not in ferriol_df["Phages"].tolist() :
            for protein, phage_harbor in phage_dpo.items() :
                if phage_harbor == phage :
                    print(phage_harbor , protein, ','.join(HR[phage_harbor]), sep = "\t")

# %%
print(f"Phages\tProtein\tTarget")
for protein,phage_harbor in phage_dpo.items() :
    if phage_harbor != "K42PH8_Dpo_domain" and phage_harbor in HR:
        print(phage_harbor , protein.split("_Dpo")[0], ','.join(HR[phage_harbor]), sep = "\t")
# Out:
# Phages	Protein	Target
# K15PH90	K15PH90__cds_55	K15
# K64PH164C4	K64PH164C4__cds_24	K64
# K5lambda5	K5lambda5__cds_196	K5
# K11PH164C1	K11PH164C1__cds_46	K11,K57
# K57lambda1_2	K57lambda1_2__cds_93	K57,K68
# K60PH164C1	K60PH164C1__cds_94	K18,K60
# K5lambda5	K5lambda5__cds_199	K5
# K5lambda5	K5lambda5__cds_200	K5
# K13PH07C1S	K13PH07C1S__cds_10	K13
# K2PH164C1	K2PH164C1__cds_23	K2
# K41P2	K41P2__cds_11	K39,K41
# K11PH164C1	K11PH164C1__cds_45	K11,K57
# K71PH129C1	K71PH129C1__cds_55	K71
# K13PH07C1S	K13PH07C1S__cds_11	K13
# K56PH164C1	K56PH164C1__cds_49	K56
# K38PH09C2	K38PH09C2__cds_24	K38
# K22PH164C1	K22PH164C1__cds_10	K22,K37
# K58PH129C2	K58PH129C2__cds_47	K58
# K44PH129C1	K44PH129C1__cds_9	K37,K44
# K17alfa62	K17alfa62__cds_64	K17,K62
# K24PH164C1	K24PH164C1__cds_8	K24
# K37PH164C1	K37PH164C1__cds_47	K2,K37
# K35PH164C3	K35PH164C3__cds_48	K30,K35,K36
# K56PH164C1	K56PH164C1__cds_48	K56
# K46PH129	K46PH129__cds_24	K46
# K25PH129C1	K25PH129C1__cds_60	K25
# ...
