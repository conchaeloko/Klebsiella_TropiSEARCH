# %%
# Ground modules
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
from Bio import SeqIO
from itertools import product
import random
from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import logging
import subprocess
from multiprocessing.pool import ThreadPool
import joblib

# SCikitlearn modules :
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report , roc_auc_score

# Scipy modules : 
from scipy.stats import fisher_exact

# %% [markdown]
# ***

# %%
# Make the blastp DB of all the dpo sequences :

path_seqbased = "/media/concha-eloko/Linux/PPT_clean/Seqbased_model"

fasta_file = f"{path_seqbased}/cdhit_clusters_2912/0.85.out"

blast_command = f"makeblastdb -in {fasta_file} -dbtype prot -out {path_seqbased}/TropiSeq/TropiSeq_0.85.db"
make_blast_process = subprocess.Popen(blast_command, shell =True, stdout = subprocess.PIPE, stderr=subprocess.STDOUT)
mkblast_out, mkblast_err = make_blast_process.communicate()
print(mkblast_out , mkblast_err)
# Out:
# b'\n\nBuilding a new DB, current time: 02/19/2024 22:23:42\nNew DB name:   /media/concha-eloko/Linux/PPT_clean/Seqbased_model/TropiSeq/TropiSeq_0.85.db\nNew DB title:  /media/concha-eloko/Linux/PPT_clean/Seqbased_model/cdhit_clusters_2912/0.85.out\nSequence type: Protein\nDeleted existing Protein BLAST database named /media/concha-eloko/Linux/PPT_clean/Seqbased_model/TropiSeq/TropiSeq_0.85.db\nKeep MBits: T\nMaximum file size: 1000000000B\nAdding sequences from FASTA; added 989 sequences in 0.047173 seconds.\n' None

# %% [markdown]
# ***
# # Make function that :
# ### A : blastp from a Dpo seq
# ### B : read the results and spot the hits
# ### C : Build a vector from the presence abscence
# ### D : Make prediction
# ***

# %% [markdown]
# > 77 phages

# %%
rsync -avzhe ssh \
conchae@garnatxa.srv.cpd:/home/conchae/prediction_depolymerase_tropism/prophage_prediction/depolymerase_decipher/ficheros_28032023/Seqbased_model/dico_cluster.cdhit__0.85.json \
/media/concha-eloko/Linux/PPT_clean/Seqbased_model

# %%
import json

path_seqbased = "/media/concha-eloko/Linux/PPT_clean/Seqbased_model"
path_db = f"{path_seqbased}/TropiSeq/TropiSeq_0.85.db"

dico_cluster = json.load(open(f"{path_seqbased}/dico_cluster.cdhit__0.85.json"))
dico_cluster_r = {ref_dpo : key_dpo for key_dpo,list_dpo in dico_cluster.items() for ref_dpo in list_dpo}

# %%
dico_cluster
# Out:
# {'Dpo_cdhit_0': ['minibatch__2009'],
#  'Dpo_cdhit_1': ['ppt__2348'],
#  'Dpo_cdhit_2': ['minibatch__106'],
#  'Dpo_cdhit_3': ['minibatch__505', 'ppt__4004', 'ppt__4400'],
#  'Dpo_cdhit_4': ['anubis_return__372',
#   'anubis_return__1536',
#   'anubis_return__3097'],
#  'Dpo_cdhit_5': ['ppt__612'],
#  'Dpo_cdhit_6': ['ppt__6611'],
#  'Dpo_cdhit_7': ['ppt__5387'],
#  'Dpo_cdhit_8': ['ppt__2174'],
#  'Dpo_cdhit_9': ['minibatch__1251', 'minibatch__439', 'ppt__3411'],
#  'Dpo_cdhit_10': ['minibatch__1246', 'ppt__2067', 'ppt__6301'],
#  'Dpo_cdhit_11': ['ppt__4977'],
#  'Dpo_cdhit_12': ['minibatch__1084'],
#  'Dpo_cdhit_13': ['ppt__4840', 'ppt__5234'],
#  'Dpo_cdhit_14': ['ppt__6878'],
#  'Dpo_cdhit_15': ['ppt__6587',
#   'ppt__3793',
#   'minibatch__102',
#   'ppt__4600',
#   'minibatch__2006'],
#  'Dpo_cdhit_16': ['ppt__4637'],
#  'Dpo_cdhit_17': ['minibatch__2160'],
#  'Dpo_cdhit_18': ['minibatch__1368', 'ppt__2236', 'ppt__4817', 'ppt__5544'],
#  'Dpo_cdhit_19': ['ppt__2087'],
#  'Dpo_cdhit_20': ['minibatch__260', 'minibatch__1183', 'ppt__861'],
#  'Dpo_cdhit_21': ['minibatch__2001', 'minibatch__105'],
#  'Dpo_cdhit_22': ['ppt__2632'],
#  'Dpo_cdhit_23': ['minibatch__1254',
#   'minibatch__850',
#   'ppt__1351',
#   'minibatch__1704',
#   'minibatch__1888'],
#  'Dpo_cdhit_24': ['minibatch__819',
#   'minibatch__1869',
#   'minibatch__961',
#   'ppt__6327'],
#  'Dpo_cdhit_25': ['minibatch__51', 'minibatch__1689', 'minibatch__1804'],
#  'Dpo_cdhit_26': ['ppt__1272'],
#  'Dpo_cdhit_27': ['minibatch__1938', 'ppt__2664', 'ppt__5819'],
#  'Dpo_cdhit_28': ['ppt__6827'],
#  'Dpo_cdhit_29': ['ppt__1777', 'ppt__2591'],
#  'Dpo_cdhit_30': ['minibatch__1576',
#   'minibatch__1533',
#   'minibatch__578',
#   'minibatch__1565',
#   'minibatch__485',
#   'minibatch__1040',
#   'ppt__5008'],
#  'Dpo_cdhit_31': ['minibatch__1962'],
#  'Dpo_cdhit_32': ['minibatch__1900', 'minibatch__1594'],
#  'Dpo_cdhit_33': ['ppt__4359'],
#  'Dpo_cdhit_34': ['ppt__3948'],
#  'Dpo_cdhit_35': ['ppt__5034'],
#  'Dpo_cdhit_36': ['minibatch__1830'],
#  'Dpo_cdhit_37': ['ppt__3206'],
#  'Dpo_cdhit_38': ['ppt__740', 'ppt__5392'],
#  'Dpo_cdhit_39': ['ppt__966', 'ppt__4579'],
#  'Dpo_cdhit_40': ['ppt__3015'],
#  'Dpo_cdhit_41': ['ppt__110', 'ppt__5683', 'ppt__6731', 'ppt__7060'],
#  'Dpo_cdhit_42': ['ppt__2433'],
#  'Dpo_cdhit_43': ['ppt__2895'],
#  'Dpo_cdhit_44': ['ppt__5516'],
#  'Dpo_cdhit_45': ['ppt__6789', 'minibatch__1545'],
#  'Dpo_cdhit_46': ['ppt__2675'],
#  'Dpo_cdhit_47': ['ppt__972',
#   'ppt__69',
#   'ppt__6051',
#   'anubis__1527',
#   'anubis_return__453'],
#  'Dpo_cdhit_48': ['minibatch__1202',
#   'ppt__3844',
#   'ppt__4574',
#   'ppt__4677',
#   'ppt__6052',
#   'ppt__1988',
#   'ppt__3339',
#   'ppt__5985',
#   'minibatch__1139',
#   'minibatch__1286'],
#  'Dpo_cdhit_49': ['anubis__94',
#   'anubis__181',
#   'anubis__841',
#   'anubis__941',
#   'anubis__1034',
#   'anubis__1193',
#   'anubis__1379',
#   'anubis__1434',
#   'anubis__344',
#   'anubis__1642',
#   'anubis__538',
#   'anubis__828',
#   'anubis__1118',
#   'anubis__1209',
#   'anubis__1234',
#   'anubis__1254',
#   'anubis__1353'],
#  'Dpo_cdhit_50': ['minibatch__946', 'ppt__1833', 'ppt__2136'],
#  'Dpo_cdhit_51': ['minibatch__498', 'minibatch__1608'],
#  'Dpo_cdhit_52': ['ppt__4281'],
#  'Dpo_cdhit_53': ['ppt__590',
#   'ppt__5415',
#   'ppt__6317',
#   'ppt__892',
#   'ppt__2601',
#   'ppt__4434',
#   'ppt__4437',
#   'ppt__4527',
#   'ppt__4599',
#   'ppt__5359',
#   'minibatch__337',
#   'anubis_return__3035'],
#  'Dpo_cdhit_54': ['minibatch__762'],
#  'Dpo_cdhit_55': ['ppt__94',
#   'minibatch__24',
#   'minibatch__1873',
#   'ppt__4074',
#   'minibatch__1847'],
#  'Dpo_cdhit_56': ['ppt__764',
#   'ppt__1008',
#   'ppt__1513',
#   'ppt__2753',
#   'ppt__2796',
#   'minibatch__1354',
#   'minibatch__364',
#   'minibatch__723',
#   'minibatch__1294'],
#  'Dpo_cdhit_57': ['minibatch__1074'],
#  'Dpo_cdhit_58': ['ppt__4751'],
#  'Dpo_cdhit_59': ['ppt__5414'],
#  'Dpo_cdhit_60': ['minibatch__1481', 'ppt__3298'],
#  'Dpo_cdhit_61': ['minibatch__1441', 'ppt__6578', 'ppt__5735'],
#  'Dpo_cdhit_62': ['ppt__3033'],
#  'Dpo_cdhit_63': ['ppt__3485', 'ppt__6061'],
#  'Dpo_cdhit_64': ['ppt__1509'],
#  'Dpo_cdhit_65': ['ppt__4112'],
#  'Dpo_cdhit_66': ['ppt__4716'],
#  'Dpo_cdhit_67': ['minibatch__758', 'minibatch__1235', 'ppt__5736'],
#  'Dpo_cdhit_68': ['minibatch__828', 'ppt__403', 'ppt__1557', 'ppt__5164'],
#  'Dpo_cdhit_69': ['ppt__3174'],
#  'Dpo_cdhit_70': ['minibatch__396', 'ppt__3863', 'minibatch__285'],
#  'Dpo_cdhit_71': ['ppt__85',
#   'ppt__152',
#   'minibatch__160',
#   'ppt__3819',
#   'ppt__3925',
#   'ppt__5635',
#   'ppt__6471',
#   'minibatch__1296'],
#  'Dpo_cdhit_72': ['minibatch__271',
#   'minibatch__1694',
#   'minibatch__997',
#   'ppt__2680',
#   'ppt__3211',
#   'ppt__4814'],
#  'Dpo_cdhit_73': ['minibatch__468'],
#  'Dpo_cdhit_74': ['minibatch__669',
#   'minibatch__834',
#   'minibatch__1374',
#   'minibatch__754',
#   'minibatch__179',
#   'minibatch__1330',
#   'ppt__230',
#   'minibatch__258',
#   'minibatch__35',
#   'minibatch__1930',
#   'minibatch__316',
#   'minibatch__559',
#   'minibatch__1949'],
#  'Dpo_cdhit_75': ['minibatch__1802', 'minibatch__1369'],
#  'Dpo_cdhit_76': ['ppt__3789', 'ppt__6227'],
#  'Dpo_cdhit_77': ['minibatch__2079', 'minibatch__659', 'ppt__424'],
#  'Dpo_cdhit_78': ['ppt__6318'],
#  'Dpo_cdhit_79': ['minibatch__25', 'minibatch__1632'],
#  'Dpo_cdhit_80': ['ppt__1128'],
#  'Dpo_cdhit_81': ['minibatch__1909'],
#  'Dpo_cdhit_82': ['ppt__2890'],
#  'Dpo_cdhit_83': ['ppt__3190'],
#  'Dpo_cdhit_84': ['minibatch__1491',
#   'minibatch__1914',
#   'ppt__2792',
#   'ppt__2837',
#   'ppt__4117',
#   'ppt__5378',
#   'ppt__5718',
#   'ppt__139',
#   'ppt__445',
#   'minibatch__1478',
#   'minibatch__1003',
#   'minibatch__1035',
#   'minibatch__23',
#   'minibatch__1059'],
#  'Dpo_cdhit_85': ['ppt__5979'],
#  'Dpo_cdhit_86': ['minibatch__419', 'ppt__1705'],
#  'Dpo_cdhit_87': ['ppt__2489', 'ppt__5370'],
#  'Dpo_cdhit_88': ['minibatch__1497',
#   'minibatch__2066',
#   'ppt__3031',
#   'ppt__5408',
#   'ppt__5830',
#   'ppt__6599'],
#  'Dpo_cdhit_89': ['minibatch__460'],
#  'Dpo_cdhit_90': ['ppt__2977'],
#  'Dpo_cdhit_91': ['minibatch__869', 'minibatch__339'],
#  'Dpo_cdhit_92': ['minibatch__842', 'minibatch__1687'],
#  'Dpo_cdhit_93': ['anubis_return__2217'],
#  'Dpo_cdhit_94': ['minibatch__1164', 'ppt__2778'],
#  'Dpo_cdhit_95': ['anubis__210',
#   'ppt__2783',
#   'anubis__548',
#   'ppt__4256',
#   'ppt__4577',
#   'ppt__4697',
#   'ppt__4917',
#   'ppt__4978',
#   'ppt__4980',
#   'anubis__1211',
#   'ppt__6127',
#   'anubis__1498',
#   'anubis__976',
#   'anubis__1008',
#   'anubis__1380',
#   'anubis__1516'],
#  'Dpo_cdhit_96': ['ppt__244',
#   'ppt__772',
#   'ppt__2801',
#   'ppt__3500',
#   'anubis__731',
#   'ppt__3627',
#   'ppt__4353',
#   'ppt__6277',
#   'ppt__6516',
#   'anubis__535'],
#  'Dpo_cdhit_97': ['minibatch__583', 'ppt__1694', 'ppt__1695', 'ppt__5647'],
#  'Dpo_cdhit_98': ['minibatch__1664'],
#  'Dpo_cdhit_99': ['minibatch__1064'],
#  'Dpo_cdhit_100': ['ppt__1963'],
#  'Dpo_cdhit_101': ['ppt__667',
#   'ppt__1720',
#   'ppt__1789',
#   'ppt__2784',
#   'ppt__3029',
#   'ppt__3055',
#   'ppt__3144',
#   'ppt__3346',
#   'ppt__5467',
#   'anubis__739',
#   'anubis__1415',
#   'anubis_return__275',
#   'anubis_return__2707'],
#  'Dpo_cdhit_102': ['anubis_return__532',
#   'anubis_return__717',
#   'anubis_return__911',
#   'anubis_return__1649',
#   'anubis_return__2063',
#   'anubis_return__2512',
#   'anubis_return__3262',
#   'anubis_return__3915',
#   'anubis_return__4150',
#   'anubis_return__4208'],
#  'Dpo_cdhit_103': ['minibatch__2122', 'ppt__4192', 'ppt__6825'],
#  'Dpo_cdhit_104': ['ppt__5216', 'ppt__6456'],
#  'Dpo_cdhit_105': ['ppt__1889', 'ppt__3147'],
#  'Dpo_cdhit_106': ['minibatch__1559'],
#  'Dpo_cdhit_107': ['anubis__274',
#   'anubis__512',
#   'anubis__513',
#   'anubis__601',
#   'anubis__794',
#   'anubis__885',
#   'anubis__932',
#   'anubis__1120',
#   'ppt__6102',
#   'anubis__273'],
#  'Dpo_cdhit_108': ['minibatch__972', 'anubis_return__3931'],
#  'Dpo_cdhit_109': ['minibatch__2162'],
#  'Dpo_cdhit_110': ['ppt__2061'],
#  'Dpo_cdhit_111': ['ppt__4018'],
#  'Dpo_cdhit_112': ['ppt__2757'],
#  'Dpo_cdhit_113': ['minibatch__489'],
#  'Dpo_cdhit_114': ['minibatch__2016'],
#  'Dpo_cdhit_115': ['minibatch__684'],
#  'Dpo_cdhit_116': ['ppt__6044'],
#  'Dpo_cdhit_117': ['minibatch__274', 'ppt__6017'],
#  'Dpo_cdhit_118': ['minibatch__1997',
#   'ppt__718',
#   'minibatch__678',
#   'ppt__1094',
#   'minibatch__2029',
#   'ppt__2034',
#   'ppt__2055',
#   'ppt__2075',
#   'ppt__2594',
#   'ppt__2682',
#   'ppt__3053',
#   'ppt__3143',
#   'ppt__3523',
#   'minibatch__653',
#   'ppt__5964',
#   'minibatch__1023'],
#  'Dpo_cdhit_119': ['anubis_return__733'],
#  'Dpo_cdhit_120': ['ppt__1096',
#   'ppt__2445',
#   'ppt__2602',
#   'ppt__2738',
#   'ppt__2799',
#   'ppt__3124',
#   'ppt__3667',
#   'ppt__3826',
#   'ppt__4352',
#   'minibatch__562',
#   'ppt__4810',
#   'minibatch__1326',
#   'ppt__5205',
#   'ppt__5373',
#   'ppt__5463',
#   'ppt__5826',
#   'minibatch__1485',
#   'ppt__6023',
#   'ppt__6144',
#   'ppt__6438',
#   'minibatch__1100'],
#  'Dpo_cdhit_121': ['ppt__2667', 'ppt__5353', 'anubis__1208'],
#  'Dpo_cdhit_122': ['ppt__3279',
#   'ppt__4962',
#   'ppt__5495',
#   'ppt__6392',
#   'ppt__6718'],
#  'Dpo_cdhit_123': ['ppt__2951',
#   'ppt__5637',
#   'ppt__6941',
#   'anubis_return__1514',
#   'anubis_return__3203'],
#  'Dpo_cdhit_124': ['ppt__187', 'ppt__2971', 'ppt__3592'],
#  'Dpo_cdhit_125': ['minibatch__771',
#   'minibatch__1031',
#   'ppt__1183',
#   'ppt__4382',
#   'ppt__5820'],
#  'Dpo_cdhit_126': ['minibatch__804'],
#  'Dpo_cdhit_127': ['minibatch__745'],
#  'Dpo_cdhit_128': ['ppt__2634'],
#  'Dpo_cdhit_129': ['ppt__5098'],
#  'Dpo_cdhit_130': ['ppt__3355'],
#  'Dpo_cdhit_131': ['ppt__4699'],
#  'Dpo_cdhit_132': ['minibatch__837', 'ppt__765', 'ppt__5949'],
#  'Dpo_cdhit_133': ['minibatch__1509'],
#  'Dpo_cdhit_134': ['ppt__350', 'ppt__871', 'ppt__1875', 'ppt__2196'],
#  'Dpo_cdhit_135': ['anubis_return__1027'],
#  'Dpo_cdhit_136': ['minibatch__1012'],
#  'Dpo_cdhit_137': ['ppt__1779',
#   'ppt__3324',
#   'ppt__3638',
#   'ppt__5079',
#   'ppt__6321',
#   'ppt__6349',
#   'ppt__1287',
#   'ppt__3336',
#   'ppt__3516',
#   'ppt__3590',
#   'ppt__4559',
#   'ppt__5511',
#   'ppt__5789',
#   'ppt__5999',
#   'ppt__6322',
#   'ppt__6887',
#   'minibatch__1980',
#   'anubis_return__872',
#   'anubis_return__1747',
#   'anubis_return__1924',
#   'anubis_return__2133',
#   'anubis_return__2371',
#   'anubis_return__2782',
#   'anubis_return__3065',
#   'anubis_return__3761',
#   'anubis_return__3781'],
#  'Dpo_cdhit_138': ['ppt__1798', 'ppt__5814', 'minibatch__1045'],
#  'Dpo_cdhit_139': ['anubis_return__208', 'anubis_return__531'],
#  'Dpo_cdhit_140': ['ppt__2171', 'anubis_return__268', 'anubis_return__3755'],
#  'Dpo_cdhit_141': ['ppt__541', 'ppt__4899', 'ppt__6145', 'minibatch__0'],
#  'Dpo_cdhit_142': ['minibatch__600',
#   'ppt__6971',
#   'minibatch__670',
#   'ppt__5535',
#   'ppt__5546',
#   'ppt__7092',
#   'minibatch__36',
#   'anubis_return__2403',
#   'anubis_return__4186'],
#  'Dpo_cdhit_143': ['ppt__1467'],
#  'Dpo_cdhit_144': ['anubis_return__3364'],
#  'Dpo_cdhit_145': ['ppt__2899', 'ppt__4530'],
#  'Dpo_cdhit_146': ['ppt__6118', 'ppt__6908', 'ppt__6932'],
#  'Dpo_cdhit_147': ['minibatch__1741', 'minibatch__230'],
#  'Dpo_cdhit_148': ['ppt__4038'],
#  'Dpo_cdhit_149': ['ppt__1791', 'minibatch__662'],
#  'Dpo_cdhit_150': ['ppt__1552'],
#  'Dpo_cdhit_151': ['ppt__4818'],
#  'Dpo_cdhit_152': ['ppt__388', 'ppt__458'],
#  'Dpo_cdhit_153': ['ppt__5476'],
#  'Dpo_cdhit_154': ['ppt__5657'],
#  'Dpo_cdhit_155': ['ppt__6418'],
#  'Dpo_cdhit_156': ['ppt__736', 'ppt__4154'],
#  'Dpo_cdhit_157': ['ppt__1085'],
#  'Dpo_cdhit_158': ['ppt__1422', 'ppt__5867'],
#  'Dpo_cdhit_159': ['ppt__1897'],
#  'Dpo_cdhit_160': ['anubis__844'],
#  'Dpo_cdhit_161': ['ppt__5421'],
#  'Dpo_cdhit_162': ['anubis__243'],
#  'Dpo_cdhit_163': ['minibatch__648'],
#  'Dpo_cdhit_164': ['minibatch__1094',
#   'minibatch__1203',
#   'minibatch__151',
#   'anubis_return__2052',
#   'anubis_return__2273',
#   'anubis_return__3562'],
#  'Dpo_cdhit_165': ['minibatch__2080',
#   'anubis_return__594',
#   'anubis_return__924',
#   'anubis_return__1952',
#   'anubis_return__3333',
#   'anubis_return__3537',
#   'anubis_return__4088'],
#  'Dpo_cdhit_166': ['ppt__4897'],
#  'Dpo_cdhit_167': ['anubis__1082', 'ppt__6762'],
#  'Dpo_cdhit_168': ['ppt__1930'],
#  'Dpo_cdhit_169': ['ppt__617'],
#  'Dpo_cdhit_170': ['ppt__1153', 'ppt__1555', 'anubis_return__666'],
#  'Dpo_cdhit_171': ['minibatch__1273', 'anubis_return__1482'],
#  'Dpo_cdhit_172': ['ppt__1523'],
#  'Dpo_cdhit_173': ['ppt__1836'],
#  'Dpo_cdhit_174': ['ppt__1089',
#   'ppt__3942',
#   'ppt__428',
#   'ppt__570',
#   'ppt__1191',
#   'ppt__3962'],
#  'Dpo_cdhit_175': ['anubis__13',
#   'anubis__21',
#   'anubis__11',
#   'anubis__92',
#   'anubis__131',
#   'anubis__9',
#   'anubis__185',
#   'anubis__234',
#   'anubis__383',
#   'anubis__390',
#   'anubis__404',
#   'anubis__502',
#   'anubis__504',
#   'anubis__507',
#   'anubis__638',
#   'anubis__723',
#   'anubis__580',
#   'anubis__750',
#   'anubis__751',
#   'anubis__814',
#   'anubis__815',
#   'anubis__835',
#   'anubis__845',
#   'anubis__860',
#   'anubis__867',
#   'anubis__871',
#   'anubis__901',
#   'anubis__833',
#   'anubis__950',
#   'anubis__829',
#   'anubis__558',
#   'anubis__1101',
#   'anubis__1105',
#   'anubis__1130',
#   'anubis__1135',
#   'anubis__1164',
#   'anubis__619',
#   'anubis__1191',
#   'anubis__1265',
#   'anubis__1327',
#   'anubis__1373',
#   'anubis__1429',
#   'anubis__1467',
#   'anubis__1468',
#   'anubis__1529',
#   'anubis__1533',
#   'anubis__1539',
#   'anubis__1562',
#   'anubis__1567',
#   'anubis__1568',
#   'anubis__1577',
#   'anubis__967',
#   'anubis__455',
#   'anubis__1608',
#   'anubis__1634',
#   'anubis__1646',
#   'anubis__1656',
#   'anubis__1657',
#   'anubis__561',
#   'anubis__1476',
#   'anubis__607',
#   'anubis__1357',
#   'anubis__10',
#   'anubis__51',
#   'anubis__55',
#   'anubis__235',
#   'anubis__444',
#   'anubis__746',
#   'anubis__816',
#   'anubis__937',
#   'anubis__1044',
#   'anubis__1200',
#   'anubis__1205',
#   'anubis__1243',
#   'anubis__1264',
#   'anubis__1356',
#   'anubis__1372',
#   'anubis__1446',
#   'anubis__1462',
#   'anubis__1497',
#   'anubis__1546',
#   'anubis__69',
#   'anubis__89',
#   'anubis__90',
#   'anubis__105',
#   'anubis__132',
#   'anubis__150',
#   'anubis__151',
#   'anubis__165',
#   'anubis__195',
#   'anubis__228',
#   'anubis__249',
#   'anubis__252',
#   'anubis__256',
#   'anubis__257',
#   'anubis__258',
#   'anubis__262',
#   'anubis__282',
#   'anubis__291',
#   'anubis__369',
#   'anubis__446',
#   'anubis__499',
#   'anubis__506',
#   'anubis__514',
#   'anubis__530',
#   'anubis__620',
#   'anubis__701',
#   'anubis__725',
#   'anubis__736',
#   'anubis__748',
#   'anubis__759',
#   'anubis__777',
#   'anubis__866',
#   'anubis__870',
#   'anubis__900',
#   'anubis__924',
#   'anubis__947',
#   'anubis__1001',
#   'anubis__1047',
#   'anubis__1083',
#   'anubis__1109',
#   'anubis__1178',
#   'anubis__1216',
#   'anubis__1217',
#   'anubis__1251',
#   'anubis__1255',
#   'anubis__1262',
#   'anubis__1266',
#   'anubis__1272',
#   'anubis__1312',
#   'anubis__1335',
#   'anubis__1389',
#   'anubis__1431',
#   'anubis__1432',
#   'anubis__1436',
#   'anubis__1447',
#   'anubis__1477',
#   'anubis__1487',
#   'anubis__1528',
#   'anubis__1556',
#   'anubis__1557',
#   'anubis__1561',
#   'anubis__1563',
#   'anubis__1565',
#   'anubis__1569',
#   'anubis__1570',
#   'anubis__1578',
#   'anubis__1600',
#   'anubis__1619',
#   'anubis__1622',
#   'anubis__1624',
#   'anubis__1631',
#   'anubis__1643'],
#  'Dpo_cdhit_176': ['minibatch__2135',
#   'minibatch__2172',
#   'minibatch__1456',
#   'anubis_return__1081',
#   'anubis_return__2377',
#   'anubis_return__3422'],
#  'Dpo_cdhit_177': ['ppt__7076'],
#  'Dpo_cdhit_178': ['ppt__806'],
#  'Dpo_cdhit_179': ['minibatch__1796',
#   'ppt__1152',
#   'minibatch__82',
#   'minibatch__490',
#   'ppt__2072',
#   'ppt__2766',
#   'minibatch__1124',
#   'ppt__7146',
#   'anubis_return__549',
#   'anubis_return__1021',
#   'anubis_return__3797'],
#  'Dpo_cdhit_180': ['ppt__1664'],
#  'Dpo_cdhit_181': ['minibatch__636'],
#  'Dpo_cdhit_182': ['minibatch__91',
#   'minibatch__2111',
#   'minibatch__1529',
#   'minibatch__1461',
#   'ppt__836',
#   'ppt__852',
#   'ppt__2040',
#   'ppt__3320',
#   'ppt__4103',
#   'ppt__4201',
#   'ppt__4225',
#   'ppt__6841',
#   'minibatch__2105',
#   'ppt__2025',
#   'minibatch__929',
#   'ppt__6915',
#   'minibatch__288',
#   'anubis_return__390',
#   'anubis_return__398',
#   'anubis_return__913',
#   'anubis_return__1004',
#   'anubis_return__1742',
#   'anubis_return__2193',
#   'anubis_return__2259',
#   'anubis_return__2275',
#   'anubis_return__2735',
#   'anubis_return__3584',
#   'anubis_return__4094',
#   'anubis_return__4195'],
#  'Dpo_cdhit_183': ['ppt__2078', 'ppt__6813'],
#  'Dpo_cdhit_184': ['ppt__116',
#   'ppt__828',
#   'ppt__950',
#   'ppt__2310',
#   'ppt__2457',
#   'ppt__2551',
#   'ppt__2771',
#   'ppt__3061',
#   'ppt__3557',
#   'ppt__4182',
#   'ppt__4525',
#   'ppt__5030',
#   'ppt__5250',
#   'ppt__5326',
#   'ppt__5341',
#   'ppt__5803',
#   'ppt__6255',
#   'ppt__6270',
#   'ppt__6361',
#   'ppt__6410'],
#  'Dpo_cdhit_185': ['ppt__1165',
#   'minibatch__1667',
#   'ppt__1327',
#   'ppt__2018',
#   'ppt__4394',
#   'ppt__4864'],
#  'Dpo_cdhit_186': ['ppt__377',
#   'ppt__1241',
#   'ppt__2815',
#   'ppt__5916',
#   'anubis_return__1664'],
#  'Dpo_cdhit_187': ['anubis__752',
#   'anubis__883',
#   'anubis__1133',
#   'anubis__1206',
#   'anubis__1463'],
#  'Dpo_cdhit_188': ['ppt__3284',
#   'ppt__6714',
#   'ppt__1266',
#   'anubis_return__1724',
#   'anubis_return__4019'],
#  'Dpo_cdhit_189': ['ppt__1685', 'ppt__1498', 'ppt__3070'],
#  'Dpo_cdhit_190': ['ppt__4163'],
#  'Dpo_cdhit_191': ['ppt__1058', 'ppt__1059', 'ppt__5154'],
#  'Dpo_cdhit_192': ['minibatch__42',
#   'ppt__266',
#   'ppt__455',
#   'minibatch__1494',
#   'ppt__491',
#   'ppt__887',
#   'ppt__900',
#   'ppt__1187',
#   'ppt__1435',
#   'ppt__1707',
#   'ppt__2235',
#   'ppt__2261',
#   'ppt__2311',
#   'minibatch__1034',
#   'ppt__2474',
#   'ppt__2790',
#   'ppt__2793',
#   'ppt__2839',
#   'minibatch__1554',
#   'minibatch__643',
#   'ppt__3490',
#   'ppt__3550',
#   'ppt__4318',
#   'minibatch__1015',
#   'ppt__4703',
#   'ppt__4705',
#   'ppt__4815',
#   'minibatch__2100',
#   'ppt__4964',
#   'ppt__5058',
#   'ppt__5111',
#   'ppt__5130',
#   'minibatch__1581',
#   'ppt__5176',
#   'minibatch__1977',
#   'ppt__5377',
#   'ppt__5528',
#   'minibatch__565',
#   'minibatch__1805',
#   'ppt__5562',
#   'minibatch__1921',
#   'ppt__5717',
#   'ppt__5745',
#   'minibatch__346',
#   'ppt__5852',
#   'ppt__5927',
#   'minibatch__1703',
#   'ppt__6228',
#   'ppt__6319',
#   'minibatch__2179',
#   'ppt__6884',
#   'ppt__6989',
#   'minibatch__334',
#   'minibatch__1623',
#   'minibatch__365',
#   'ppt__7103',
#   'minibatch__2094',
#   'minibatch__1462',
#   'minibatch__1890',
#   'anubis_return__910'],
#  'Dpo_cdhit_193': ['anubis_return__1260'],
#  'Dpo_cdhit_194': ['ppt__1304', 'ppt__4313'],
#  'Dpo_cdhit_195': ['minibatch__1902',
#   'minibatch__582',
#   'minibatch__2015',
#   'minibatch__2033',
#   'ppt__1185',
#   'ppt__2626',
#   'ppt__4874',
#   'ppt__5351',
#   'ppt__5804'],
#  'Dpo_cdhit_196': ['ppt__359',
#   'minibatch__294',
#   'ppt__4187',
#   'ppt__4384',
#   'ppt__5571',
#   'minibatch__2120'],
#  'Dpo_cdhit_197': ['ppt__6414'],
#  'Dpo_cdhit_198': ['ppt__3171', 'anubis_return__1653'],
#  'Dpo_cdhit_199': ['ppt__4199', 'anubis_return__2256'],
#  'Dpo_cdhit_200': ['ppt__4901',
#   'ppt__6877',
#   'ppt__2252',
#   'ppt__4996',
#   'ppt__6882',
#   'minibatch__1371',
#   'anubis_return__2661',
#   'anubis_return__4118'],
#  'Dpo_cdhit_201': ['minibatch__208'],
#  'Dpo_cdhit_202': ['minibatch__1220',
#   'minibatch__64',
#   'minibatch__2044',
#   'minibatch__573',
#   'minibatch__1188'],
#  'Dpo_cdhit_203': ['ppt__838',
#   'anubis__227',
#   'ppt__2746',
#   'ppt__6176',
#   'ppt__6198'],
#  'Dpo_cdhit_204': ['anubis_return__1350'],
#  'Dpo_cdhit_205': ['anubis__1609', 'anubis__115'],
#  'Dpo_cdhit_206': ['anubis__177',
#   'anubis__1065',
#   'anubis__1163',
#   'anubis__1223',
#   'anubis__91',
#   'anubis__388',
#   'anubis__1022',
#   'anubis__1176',
#   'anubis__1313'],
#  'Dpo_cdhit_207': ['ppt__4878'],
#  'Dpo_cdhit_208': ['ppt__1805'],
#  'Dpo_cdhit_209': ['anubis__1382', 'anubis__1396'],
#  'Dpo_cdhit_210': ['ppt__2050'],
#  'Dpo_cdhit_211': ['anubis__1537', 'anubis__1586'],
#  'Dpo_cdhit_212': ['anubis_return__400', 'anubis_return__2602'],
#  'Dpo_cdhit_213': ['ppt__6726'],
#  'Dpo_cdhit_214': ['minibatch__385'],
#  'Dpo_cdhit_215': ['ppt__1567',
#   'ppt__2749',
#   'anubis__639',
#   'anubis__848',
#   'anubis__1404',
#   'ppt__6646',
#   'ppt__6664',
#   'ppt__6702',
#   'minibatch__2190'],
#  'Dpo_cdhit_216': ['ppt__6874', 'minibatch__1535'],
#  'Dpo_cdhit_217': ['ppt__2147',
#   'ppt__464',
#   'ppt__2131',
#   'minibatch__744',
#   'ppt__6135',
#   'ppt__6669',
#   'ppt__7080'],
#  'Dpo_cdhit_218': ['anubis__122',
#   'ppt__2101',
#   'ppt__2532',
#   'ppt__5581',
#   'ppt__5582',
#   'minibatch__1450'],
#  'Dpo_cdhit_219': ['minibatch__1666',
#   'minibatch__918',
#   'ppt__6405',
#   'anubis_return__3950'],
#  'Dpo_cdhit_220': ['ppt__6333'],
#  'Dpo_cdhit_221': ['anubis__582',
#   'anubis__161',
#   'anubis__267',
#   'anubis__528',
#   'anubis__605',
#   'anubis__1114',
#   'anubis__1190',
#   'anubis__1430',
#   'anubis__1449'],
#  'Dpo_cdhit_222': ['ppt__1445', 'ppt__3004', 'ppt__3843'],
#  'Dpo_cdhit_223': ['ppt__1929', 'ppt__1932'],
#  'Dpo_cdhit_224': ['ppt__44',
#   'minibatch__77',
#   'minibatch__275',
#   'minibatch__192',
#   'minibatch__1567',
#   'minibatch__380',
#   'ppt__3466',
#   'minibatch__991',
#   'ppt__3652',
#   'ppt__4021',
#   'ppt__4514',
#   'ppt__5178',
#   'ppt__5790',
#   'ppt__5952',
#   'ppt__6121',
#   'minibatch__966',
#   'ppt__6942',
#   'anubis_return__1354',
#   'anubis_return__2896'],
#  'Dpo_cdhit_225': ['anubis__1635'],
#  'Dpo_cdhit_226': ['anubis__405',
#   'anubis__1112',
#   'anubis__1311',
#   'anubis_return__605',
#   'anubis_return__4216'],
#  'Dpo_cdhit_227': ['ppt__719',
#   'ppt__1095',
#   'ppt__1858',
#   'ppt__2054',
#   'ppt__3054'],
#  'Dpo_cdhit_228': ['ppt__1568', 'ppt__3204'],
#  'Dpo_cdhit_229': ['ppt__3040',
#   'minibatch__1026',
#   'ppt__4715',
#   'ppt__5655',
#   'ppt__5807',
#   'minibatch__1744',
#   'minibatch__1331'],
#  'Dpo_cdhit_230': ['anubis_return__1471'],
#  'Dpo_cdhit_231': ['ppt__3012', 'ppt__6529'],
#  'Dpo_cdhit_232': ['ppt__2382',
#   'minibatch__893',
#   'ppt__3791',
#   'ppt__4015',
#   'minibatch__2086',
#   'anubis_return__1024',
#   'anubis_return__1092'],
#  'Dpo_cdhit_233': ['minibatch__467', 'ppt__1910'],
#  'Dpo_cdhit_234': ['ppt__5060'],
#  'Dpo_cdhit_235': ['ppt__1220', 'anubis_return__3186'],
#  'Dpo_cdhit_236': ['ppt__2102', 'ppt__3272', 'ppt__7104'],
#  'Dpo_cdhit_237': ['ppt__2688'],
#  'Dpo_cdhit_238': ['ppt__1635'],
#  'Dpo_cdhit_239': ['ppt__499',
#   'ppt__2575',
#   'ppt__2864',
#   'ppt__3675',
#   'minibatch__191',
#   'ppt__4480',
#   'ppt__4483',
#   'ppt__6046',
#   'minibatch__1474',
#   'anubis_return__3512',
#   'anubis_return__3513'],
#  'Dpo_cdhit_240': ['anubis_return__1373',
#   'anubis_return__2041',
#   'anubis_return__2345'],
#  'Dpo_cdhit_241': ['minibatch__1990',
#   'ppt__3032',
#   'anubis_return__1564',
#   'anubis_return__2251',
#   'anubis_return__2564',
#   'anubis_return__3029',
#   'anubis_return__3354',
#   'anubis_return__3722',
#   'anubis_return__3836',
#   'anubis_return__3942',
#   'anubis_return__4087'],
#  'Dpo_cdhit_242': ['ppt__2582', 'anubis__1425', 'anubis_return__1314'],
#  'Dpo_cdhit_243': ['ppt__5744'],
#  'Dpo_cdhit_244': ['ppt__3451', 'ppt__4852', 'minibatch__1281'],
#  'Dpo_cdhit_245': ['ppt__4974', 'minibatch__1198'],
#  'Dpo_cdhit_246': ['anubis_return__4120'],
#  'Dpo_cdhit_247': ['ppt__2360', 'ppt__5578', 'minibatch__1879'],
#  'Dpo_cdhit_248': ['ppt__380', 'ppt__846', 'ppt__1999'],
#  'Dpo_cdhit_249': ['ppt__1397', 'ppt__1529', 'ppt__2592'],
#  'Dpo_cdhit_250': ['ppt__5281', 'ppt__6098'],
#  'Dpo_cdhit_251': ['ppt__6972'],
#  'Dpo_cdhit_252': ['ppt__3152', 'ppt__6610', 'ppt__4016'],
#  'Dpo_cdhit_253': ['anubis__1347'],
#  'Dpo_cdhit_254': ['minibatch__1797',
#   'ppt__1043',
#   'ppt__1493',
#   'ppt__1765',
#   'minibatch__996',
#   'ppt__2368',
#   'ppt__2545',
#   'ppt__2663',
#   'ppt__4254',
#   'minibatch__379',
#   'ppt__4660',
#   'minibatch__1352',
#   'minibatch__2040',
#   'ppt__5793',
#   'ppt__6080',
#   'ppt__6629',
#   'minibatch__75',
#   'anubis_return__185',
#   'anubis_return__563',
#   'anubis_return__753',
#   'anubis_return__1622',
#   'anubis_return__2027',
#   'anubis_return__2359',
#   'anubis_return__3348',
#   'anubis_return__3756',
#   'anubis_return__3972'],
#  'Dpo_cdhit_255': ['ppt__1492',
#   'ppt__1868',
#   'ppt__2502',
#   'minibatch__526',
#   'ppt__3042',
#   'minibatch__1563',
#   'minibatch__478',
#   'minibatch__1615',
#   'minibatch__2154',
#   'anubis_return__2146'],
#  'Dpo_cdhit_256': ['ppt__700',
#   'ppt__1168',
#   'ppt__1495',
#   'ppt__4006',
#   'ppt__5646',
#   'ppt__6259',
#   'minibatch__829'],
#  'Dpo_cdhit_257': ['ppt__3640',
#   'ppt__5663',
#   'minibatch__757',
#   'ppt__6765',
#   'anubis_return__2008',
#   'anubis_return__3678'],
#  'Dpo_cdhit_258': ['ppt__5996'],
#  'Dpo_cdhit_259': ['ppt__1386'],
#  'Dpo_cdhit_260': ['ppt__2808',
#   'ppt__4828',
#   'ppt__6050',
#   'ppt__80',
#   'ppt__105',
#   'ppt__185',
#   'ppt__309',
#   'ppt__379',
#   'ppt__387',
#   'ppt__477',
#   'ppt__487',
#   'ppt__535',
#   'ppt__710',
#   'ppt__815',
#   'ppt__1029',
#   'ppt__1075',
#   'ppt__1404',
#   'ppt__1674',
#   'ppt__1780',
#   'ppt__1995',
#   'ppt__2056',
#   'ppt__2150',
#   'ppt__2324',
#   'ppt__2326',
#   'ppt__2498',
#   'ppt__2709',
#   'ppt__2794',
#   'ppt__2860',
#   'ppt__2939',
#   'ppt__3044',
#   'ppt__3145',
#   'ppt__3151',
#   'ppt__3168',
#   'ppt__3258',
#   'ppt__3401',
#   'ppt__3540',
#   'ppt__3558',
#   'ppt__3566',
#   'ppt__3577',
#   'ppt__3795',
#   'ppt__3837',
#   'ppt__3849',
#   'ppt__3909',
#   'ppt__3974',
#   'ppt__4147',
#   'ppt__4294',
#   'ppt__4317',
#   'ppt__4450',
#   'ppt__4531',
#   'ppt__4738',
#   'ppt__4750',
#   'ppt__4773',
#   'ppt__4829',
#   'ppt__5228',
#   'ppt__5451',
#   'ppt__5491',
#   'ppt__5569',
#   'ppt__5611',
#   'ppt__5713',
#   'ppt__5776',
#   'ppt__6003',
#   'ppt__6045',
#   'ppt__6140',
#   'ppt__6234',
#   'ppt__6316',
#   'ppt__6338',
#   'ppt__6378',
#   'ppt__6698',
#   'ppt__6764',
#   'ppt__6796',
#   'ppt__6891',
#   'ppt__6934',
#   'ppt__7011',
#   'ppt__7023'],
#  'Dpo_cdhit_261': ['ppt__2104', 'ppt__3274'],
#  'Dpo_cdhit_262': ['ppt__3245', 'minibatch__445'],
#  'Dpo_cdhit_263': ['anubis__401', 'anubis__553'],
#  'Dpo_cdhit_264': ['ppt__4013',
#   'ppt__4326',
#   'minibatch__989',
#   'anubis_return__1015'],
#  'Dpo_cdhit_265': ['ppt__4322',
#   'ppt__4323',
#   'minibatch__619',
#   'minibatch__1526'],
#  'Dpo_cdhit_266': ['anubis__223',
#   'anubis__279',
#   'ppt__2564',
#   'anubis__905',
#   'anubis__906',
#   'ppt__6065',
#   'anubis__1440',
#   'anubis__1450',
#   'anubis__1521',
#   'ppt__7135',
#   'anubis__1645',
#   'anubis__516'],
#  'Dpo_cdhit_267': ['ppt__3968',
#   'minibatch__1693',
#   'anubis_return__191',
#   'anubis_return__3621'],
#  'Dpo_cdhit_268': ['ppt__170', 'ppt__671', 'ppt__3589', 'ppt__6323'],
#  'Dpo_cdhit_269': ['ppt__1611', 'ppt__3512', 'ppt__3706', 'minibatch__322'],
#  'Dpo_cdhit_270': ['anubis__79',
#   'anubis__191',
#   'anubis__433',
#   'anubis__854',
#   'minibatch__1028',
#   'anubis__1003',
#   'anubis__1328',
#   'anubis__1239'],
#  'Dpo_cdhit_271': ['ppt__640',
#   'ppt__665',
#   'ppt__672',
#   'ppt__1329',
#   'ppt__1781',
#   'ppt__1840',
#   'ppt__3338',
#   'ppt__3735',
#   'ppt__4557',
#   'minibatch__1660',
#   'ppt__5512',
#   'ppt__5689',
#   'ppt__6205',
#   'minibatch__1520',
#   'anubis_return__2876',
#   'anubis_return__3737',
#   'anubis_return__3854'],
#  'Dpo_cdhit_272': ['ppt__5754', 'ppt__6109'],
#  'Dpo_cdhit_273': ['ppt__6304'],
#  'Dpo_cdhit_274': ['anubis_return__578'],
#  'Dpo_cdhit_275': ['anubis__109',
#   'anubis__138',
#   'minibatch__1275',
#   'anubis__328',
#   'anubis__332',
#   'anubis__472',
#   'minibatch__1536',
#   'anubis__712',
#   'anubis__795',
#   'anubis__797',
#   'anubis__809',
#   'anubis__943',
#   'anubis__994',
#   'anubis__348',
#   'anubis__1318',
#   'anubis__1475',
#   'minibatch__540',
#   'anubis__1306',
#   'anubis__140',
#   'anubis__205',
#   'anubis__214',
#   'anubis__426',
#   'anubis__721',
#   'anubis__796',
#   'anubis__1096',
#   'anubis__1494'],
#  'Dpo_cdhit_276': ['ppt__1793', 'minibatch__817'],
#  'Dpo_cdhit_277': ['minibatch__985', 'minibatch__1305', 'minibatch__1524'],
#  'Dpo_cdhit_278': ['anubis__824',
#   'anubis__916',
#   'anubis__1540',
#   'anubis__1599',
#   'anubis__1337',
#   'anubis__149',
#   'anubis__527',
#   'anubis__1085',
#   'anubis__1134',
#   'anubis__1242',
#   'anubis_return__3667'],
#  'Dpo_cdhit_279': ['anubis__1072'],
#  'Dpo_cdhit_280': ['minibatch__15', 'minibatch__1733'],
#  'Dpo_cdhit_281': ['ppt__5982'],
#  'Dpo_cdhit_282': ['ppt__802', 'anubis_return__1050'],
#  'Dpo_cdhit_283': ['ppt__352',
#   'ppt__354',
#   'ppt__1528',
#   'ppt__2113',
#   'ppt__2365',
#   'ppt__4003',
#   'ppt__4618',
#   'ppt__4774',
#   'ppt__5364',
#   'ppt__6594',
#   'ppt__6595',
#   'minibatch__253',
#   'ppt__6903',
#   'minibatch__748',
#   'minibatch__1134',
#   'minibatch__1232',
#   'anubis_return__610'],
#  'Dpo_cdhit_284': ['ppt__551', 'ppt__5886', 'ppt__6393'],
#  'Dpo_cdhit_285': ['ppt__1182',
#   'ppt__2413',
#   'ppt__2596',
#   'minibatch__84',
#   'ppt__4209',
#   'minibatch__236',
#   'minibatch__341',
#   'minibatch__1511',
#   'anubis_return__741',
#   'anubis_return__1367',
#   'anubis_return__1589',
#   'anubis_return__2320',
#   'anubis_return__3347'],
#  'Dpo_cdhit_286': ['ppt__2887'],
#  'Dpo_cdhit_287': ['ppt__2932', 'anubis_return__1507'],
#  'Dpo_cdhit_288': ['ppt__5003',
#   'ppt__5837',
#   'anubis_return__2719',
#   'anubis_return__3360'],
#  'Dpo_cdhit_289': ['minibatch__1103', 'anubis_return__1130'],
#  'Dpo_cdhit_290': ['ppt__158',
#   'anubis__280',
#   'ppt__2755',
#   'ppt__3468',
#   'ppt__3865',
#   'anubis__1012',
#   'anubis__1195',
#   'anubis__1197',
#   'anubis__1201',
#   'ppt__6984',
#   'anubis__1630',
#   'anubis__76',
#   'anubis__308',
#   'anubis__476',
#   'anubis__714',
#   'anubis_return__879'],
#  'Dpo_cdhit_291': ['ppt__2739',
#   'ppt__5177',
#   'ppt__42',
#   'anubis__83',
#   'ppt__530',
#   'minibatch__214',
#   'ppt__651',
#   'ppt__1223',
#   'ppt__1295',
#   'ppt__1343',
#   'anubis__290',
#   'minibatch__625',
#   'ppt__1569',
#   'ppt__1643',
#   'ppt__1954',
#   'ppt__2145',
#   'minibatch__530',
#   'minibatch__1621',
#   'ppt__2287',
#   'ppt__2377',
#   'minibatch__507',
#   'ppt__2661',
#   'ppt__2816',
#   'ppt__2906',
#   'ppt__3028',
#   'anubis__606',
#   'anubis__637',
#   'ppt__3191',
#   'ppt__3518',
#   'ppt__3602',
#   'minibatch__2007',
#   'ppt__3623',
#   'minibatch__609',
#   'ppt__3649',
#   'ppt__3692',
#   'minibatch__1431',
#   'ppt__4488',
#   'minibatch__1239',
#   'ppt__4641',
#   'ppt__4777',
#   'ppt__5196',
#   'minibatch__805',
#   'ppt__5259',
#   'minibatch__1795',
#   'ppt__6014',
#   'ppt__6031',
#   'anubis__1351',
#   'anubis__1352',
#   'ppt__6068',
#   'ppt__6178',
#   'ppt__6214',
#   'ppt__6373',
#   'minibatch__1440',
#   'ppt__6723',
#   'minibatch__2187',
#   'ppt__6831',
#   'ppt__6832',
#   'anubis__1603',
#   'minibatch__1218',
#   'minibatch__1862',
#   'minibatch__1947',
#   'anubis__827',
#   'anubis__1283',
#   'anubis_return__1395',
#   'anubis_return__2851'],
#  'Dpo_cdhit_292': ['ppt__5287'],
#  'Dpo_cdhit_293': ['minibatch__184'],
#  'Dpo_cdhit_294': ['anubis__1391'],
#  'Dpo_cdhit_295': ['ppt__4023', 'anubis_return__2117'],
#  'Dpo_cdhit_296': ['minibatch__1122'],
#  'Dpo_cdhit_297': ['anubis_return__667',
#   'anubis_return__1251',
#   'anubis_return__2093'],
#  'Dpo_cdhit_298': ['ppt__2852'],
#  'Dpo_cdhit_299': ['ppt__3939', 'anubis_return__2087'],
#  'Dpo_cdhit_300': ['anubis__868'],
#  'Dpo_cdhit_301': ['anubis__610',
#   'anubis__647',
#   'anubis__1024',
#   'anubis__1375',
#   'anubis__1587',
#   'anubis__1591',
#   'anubis__1605',
#   'anubis__1607',
#   'anubis__768',
#   'anubis__1160',
#   'anubis__1187',
#   'anubis_return__1612'],
#  'Dpo_cdhit_302': ['ppt__571',
#   'ppt__1318',
#   'ppt__1639',
#   'ppt__3066',
#   'ppt__3071',
#   'ppt__3072',
#   'ppt__3938',
#   'ppt__3943',
#   'ppt__3995',
#   'ppt__4031',
#   'ppt__4213',
#   'anubis__801',
#   'anubis__933',
#   'anubis__1215',
#   'anubis_return__509'],
#  'Dpo_cdhit_303': ['ppt__5972', 'ppt__6441'],
#  'Dpo_cdhit_304': ['ppt__22',
#   'ppt__258',
#   'minibatch__98',
#   'ppt__1073',
#   'ppt__1123',
#   'minibatch__387',
#   'ppt__2313',
#   'ppt__2315',
#   'ppt__2645',
#   'ppt__3574',
#   'ppt__4827',
#   'minibatch__2004',
#   'ppt__5314',
#   'ppt__5720',
#   'ppt__6131',
#   'minibatch__1736',
#   'ppt__6133',
#   'ppt__6543',
#   'ppt__7083'],
#  'Dpo_cdhit_305': ['anubis_return__392',
#   'anubis_return__1009',
#   'anubis_return__1091',
#   'anubis_return__1986',
#   'anubis_return__2006',
#   'anubis_return__2123'],
#  'Dpo_cdhit_306': ['ppt__794', 'ppt__4744', 'ppt__7095'],
#  'Dpo_cdhit_307': ['ppt__2244', 'minibatch__410'],
#  'Dpo_cdhit_308': ['ppt__1812',
#   'ppt__2765',
#   'ppt__2857',
#   'ppt__3373',
#   'minibatch__2192',
#   'minibatch__453',
#   'ppt__6668',
#   'minibatch__502'],
#  'Dpo_cdhit_309': ['ppt__2332',
#   'minibatch__724',
#   'ppt__5656',
#   'anubis_return__744',
#   'anubis_return__2465',
#   'anubis_return__2527',
#   'anubis_return__2546',
#   'anubis_return__3217',
#   'anubis_return__3520',
#   'anubis_return__4051'],
#  'Dpo_cdhit_310': ['anubis__1368'],
#  'Dpo_cdhit_311': ['minibatch__725'],
#  'Dpo_cdhit_312': ['anubis__439',
#   'anubis__1403',
#   'anubis__1479',
#   'anubis__1589'],
#  'Dpo_cdhit_313': ['ppt__442', 'ppt__4544', 'ppt__5536'],
#  'Dpo_cdhit_314': ['anubis__646'],
#  'Dpo_cdhit_315': ['minibatch__1269', 'minibatch__1961'],
#  'Dpo_cdhit_316': ['minibatch__1189',
#   'ppt__1888',
#   'ppt__2282',
#   'ppt__2649',
#   'minibatch__1901',
#   'ppt__3146',
#   'ppt__3408',
#   'minibatch__857',
#   'ppt__4145',
#   'ppt__4413',
#   'ppt__4420',
#   'ppt__4730',
#   'minibatch__1820',
#   'ppt__6229',
#   'ppt__6300',
#   'ppt__6725',
#   'ppt__6759',
#   'minibatch__1457',
#   'minibatch__1398',
#   'minibatch__738',
#   'anubis_return__1289',
#   'anubis_return__2638',
#   'anubis_return__2721',
#   'anubis_return__2798',
#   'anubis_return__2833',
#   'anubis_return__3636',
#   'anubis_return__3747',
#   'anubis_return__3767',
#   'anubis_return__3768',
#   'anubis_return__3956',
#   'anubis_return__4169'],
#  'Dpo_cdhit_317': ['ppt__6881'],
#  'Dpo_cdhit_318': ['ppt__550', 'ppt__5889'],
#  'Dpo_cdhit_319': ['anubis__108',
#   'anubis__259',
#   'anubis__329',
#   'anubis__331',
#   'anubis__349',
#   'anubis__396',
#   'anubis__425',
#   'anubis__517',
#   'anubis__599',
#   'anubis__636',
#   'anubis__659',
#   'anubis__711',
#   'anubis__798',
#   'anubis__799',
#   'anubis__810',
#   'anubis__817',
#   'anubis__1317',
#   'anubis__1395',
#   'anubis__1474',
#   'anubis__1604',
#   'anubis__136',
#   'anubis__215',
#   'anubis__740',
#   'anubis__1077',
#   'anubis__1138',
#   'anubis__1512'],
#  'Dpo_cdhit_320': ['ppt__5806'],
#  'Dpo_cdhit_321': ['ppt__3091'],
#  'Dpo_cdhit_322': ['ppt__604', 'ppt__1826', 'ppt__2750'],
#  'Dpo_cdhit_323': ['ppt__188',
#   'ppt__679',
#   'minibatch__451',
#   'minibatch__300',
#   'ppt__2051',
#   'minibatch__115',
#   'ppt__2952',
#   'ppt__2954',
#   'ppt__2970',
#   'minibatch__484',
#   'ppt__4626',
#   'ppt__4628',
#   'minibatch__1304',
#   'minibatch__2132',
#   'minibatch__280'],
#  'Dpo_cdhit_324': ['ppt__1349',
#   'ppt__2756',
#   'anubis__686',
#   'ppt__3852',
#   'anubis__475',
#   'ppt__4286',
#   'ppt__4363',
#   'ppt__4778',
#   'ppt__5029',
#   'ppt__5567',
#   'anubis__1196',
#   'ppt__6822',
#   'ppt__6910',
#   'ppt__7053',
#   'anubis__926',
#   'anubis__1055'],
#  'Dpo_cdhit_325': ['anubis__251',
#   'anubis__250',
#   'anubis__772',
#   'anubis__785',
#   'ppt__5751',
#   'anubis__1249'],
#  'Dpo_cdhit_326': ['ppt__6286'],
#  'Dpo_cdhit_327': ['anubis__5',
#   'anubis__7',
#   'anubis__25',
#   'anubis__26',
#   'anubis__95',
#   'anubis__96',
#   'anubis__120',
#   'minibatch__789',
#   'anubis__276',
#   'anubis__365',
#   'anubis__373',
#   'anubis__375',
#   'anubis__403',
#   'anubis__420',
#   'anubis__656',
#   'anubis__763',
#   'anubis__764',
#   'anubis__782',
#   'anubis__834',
#   'minibatch__1043',
#   'anubis__894',
#   'anubis__911',
#   'anubis__931',
#   'anubis__934',
#   'anubis__1021',
#   'anubis__1100',
#   'anubis__1110',
#   'anubis__1111',
#   'ppt__5337',
#   'anubis__1141',
#   'anubis__1143',
#   'anubis__1159',
#   'anubis__1203',
#   'anubis__1293',
#   'anubis__1361',
#   'anubis__1409',
#   'anubis__1410',
#   'anubis__6',
#   'anubis__1417',
#   'anubis__1433',
#   'anubis__1501',
#   'anubis__1502',
#   'anubis__1513',
#   'anubis__4',
#   'anubis__119',
#   'anubis__374',
#   'anubis__484',
#   'anubis__519',
#   'anubis__704',
#   'anubis__864',
#   'anubis__909',
#   'anubis__944',
#   'anubis__990',
#   'anubis__991',
#   'anubis__1051',
#   'anubis__1099',
#   'anubis__1140',
#   'anubis__1142',
#   'anubis__1150',
#   'anubis__1273',
#   'anubis__1412',
#   'anubis__1418',
#   'anubis__1422',
#   'anubis__1495',
#   'anubis__1500',
#   'anubis__1503',
#   'anubis__1514'],
#  'Dpo_cdhit_328': ['anubis__1023',
#   'anubis__303',
#   'anubis__437',
#   'anubis__1478'],
#  'Dpo_cdhit_329': ['ppt__247'],
#  'Dpo_cdhit_330': ['ppt__1033', 'ppt__6169'],
#  'Dpo_cdhit_331': ['ppt__454',
#   'ppt__621',
#   'ppt__947',
#   'ppt__1348',
#   'minibatch__1677',
#   'ppt__3402',
#   'ppt__3536',
#   'ppt__3539',
#   'ppt__4284',
#   'ppt__4287',
#   'ppt__4360',
#   'ppt__4362',
#   'ppt__4540',
#   'ppt__4779',
#   'ppt__4923',
#   'ppt__5043',
#   'ppt__5243',
#   'ppt__5568',
#   'ppt__6156',
#   'minibatch__1861',
#   'minibatch__1891',
#   'ppt__6911',
#   'minibatch__797',
#   'minibatch__2113'],
#  'Dpo_cdhit_332': ['ppt__1393', 'ppt__6271', 'ppt__6510'],
#  'Dpo_cdhit_333': ['ppt__162',
#   'ppt__250',
#   'ppt__542',
#   'ppt__545',
#   'ppt__818',
#   'ppt__1035',
#   'anubis__387',
#   'ppt__2336',
#   'anubis__912',
#   'anubis__1052',
#   'minibatch__1854',
#   'anubis__1374',
#   'ppt__6604',
#   'minibatch__630',
#   'ppt__6848',
#   'anubis__198',
#   'anubis__457',
#   'anubis__566'],
#  'Dpo_cdhit_334': ['anubis__134',
#   'anubis__139',
#   'anubis__22',
#   'anubis__30',
#   'anubis__78',
#   'anubis__97',
#   'anubis__106',
#   'anubis__112',
#   'anubis__148',
#   'anubis__203',
#   'anubis__297',
#   'anubis__350',
#   'anubis__364',
#   'anubis__366',
#   'anubis__397',
#   'anubis__518',
#   'anubis__554',
#   'anubis__603',
#   'anubis__622',
#   'anubis__658',
#   'anubis__691',
#   'anubis__700',
#   'anubis__730',
#   'anubis__738',
#   'anubis__970',
#   'anubis__978',
#   'anubis__984',
#   'anubis__1006',
#   'anubis__1050',
#   'anubis__1058',
#   'anubis__1087',
#   'anubis__1119',
#   'anubis__1354',
#   'anubis__1509',
#   'anubis__1530',
#   'anubis__1538',
#   'anubis__1596'],
#  'Dpo_cdhit_335': ['minibatch__1724'],
#  'Dpo_cdhit_336': ['anubis_return__321',
#   'anubis_return__976',
#   'anubis_return__1210',
#   'anubis_return__1655',
#   'anubis_return__1699',
#   'anubis_return__1713',
#   'anubis_return__2100',
#   'anubis_return__2201',
#   'anubis_return__2333',
#   'anubis_return__2449',
#   'anubis_return__2451',
#   'anubis_return__2680',
#   'anubis_return__2777',
#   'anubis_return__2794',
#   'anubis_return__3010',
#   'anubis_return__3030',
#   'anubis_return__3547',
#   'anubis_return__3919',
#   'anubis_return__4287'],
#  'Dpo_cdhit_337': ['anubis_return__1659', 'anubis_return__4189'],
#  'Dpo_cdhit_338': ['ppt__1604'],
#  'Dpo_cdhit_339': ['ppt__1303'],
#  'Dpo_cdhit_340': ['ppt__2892'],
#  'Dpo_cdhit_341': ['ppt__3972'],
#  'Dpo_cdhit_342': ['ppt__754'],
#  'Dpo_cdhit_343': ['ppt__2758', 'ppt__4704', 'minibatch__1564'],
#  'Dpo_cdhit_344': ['anubis__891', 'anubis__1281'],
#  'Dpo_cdhit_345': ['ppt__5015',
#   'ppt__5290',
#   'ppt__5471',
#   'ppt__6469',
#   'ppt__7122'],
#  'Dpo_cdhit_346': ['ppt__2531', 'ppt__5035', 'minibatch__1380'],
#  'Dpo_cdhit_347': ['ppt__6404'],
#  'Dpo_cdhit_348': ['anubis__531',
#   'minibatch__877',
#   'anubis__265',
#   'anubis__459',
#   'anubis__1186'],
#  'Dpo_cdhit_349': ['ppt__5672'],
#  'Dpo_cdhit_350': ['minibatch__1292'],
#  'Dpo_cdhit_351': ['ppt__1',
#   'ppt__3380',
#   'ppt__5182',
#   'minibatch__1593',
#   'minibatch__719',
#   'minibatch__1387'],
#  'Dpo_cdhit_352': ['ppt__3131', 'ppt__3213', 'anubis_return__4127'],
#  'Dpo_cdhit_353': ['ppt__964',
#   'ppt__2271',
#   'ppt__3234',
#   'ppt__3811',
#   'minibatch__1192',
#   'ppt__4668',
#   'minibatch__1919',
#   'anubis__1156',
#   'anubis_return__451',
#   'anubis_return__2470'],
#  'Dpo_cdhit_354': ['minibatch__1875'],
#  'Dpo_cdhit_355': ['ppt__585'],
#  'Dpo_cdhit_356': ['ppt__1259',
#   'ppt__4067',
#   'ppt__4068',
#   'ppt__4787',
#   'minibatch__237',
#   'ppt__4873',
#   'ppt__5089',
#   'ppt__5445',
#   'ppt__6155',
#   'minibatch__1420',
#   'minibatch__1719',
#   'minibatch__2164'],
#  'Dpo_cdhit_357': ['ppt__5412'],
#  'Dpo_cdhit_358': ['ppt__965',
#   'anubis__179',
#   'ppt__1055',
#   'anubis__445',
#   'ppt__2276',
#   'ppt__2823',
#   'anubis__556',
#   'ppt__2948',
#   'ppt__3016',
#   'anubis__655',
#   'anubis__770',
#   'anubis__771',
#   'anubis__939',
#   'anubis__959',
#   'anubis__1064',
#   'anubis__1376',
#   'anubis__1548',
#   'anubis_return__3663'],
#  'Dpo_cdhit_359': ['ppt__2894'],
#  'Dpo_cdhit_360': ['ppt__5090'],
#  'Dpo_cdhit_361': ['ppt__236',
#   'ppt__237',
#   'minibatch__31',
#   'ppt__1294',
#   'ppt__2341',
#   'ppt__3300',
#   'ppt__3358',
#   'ppt__3677',
#   'ppt__4095',
#   'ppt__4739',
#   'minibatch__38',
#   'ppt__5237',
#   'ppt__5548',
#   'minibatch__1300',
#   'ppt__5969',
#   'ppt__6015',
#   'ppt__6217',
#   'ppt__6342',
#   'ppt__6995',
#   'minibatch__518',
#   'minibatch__1734',
#   'minibatch__1778'],
#  'Dpo_cdhit_362': ['minibatch__1644'],
#  'Dpo_cdhit_363': ['anubis__1', 'anubis_return__2567'],
#  'Dpo_cdhit_364': ['ppt__2893'],
#  'Dpo_cdhit_365': ['ppt__1131',
#   'ppt__2246',
#   'ppt__3524',
#   'ppt__6093',
#   'ppt__7098'],
#  'Dpo_cdhit_366': ['anubis__1617'],
#  'Dpo_cdhit_367': ['ppt__2337', 'ppt__6111', 'anubis_return__1170'],
#  'Dpo_cdhit_368': ['ppt__2443',
#   'anubis__16',
#   'anubis__34',
#   'anubis__64',
#   'anubis__65',
#   'anubis__66',
#   'anubis__67',
#   'anubis__102',
#   'anubis__103',
#   'anubis__111',
#   'anubis__128',
#   'minibatch__2056',
#   'anubis__153',
#   'minibatch__1884',
#   'anubis__162',
#   'anubis__196',
#   'anubis__197',
#   'anubis__236',
#   'anubis__254',
#   'anubis__317',
#   'anubis__335',
#   'anubis__337',
#   'anubis__345',
#   'anubis__376',
#   'anubis__377',
#   'anubis__378',
#   'minibatch__443',
#   'anubis__399',
#   'anubis__411',
#   'anubis__424',
#   'anubis__443',
#   'anubis__491',
#   'anubis__567',
#   'anubis__568',
#   'anubis__624',
#   'anubis__648',
#   'anubis__649',
#   'anubis__650',
#   'anubis__662',
#   'anubis__663',
#   'anubis__665',
#   'anubis__666',
#   'ppt__3498',
#   'anubis__737',
#   'anubis__741',
#   'anubis__757',
#   'anubis__786',
#   'anubis__787',
#   'anubis__851',
#   'anubis__879',
#   'anubis__880',
#   'anubis__935',
#   'anubis__936',
#   'minibatch__1737',
#   'anubis__1009',
#   'anubis__1040',
#   'anubis__1049',
#   'anubis__1173',
#   'anubis__42',
#   'anubis__43',
#   'anubis__1303',
#   'anubis__1330',
#   'anubis__1402',
#   'anubis__1413',
#   'anubis__1442',
#   'anubis__1459',
#   'ppt__6615',
#   'ppt__6766',
#   'anubis__1572',
#   'anubis__1575',
#   'anubis__1620',
#   'minibatch__248',
#   'minibatch__792',
#   'minibatch__1587',
#   'minibatch__1712',
#   'minibatch__1934',
#   'minibatch__1958',
#   'minibatch__2054',
#   'anubis__99',
#   'anubis__152',
#   'anubis__255',
#   'anubis__338',
#   'anubis__412',
#   'anubis__489',
#   'anubis__490',
#   'anubis__696',
#   'anubis__1036',
#   'anubis__1039',
#   'anubis__1127',
#   'anubis__1167',
#   'anubis__1224',
#   'anubis__1241',
#   'anubis__1259',
#   'anubis__1304',
#   'anubis__1393',
#   'anubis__1408',
#   'anubis__1454',
#   'anubis__1581',
#   'anubis__1637',
#   'anubis_return__1233'],
#  'Dpo_cdhit_369': ['anubis__501',
#   'anubis__813',
#   'anubis__981',
#   'anubis__1045',
#   'anubis__171',
#   'anubis__220',
#   'anubis__384',
#   'anubis__642',
#   'anubis__1131',
#   'anubis__1515'],
#  'Dpo_cdhit_370': ['anubis_return__3811'],
#  'Dpo_cdhit_371': ['anubis_return__2196', 'anubis_return__3073'],
#  'Dpo_cdhit_372': ['ppt__5101', 'anubis_return__2800', 'anubis_return__2802'],
#  'Dpo_cdhit_373': ['anubis__1132'],
#  'Dpo_cdhit_374': ['anubis__1366'],
#  'Dpo_cdhit_375': ['ppt__1986', 'minibatch__464', 'ppt__6482'],
#  'Dpo_cdhit_376': ['minibatch__50',
#   'minibatch__1421',
#   'ppt__1253',
#   'ppt__1574',
#   'ppt__2772',
#   'ppt__5254'],
#  'Dpo_cdhit_377': ['ppt__1015', 'ppt__1860', 'ppt__6022', 'minibatch__2052'],
#  'Dpo_cdhit_378': ['ppt__5020'],
#  'Dpo_cdhit_379': ['ppt__981', 'anubis__1416'],
#  'Dpo_cdhit_380': ['ppt__1443',
#   'ppt__2418',
#   'ppt__3111',
#   'ppt__4172',
#   'ppt__7150',
#   'ppt__1980',
#   'ppt__3702',
#   'anubis__1482',
#   'anubis_return__691',
#   'anubis_return__1222',
#   'anubis_return__1338',
#   'anubis_return__2234',
#   'anubis_return__4305'],
#  'Dpo_cdhit_381': ['ppt__133',
#   'ppt__2737',
#   'minibatch__1186',
#   'minibatch__1153',
#   'anubis_return__870',
#   'anubis_return__1319'],
#  'Dpo_cdhit_382': ['ppt__557',
#   'ppt__2138',
#   'ppt__3880',
#   'ppt__4672',
#   'ppt__4863',
#   'ppt__6924',
#   'minibatch__986'],
#  'Dpo_cdhit_383': ['minibatch__1426', 'minibatch__1260'],
#  'Dpo_cdhit_384': ['ppt__484',
#   'ppt__93',
#   'ppt__96',
#   'ppt__313',
#   'ppt__356',
#   'ppt__1146',
#   'ppt__1953',
#   'minibatch__512',
#   'minibatch__556',
#   'minibatch__8',
#   'minibatch__1075',
#   'anubis_return__217'],
#  'Dpo_cdhit_385': ['minibatch__2047'],
#  'Dpo_cdhit_386': ['ppt__4771', 'anubis__1309', 'anubis_return__2579'],
#  'Dpo_cdhit_387': ['anubis__389',
#   'anubis__1506',
#   'anubis__617',
#   'anubis__823'],
#  'Dpo_cdhit_388': ['ppt__5797'],
#  'Dpo_cdhit_389': ['ppt__163',
#   'ppt__544',
#   'minibatch__1435',
#   'minibatch__2112'],
#  'Dpo_cdhit_390': ['ppt__483', 'ppt__2752', 'ppt__5610'],
#  'Dpo_cdhit_391': ['ppt__4399'],
#  'Dpo_cdhit_392': ['ppt__1783', 'minibatch__1147', 'minibatch__108'],
#  'Dpo_cdhit_393': ['ppt__1996'],
#  'Dpo_cdhit_394': ['minibatch__608'],
#  'Dpo_cdhit_395': ['anubis__307'],
#  'Dpo_cdhit_396': ['ppt__6180', 'ppt__6345'],
#  'Dpo_cdhit_397': ['anubis_return__169',
#   'anubis_return__833',
#   'anubis_return__834',
#   'anubis_return__914',
#   'anubis_return__992',
#   'anubis_return__2358',
#   'anubis_return__2366',
#   'anubis_return__3208',
#   'anubis_return__3407',
#   'anubis_return__3760'],
#  'Dpo_cdhit_398': ['anubis_return__3045'],
#  'Dpo_cdhit_399': ['minibatch__1237', 'ppt__5505'],
#  'Dpo_cdhit_400': ['ppt__1934'],
#  'Dpo_cdhit_401': ['ppt__5159'],
#  'Dpo_cdhit_402': ['ppt__1802',
#   'ppt__2066',
#   'anubis_return__1792',
#   'anubis_return__2211',
#   'anubis_return__2625',
#   'anubis_return__2878',
#   'anubis_return__2884'],
#  'Dpo_cdhit_403': ['minibatch__1131', 'ppt__4388', 'ppt__5520'],
#  'Dpo_cdhit_404': ['ppt__767',
#   'ppt__1199',
#   'ppt__1978',
#   'ppt__2419',
#   'ppt__3471',
#   'ppt__5279',
#   'minibatch__904',
#   'ppt__6202',
#   'ppt__6204',
#   'minibatch__2158',
#   'anubis_return__4247'],
#  'Dpo_cdhit_405': ['anubis_return__591',
#   'anubis_return__592',
#   'anubis_return__926',
#   'anubis_return__1801',
#   'anubis_return__2682',
#   'anubis_return__2826',
#   'anubis_return__4209'],
#  'Dpo_cdhit_406': ['ppt__3388',
#   'ppt__137',
#   'ppt__331',
#   'ppt__801',
#   'ppt__1278',
#   'ppt__1279',
#   'ppt__1418',
#   'ppt__1420',
#   'ppt__1454',
#   'ppt__1830',
#   'ppt__2471',
#   'ppt__2509',
#   'ppt__2671',
#   'ppt__2825',
#   'ppt__2826',
#   'ppt__2914',
#   'ppt__2922',
#   'ppt__2976',
#   'ppt__3092',
#   'ppt__3344',
#   'ppt__3391',
#   'ppt__3762',
#   'ppt__3898',
#   'ppt__4062',
#   'ppt__4100',
#   'ppt__4518',
#   'ppt__4519',
#   'minibatch__1501',
#   'ppt__5201',
#   'ppt__5204',
#   'ppt__5338',
#   'ppt__5342',
#   'minibatch__306',
#   'minibatch__638',
#   'ppt__5560',
#   'ppt__5677',
#   'ppt__5719',
#   'ppt__5823',
#   'minibatch__2095',
#   'ppt__5858',
#   'ppt__5955',
#   'ppt__5956',
#   'ppt__6040',
#   'ppt__6211',
#   'ppt__6265',
#   'ppt__6375',
#   'ppt__6389',
#   'ppt__6424',
#   'ppt__6618',
#   'minibatch__1132',
#   'ppt__6782',
#   'ppt__6823',
#   'ppt__6969',
#   'minibatch__327',
#   'minibatch__1379',
#   'anubis_return__371'],
#  'Dpo_cdhit_407': ['minibatch__1871',
#   'minibatch__1996',
#   'anubis_return__1077'],
#  'Dpo_cdhit_408': ['anubis_return__1552'],
#  'Dpo_cdhit_409': ['minibatch__183'],
#  'Dpo_cdhit_410': ['anubis_return__2510'],
#  'Dpo_cdhit_411': ['ppt__669', 'ppt__5579'],
#  'Dpo_cdhit_412': ['ppt__3853', 'ppt__5587'],
#  'Dpo_cdhit_413': ['anubis__229',
#   'ppt__3935',
#   'anubis_return__511',
#   'anubis_return__828',
#   'anubis_return__1827'],
#  'Dpo_cdhit_414': ['minibatch__1978', 'ppt__5742', 'ppt__6055'],
#  'Dpo_cdhit_415': ['ppt__6307', 'anubis__1629'],
#  'Dpo_cdhit_416': ['anubis_return__45',
#   'anubis_return__1096',
#   'anubis_return__2240',
#   'anubis_return__3802'],
#  'Dpo_cdhit_417': ['anubis_return__1313'],
#  'Dpo_cdhit_418': ['ppt__5024', 'anubis__29'],
#  'Dpo_cdhit_419': ['anubis__1610'],
#  'Dpo_cdhit_420': ['ppt__6582', 'anubis_return__3926'],
#  'Dpo_cdhit_421': ['ppt__125',
#   'ppt__832',
#   'ppt__943',
#   'ppt__1976',
#   'ppt__3723',
#   'ppt__3727',
#   'minibatch__295',
#   'minibatch__1515',
#   'minibatch__148',
#   'minibatch__950',
#   'minibatch__2005',
#   'minibatch__1709',
#   'minibatch__1307',
#   'ppt__6606',
#   'ppt__6894',
#   'minibatch__1933'],
#  'Dpo_cdhit_422': ['ppt__3465', 'anubis__1460', 'anubis__1543'],
#  'Dpo_cdhit_423': ['ppt__519', 'minibatch__109', 'anubis_return__857'],
#  'Dpo_cdhit_424': ['anubis__1348'],
#  'Dpo_cdhit_425': ['ppt__4169', 'minibatch__913'],
#  'Dpo_cdhit_426': ['anubis_return__3034'],
#  'Dpo_cdhit_427': ['ppt__935'],
#  'Dpo_cdhit_428': ['ppt__2730', 'minibatch__172', 'ppt__6213'],
#  'Dpo_cdhit_429': ['minibatch__963', 'minibatch__629'],
#  'Dpo_cdhit_430': ['minibatch__1844',
#   'ppt__3918',
#   'ppt__5076',
#   'ppt__6678',
#   'minibatch__1284',
#   'anubis_return__348',
#   'anubis_return__1344',
#   'anubis_return__1345'],
#  'Dpo_cdhit_431': ['anubis_return__904'],
#  'Dpo_cdhit_432': ['anubis_return__942'],
#  'Dpo_cdhit_433': ['ppt__6620'],
#  'Dpo_cdhit_434': ['anubis__1632'],
#  'Dpo_cdhit_435': ['anubis__170'],
#  'Dpo_cdhit_436': ['anubis__811', 'anubis__270', 'anubis__761'],
#  'Dpo_cdhit_437': ['ppt__1820'],
#  'Dpo_cdhit_438': ['ppt__6170'],
#  'Dpo_cdhit_439': ['ppt__2542'],
#  'Dpo_cdhit_440': ['anubis__998',
#   'anubis__999',
#   'anubis__1321',
#   'anubis__1601',
#   'anubis__1655'],
#  'Dpo_cdhit_441': ['anubis_return__735'],
# ...
#   'anubis__316',
#   'anubis__46',
#   'anubis__75',
#   'anubis__463',
#   'anubis__600',
#   'anubis__1028',
#   'anubis__1161',
#   'anubis__1544'],
#  'Dpo_cdhit_775': ['anubis__1175',
#   'anubis_return__3015',
#   'anubis_return__3103'],
#  'Dpo_cdhit_776': ['ppt__6575'],
#  'Dpo_cdhit_777': ['anubis_return__1153',
#   'anubis_return__2900',
#   'anubis_return__3307'],
#  'Dpo_cdhit_778': ['anubis_return__4260'],
#  'Dpo_cdhit_779': ['minibatch__1449'],
#  'Dpo_cdhit_780': ['ppt__1554', 'anubis_return__760'],
#  'Dpo_cdhit_781': ['ppt__2633'],
#  'Dpo_cdhit_782': ['anubis_return__3411'],
#  'Dpo_cdhit_783': ['ppt__269'],
#  'Dpo_cdhit_784': ['anubis__1016'],
#  'Dpo_cdhit_785': ['ppt__2547'],
#  'Dpo_cdhit_786': ['anubis__865'],
#  'Dpo_cdhit_787': ['ppt__21',
#   'ppt__597',
#   'ppt__3045',
#   'ppt__3473',
#   'ppt__3892'],
#  'Dpo_cdhit_788': ['ppt__849', 'ppt__1273', 'ppt__4484', 'ppt__5366'],
#  'Dpo_cdhit_789': ['ppt__3024', 'ppt__5000'],
#  'Dpo_cdhit_790': ['ppt__4589',
#   'minibatch__1532',
#   'ppt__6687',
#   'ppt__6688',
#   'ppt__7147',
#   'minibatch__222'],
#  'Dpo_cdhit_791': ['ppt__2519', 'anubis_return__1272'],
#  'Dpo_cdhit_792': ['ppt__2563'],
#  'Dpo_cdhit_793': ['ppt__3396'],
#  'Dpo_cdhit_794': ['ppt__5151', 'ppt__6798'],
#  'Dpo_cdhit_795': ['ppt__488',
#   'ppt__494',
#   'ppt__1507',
#   'ppt__1518',
#   'minibatch__1385',
#   'ppt__3085',
#   'ppt__4118',
#   'minibatch__626',
#   'ppt__4924',
#   'ppt__5069',
#   'ppt__5784',
#   'minibatch__1993'],
#  'Dpo_cdhit_796': ['anubis__32',
#   'anubis__45',
#   'anubis__47',
#   'anubis__74',
#   'anubis__86',
#   'anubis__88',
#   'anubis__104',
#   'anubis__126',
#   'anubis__141',
#   'anubis__146',
#   'anubis__160',
#   'anubis__166',
#   'anubis__173',
#   'anubis__178',
#   'anubis__180',
#   'anubis__199',
#   'anubis__201',
#   'anubis__208',
#   'anubis__231',
#   'anubis__233',
#   'anubis__237',
#   'anubis__239',
#   'anubis__293',
#   'anubis__298',
#   'anubis__323',
#   'anubis__352',
#   'anubis__413',
#   'anubis__466',
#   'anubis__469',
#   'anubis__497',
#   'anubis__526',
#   'anubis__575',
#   'anubis__595',
#   'anubis__613',
#   'anubis__802',
#   'anubis__881',
#   'anubis__884',
#   'anubis__908',
#   'anubis__925',
#   'anubis__956',
#   'anubis__962',
#   'anubis__980',
#   'anubis__1056',
#   'anubis__1061',
#   'anubis__1124',
#   'anubis__1129',
#   'anubis__1151',
#   'anubis__1218',
#   'anubis__1270',
#   'anubis__1305',
#   'anubis__1344',
#   'anubis__1397',
#   'anubis__1441',
#   'anubis__1485',
#   'anubis__1492',
#   'anubis__1558',
#   'anubis__1573'],
#  'Dpo_cdhit_797': ['minibatch__1707'],
#  'Dpo_cdhit_798': ['anubis__260'],
#  'Dpo_cdhit_799': ['ppt__4835'],
#  'Dpo_cdhit_800': ['anubis__14',
#   'anubis__18',
#   'anubis__24',
#   'anubis__36',
#   'anubis__39',
#   'anubis__52',
#   'anubis__56',
#   'anubis__84',
#   'anubis__93',
#   'anubis__147',
#   'anubis__169',
#   'anubis__175',
#   'anubis__204',
#   'anubis__209',
#   'anubis__212',
#   'anubis__216',
#   'anubis__246',
#   'anubis__247',
#   'anubis__253',
#   'anubis__261',
#   'anubis__285',
#   'anubis__296',
#   'anubis__304',
#   'anubis__309',
#   'anubis__379',
#   'anubis__380',
#   'anubis__395',
#   'anubis__421',
#   'anubis__423',
#   'anubis__465',
#   'anubis__492',
#   'anubis__505',
#   'anubis__520',
#   'anubis__524',
#   'anubis__537',
#   'anubis__539',
#   'anubis__541',
#   'anubis__542',
#   'anubis__543',
#   'anubis__573',
#   'anubis__583',
#   'anubis__587',
#   'anubis__589',
#   'anubis__621',
#   'anubis__629',
#   'anubis__657',
#   'anubis__669',
#   'anubis__694',
#   'anubis__702',
#   'anubis__729',
#   'anubis__744',
#   'anubis__745',
#   'anubis__756',
#   'anubis__793',
#   'anubis__821',
#   'anubis__859',
#   'anubis__861',
#   'anubis__863',
#   'anubis__80',
#   'anubis__294',
#   'anubis__949',
#   'anubis__960',
#   'anubis__993',
#   'anubis__1011',
#   'anubis__1046',
#   'anubis__1048',
#   'anubis__1074',
#   'anubis__1078',
#   'anubis__1139',
#   'anubis__1154',
#   'anubis__1219',
#   'anubis__1261',
#   'anubis__1268',
#   'anubis__1278',
#   'anubis__1286',
#   'anubis__1290',
#   'anubis__1308',
#   'anubis__1319',
#   'anubis__1320',
#   'anubis__1342',
#   'anubis__1451',
#   'anubis__1466',
#   'anubis__1469',
#   'anubis__1480',
#   'anubis__1481',
#   'anubis__1483',
#   'anubis__1496',
#   'anubis__1536',
#   'anubis__1545',
#   'anubis__1547',
#   'anubis__1593',
#   'anubis__1595',
#   'anubis__1606',
#   'anubis__1613',
#   'anubis__1625',
#   'anubis__1633',
#   'anubis__1388',
#   'anubis__1566',
#   'anubis__482',
#   'anubis__760',
#   'anubis__1287',
#   'anubis__1346'],
#  'Dpo_cdhit_801': ['anubis__571',
#   'anubis__951',
#   'anubis__1464',
#   'anubis__1465'],
#  'Dpo_cdhit_802': ['anubis__952', 'anubis__1279'],
#  'Dpo_cdhit_803': ['anubis_return__898', 'anubis_return__2265'],
#  'Dpo_cdhit_804': ['anubis__164', 'anubis__1285', 'anubis__473'],
#  'Dpo_cdhit_805': ['anubis_return__3887'],
#  'Dpo_cdhit_806': ['ppt__526', 'ppt__2097'],
#  'Dpo_cdhit_807': ['anubis__493'],
#  'Dpo_cdhit_808': ['anubis__532'],
#  'Dpo_cdhit_809': ['anubis__451', 'anubis__1153'],
#  'Dpo_cdhit_810': ['ppt__6616', 'ppt__6729', 'ppt__7152'],
#  'Dpo_cdhit_811': ['anubis__1122'],
#  'Dpo_cdhit_812': ['minibatch__144', 'minibatch__784'],
#  'Dpo_cdhit_813': ['anubis_return__441', 'anubis_return__490'],
#  'Dpo_cdhit_814': ['ppt__2114'],
#  'Dpo_cdhit_815': ['ppt__2179'],
#  'Dpo_cdhit_816': ['ppt__4856', 'ppt__4855', 'anubis_return__2636'],
#  'Dpo_cdhit_817': ['ppt__3235'],
#  'Dpo_cdhit_818': ['anubis_return__2634'],
#  'Dpo_cdhit_819': ['minibatch__855', 'minibatch__1222'],
#  'Dpo_cdhit_820': ['anubis__351',
#   'anubis__440',
#   'anubis__1158',
#   'anubis__1654'],
#  'Dpo_cdhit_821': ['anubis_return__399'],
#  'Dpo_cdhit_822': ['anubis_return__3346'],
#  'Dpo_cdhit_823': ['ppt__2903'],
#  'Dpo_cdhit_824': ['ppt__196',
#   'ppt__1599',
#   'ppt__1629',
#   'ppt__1815',
#   'ppt__2513',
#   'ppt__3282',
#   'ppt__4595',
#   'ppt__5071'],
#  'Dpo_cdhit_825': ['ppt__6407'],
#  'Dpo_cdhit_826': ['ppt__4647'],
#  'Dpo_cdhit_827': ['ppt__4427'],
#  'Dpo_cdhit_828': ['anubis__362',
#   'anubis__15',
#   'anubis__61',
#   'anubis__1363',
#   'anubis__857',
#   'anubis__929'],
#  'Dpo_cdhit_829': ['ppt__3361'],
#  'Dpo_cdhit_830': ['ppt__5865', 'ppt__5946'],
#  'Dpo_cdhit_831': ['ppt__7006'],
#  'Dpo_cdhit_832': ['ppt__201'],
#  'Dpo_cdhit_833': ['anubis_return__1080', 'anubis_return__2844'],
#  'Dpo_cdhit_834': ['ppt__1248'],
#  'Dpo_cdhit_835': ['ppt__6466'],
#  'Dpo_cdhit_836': ['ppt__3792'],
#  'Dpo_cdhit_837': ['anubis__0',
#   'anubis__60',
#   'anubis__73',
#   'anubis__159',
#   'anubis__186',
#   'anubis__207',
#   'anubis__221',
#   'anubis__226',
#   'anubis__263',
#   'anubis__269',
#   'anubis__281',
#   'anubis__306',
#   'anubis__313',
#   'anubis__320',
#   'anubis__347',
#   'anubis__371',
#   'anubis__438',
#   'anubis__441',
#   'anubis__448',
#   'anubis__462',
#   'anubis__464',
#   'anubis__467',
#   'anubis__495',
#   'anubis__525',
#   'anubis__540',
#   'anubis__572',
#   'anubis__588',
#   'anubis__594',
#   'anubis__630',
#   'anubis__652',
#   'anubis__668',
#   'anubis__681',
#   'anubis__717',
#   'anubis__776',
#   'anubis__862',
#   'anubis__874',
#   'anubis__886',
#   'anubis__888',
#   'anubis__898',
#   'anubis__914',
#   'anubis__917',
#   'anubis__923',
#   'anubis__953',
#   'anubis__1020',
#   'anubis__1059',
#   'anubis__1066',
#   'anubis__1070',
#   'anubis__1071',
#   'anubis__1106',
#   'anubis__1144',
#   'anubis__1147',
#   'anubis__1202',
#   'anubis__1250',
#   'anubis__1256',
#   'anubis__1267',
#   'anubis__1280',
#   'anubis__1294',
#   'anubis__1428',
#   'anubis__1452',
#   'anubis__1455',
#   'anubis__1484',
#   'anubis__1493',
#   'anubis__1505',
#   'anubis__1518',
#   'anubis__1519',
#   'anubis__1541',
#   'anubis__1576',
#   'anubis__1583',
#   'anubis__1584',
#   'anubis__1585',
#   'anubis__1611',
#   'anubis__1390'],
#  'Dpo_cdhit_838': ['ppt__2036'],
#  'Dpo_cdhit_839': ['anubis_return__53',
#   'anubis_return__277',
#   'anubis_return__292',
#   'anubis_return__353',
#   'anubis_return__801',
#   'anubis_return__809',
#   'anubis_return__1967',
#   'anubis_return__4069'],
#  'Dpo_cdhit_840': ['ppt__3916', 'ppt__5288'],
#  'Dpo_cdhit_841': ['anubis__1231'],
#  'Dpo_cdhit_842': ['ppt__522',
#   'ppt__528',
#   'ppt__1308',
#   'ppt__1376',
#   'ppt__1407',
#   'ppt__2606',
#   'ppt__6867'],
#  'Dpo_cdhit_843': ['ppt__6925'],
#  'Dpo_cdhit_844': ['ppt__1579', 'ppt__3107'],
#  'Dpo_cdhit_845': ['ppt__3945', 'ppt__6930'],
#  'Dpo_cdhit_846': ['ppt__4064'],
#  'Dpo_cdhit_847': ['ppt__4858'],
#  'Dpo_cdhit_848': ['anubis__1086'],
#  'Dpo_cdhit_849': ['anubis_return__332',
#   'anubis_return__520',
#   'anubis_return__920',
#   'anubis_return__1007',
#   'anubis_return__1580'],
#  'Dpo_cdhit_850': ['ppt__1382', 'ppt__3846'],
#  'Dpo_cdhit_851': ['ppt__84', 'ppt__6592', 'ppt__6856'],
#  'Dpo_cdhit_852': ['anubis__1126'],
#  'Dpo_cdhit_853': ['ppt__68',
#   'ppt__192',
#   'ppt__249',
#   'ppt__538',
#   'ppt__1054',
#   'ppt__2581',
#   'ppt__4492',
#   'ppt__4772',
#   'ppt__5049',
#   'ppt__5065',
#   'ppt__6957',
#   'ppt__6981'],
#  'Dpo_cdhit_854': ['ppt__864'],
#  'Dpo_cdhit_855': ['ppt__4273'],
#  'Dpo_cdhit_856': ['ppt__4512', 'anubis_return__2648'],
#  'Dpo_cdhit_857': ['anubis__187'],
#  'Dpo_cdhit_858': ['ppt__4795'],
#  'Dpo_cdhit_859': ['minibatch__931'],
#  'Dpo_cdhit_860': ['ppt__1966'],
#  'Dpo_cdhit_861': ['ppt__4498'],
#  'Dpo_cdhit_862': ['minibatch__1755', 'anubis_return__2639'],
#  'Dpo_cdhit_863': ['ppt__5100'],
#  'Dpo_cdhit_864': ['anubis_return__2839'],
#  'Dpo_cdhit_865': ['ppt__1169'],
#  'Dpo_cdhit_866': ['anubis__1394',
#   'anubis__707',
#   'anubis__718',
#   'anubis__899',
#   'anubis__1013',
#   'anubis__1507'],
#  'Dpo_cdhit_867': ['ppt__1769', 'ppt__3357', 'ppt__5721', 'ppt__6012'],
#  'Dpo_cdhit_868': ['ppt__934'],
#  'Dpo_cdhit_869': ['ppt__4638', 'ppt__5097'],
#  'Dpo_cdhit_870': ['anubis__676'],
#  'Dpo_cdhit_871': ['anubis_return__1868'],
#  'Dpo_cdhit_872': ['ppt__1072', 'ppt__1766'],
#  'Dpo_cdhit_873': ['ppt__5773', 'minibatch__1573'],
#  'Dpo_cdhit_874': ['anubis__1378', 'anubis__343'],
#  'Dpo_cdhit_875': ['ppt__3878'],
#  'Dpo_cdhit_876': ['ppt__2118'],
#  'Dpo_cdhit_877': ['ppt__1236'],
#  'Dpo_cdhit_878': ['ppt__1625'],
#  'Dpo_cdhit_879': ['ppt__3501'],
#  'Dpo_cdhit_880': ['ppt__6505'],
#  'Dpo_cdhit_881': ['ppt__6700'],
#  'Dpo_cdhit_882': ['ppt__184',
#   'ppt__475',
#   'ppt__527',
#   'ppt__923',
#   'ppt__1573',
#   'ppt__1653',
#   'ppt__1682',
#   'ppt__1725',
#   'ppt__1882',
#   'ppt__2228',
#   'ppt__3310',
#   'ppt__3671',
#   'ppt__3751',
#   'ppt__3999',
#   'ppt__4511',
#   'ppt__5498',
#   'ppt__5674',
#   'ppt__5795',
#   'ppt__5974',
#   'ppt__6085'],
#  'Dpo_cdhit_883': ['minibatch__481'],
#  'Dpo_cdhit_884': ['ppt__1427',
#   'ppt__2568',
#   'ppt__2941',
#   'ppt__3632',
#   'ppt__4001',
#   'ppt__6528',
#   'ppt__6533'],
#  'Dpo_cdhit_885': ['ppt__6289', 'ppt__6978'],
#  'Dpo_cdhit_886': ['ppt__6443'],
#  'Dpo_cdhit_887': ['anubis__1177'],
#  'Dpo_cdhit_888': ['ppt__1380'],
#  'Dpo_cdhit_889': ['anubis_return__3729'],
#  'Dpo_cdhit_890': ['ppt__780'],
#  'Dpo_cdhit_891': ['ppt__629', 'anubis_return__1335'],
#  'Dpo_cdhit_892': ['anubis__182', 'ppt__2229', 'ppt__2572', 'ppt__3444'],
#  'Dpo_cdhit_893': ['minibatch__2067'],
#  'Dpo_cdhit_894': ['ppt__2989'],
#  'Dpo_cdhit_895': ['minibatch__690'],
#  'Dpo_cdhit_896': ['ppt__4654'],
#  'Dpo_cdhit_897': ['ppt__115',
#   'ppt__2187',
#   'ppt__3445',
#   'ppt__3486',
#   'ppt__4194',
#   'ppt__5973',
#   'minibatch__1233'],
#  'Dpo_cdhit_898': ['ppt__3932', 'anubis_return__3560'],
#  'Dpo_cdhit_899': ['minibatch__1136'],
#  'Dpo_cdhit_900': ['anubis__1238'],
#  'Dpo_cdhit_901': ['ppt__3728'],
#  'Dpo_cdhit_902': ['minibatch__861'],
#  'Dpo_cdhit_903': ['anubis__671'],
#  'Dpo_cdhit_904': ['anubis_return__245',
#   'anubis_return__2360',
#   'anubis_return__2559'],
#  'Dpo_cdhit_905': ['minibatch__141'],
#  'Dpo_cdhit_906': ['ppt__1698'],
#  'Dpo_cdhit_907': ['minibatch__1111'],
#  'Dpo_cdhit_908': ['anubis__168',
#   'anubis__230',
#   'anubis__283',
#   'anubis__982',
#   'anubis__434',
#   'anubis__1180',
#   'anubis__1444',
#   'anubis__1470'],
#  'Dpo_cdhit_909': ['minibatch__1217'],
#  'Dpo_cdhit_910': ['ppt__561',
#   'ppt__1850',
#   'ppt__2043',
#   'ppt__3423',
#   'ppt__4240',
#   'ppt__5857',
#   'ppt__6246',
#   'ppt__6983'],
#  'Dpo_cdhit_911': ['ppt__1360'],
#  'Dpo_cdhit_912': ['ppt__2218', 'anubis_return__745'],
#  'Dpo_cdhit_913': ['minibatch__2061', 'minibatch__372'],
#  'Dpo_cdhit_914': ['minibatch__1811'],
#  'Dpo_cdhit_915': ['anubis__488'],
#  'Dpo_cdhit_916': ['ppt__5692'],
#  'Dpo_cdhit_917': ['anubis_return__2588'],
#  'Dpo_cdhit_918': ['anubis_return__4275'],
#  'Dpo_cdhit_919': ['anubis_return__1865'],
#  'Dpo_cdhit_920': ['ppt__833'],
#  'Dpo_cdhit_921': ['ppt__4476', 'ppt__5715'],
#  'Dpo_cdhit_922': ['anubis__154'],
#  'Dpo_cdhit_923': ['ppt__4550'],
#  'Dpo_cdhit_924': ['ppt__6569'],
#  'Dpo_cdhit_925': ['ppt__753', 'ppt__4916', 'ppt__4990', 'ppt__7015'],
#  'Dpo_cdhit_926': ['anubis__1038'],
#  'Dpo_cdhit_927': ['ppt__512'],
#  'Dpo_cdhit_928': ['ppt__1387'],
#  'Dpo_cdhit_929': ['ppt__5901', 'minibatch__1174', 'ppt__6631'],
#  'Dpo_cdhit_930': ['ppt__5128'],
#  'Dpo_cdhit_931': ['ppt__5710'],
#  'Dpo_cdhit_932': ['minibatch__1396', 'minibatch__1989'],
#  'Dpo_cdhit_933': ['anubis__248'],
#  'Dpo_cdhit_934': ['ppt__5608', 'anubis_return__3171'],
#  'Dpo_cdhit_935': ['ppt__6119', 'anubis_return__3879'],
#  'Dpo_cdhit_936': ['anubis__37',
#   'anubis__114',
#   'anubis__190',
#   'anubis__275',
#   'anubis__295',
#   'anubis__536',
#   'anubis__563',
#   'anubis__654',
#   'anubis__804',
#   'anubis__807',
#   'anubis__892',
#   'anubis__919',
#   'anubis__946',
#   'anubis__1323',
#   'anubis__1571',
#   'anubis__33',
#   'anubis__407',
#   'anubis__470',
#   'anubis__523',
#   'anubis__584',
#   'anubis__585',
#   'anubis__596',
#   'anubis__733',
#   'anubis__742',
#   'anubis__842',
#   'anubis__869',
#   'anubis__975',
#   'anubis__1063',
#   'anubis__1084',
#   'anubis__1188',
#   'anubis__1282',
#   'anubis__1350',
#   'anubis__1419',
#   'anubis__1549',
#   'anubis__1582'],
#  'Dpo_cdhit_937': ['ppt__4150'],
#  'Dpo_cdhit_938': ['anubis__988'],
#  'Dpo_cdhit_939': ['anubis_return__2231'],
#  'Dpo_cdhit_940': ['anubis_return__3524'],
#  'Dpo_cdhit_941': ['anubis_return__3644'],
#  'Dpo_cdhit_942': ['ppt__1702'],
#  'Dpo_cdhit_943': ['anubis_return__1971', 'anubis_return__3236'],
#  'Dpo_cdhit_944': ['ppt__3794'],
#  'Dpo_cdhit_945': ['ppt__1823'],
#  'Dpo_cdhit_946': ['ppt__5549'],
#  'Dpo_cdhit_947': ['ppt__5817'],
#  'Dpo_cdhit_948': ['anubis__416'],
#  'Dpo_cdhit_949': ['anubis__1298'],
#  'Dpo_cdhit_950': ['minibatch__1898', 'ppt__2975', 'anubis_return__1529'],
#  'Dpo_cdhit_951': ['anubis_return__84', 'anubis_return__214'],
#  'Dpo_cdhit_952': ['anubis_return__352',
#   'anubis_return__1420',
#   'anubis_return__3437'],
#  'Dpo_cdhit_953': ['anubis_return__2651', 'anubis_return__4161'],
#  'Dpo_cdhit_954': ['ppt__3317'],
#  'Dpo_cdhit_955': ['anubis__653', 'anubis__964'],
#  'Dpo_cdhit_956': ['anubis__628', 'anubis__1564'],
#  'Dpo_cdhit_957': ['anubis_return__3827'],
#  'Dpo_cdhit_958': ['anubis_return__1902'],
#  'Dpo_cdhit_959': ['anubis_return__1997'],
#  'Dpo_cdhit_960': ['anubis__284', 'anubis__522', 'anubis__625'],
#  'Dpo_cdhit_961': ['anubis__1316', 'anubis_return__335', 'anubis_return__517'],
#  'Dpo_cdhit_962': ['anubis_return__2731', 'anubis_return__2732'],
#  'Dpo_cdhit_963': ['anubis_return__2351'],
#  'Dpo_cdhit_964': ['anubis_return__130',
#   'anubis_return__366',
#   'anubis_return__506',
#   'anubis_return__686',
#   'anubis_return__1048',
#   'anubis_return__1075',
#   'anubis_return__1200',
#   'anubis_return__1923',
#   'anubis_return__2312',
#   'anubis_return__3555',
#   'anubis_return__3592',
#   'anubis_return__3960',
#   'anubis_return__4103'],
#  'Dpo_cdhit_965': ['anubis_return__1857'],
#  'Dpo_cdhit_966': ['anubis_return__2973'],
#  'Dpo_cdhit_967': ['anubis_return__3270'],
#  'Dpo_cdhit_968': ['anubis_return__3745'],
#  'Dpo_cdhit_969': ['ppt__4665'],
#  'Dpo_cdhit_970': ['minibatch__1935'],
#  'Dpo_cdhit_971': ['ppt__4763', 'anubis_return__2575'],
#  'Dpo_cdhit_972': ['ppt__2859',
#   'ppt__4462',
#   'anubis_return__1462',
#   'anubis_return__2400'],
#  'Dpo_cdhit_973': ['anubis_return__1312'],
#  'Dpo_cdhit_974': ['anubis_return__1856'],
#  'Dpo_cdhit_975': ['anubis_return__2691'],
#  'Dpo_cdhit_976': ['anubis_return__778'],
#  'Dpo_cdhit_977': ['anubis_return__2319'],
#  'Dpo_cdhit_978': ['anubis_return__1879'],
#  'Dpo_cdhit_979': ['anubis_return__854'],
#  'Dpo_cdhit_980': ['anubis_return__1332'],
#  'Dpo_cdhit_981': ['anubis_return__1951'],
#  'Dpo_cdhit_982': ['ppt__2616', 'ppt__3267'],
#  'Dpo_cdhit_983': ['ppt__6632'],
#  'Dpo_cdhit_984': ['ppt__4308'],
#  'Dpo_cdhit_985': ['minibatch__1069'],
#  'Dpo_cdhit_986': ['ppt__6191'],
#  'Dpo_cdhit_987': ['ppt__1610', 'ppt__2183'],
#  'Dpo_cdhit_988': ['ppt__3379']}

# %%
path_seq = "/media/concha-eloko/Linux/77_strains_phage_project/rbp_work"
path_tmp =  "/media/concha-eloko/Linux/PPT_clean/Seqbased_model/tmp"
labels_blast=["qseqid", "sseqid", "pident", "length", "mismatch", "gapopen", "qstart", "qend", "sstart", "send", "evalue", "bitscore"]

dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_seq}/77_phages_Dpo_domains.2512.multi.fasta", "fasta") if len(record.seq) >0}
set_records = [record for record in SeqIO.parse(f"{path_seq}/77_phages_Dpo_domains.2512.multi.fasta", "fasta") if len(record.seq) > 0]


def tmp_fasta_file(record , path_tmp) :
    name_file = "_".join(record.description.split(" "))
    path_fasta = f"{path_tmp}/{name_file}.fasta"
    length_seq = len(record.seq)
    with open(path_fasta, "w") as outfile :
        outfile.write(f">{record.description}\n{str(record.seq)}")
    return path_fasta , length_seq

def blast_seq(path_fasta, path_DB, path_tmp) :
    file_name = path_fasta.split("/")[-1]
    command = f"blastp -query {path_fasta} -db {path_DB} -out {path_tmp}/{file_name}.blast_out -outfmt 6 -evalue 1e-10"
    blastp_sub = subprocess.Popen(command ,shell = True, stdout = subprocess.PIPE, stderr = subprocess.STDOUT)
    out , err = blastp_sub.communicate()
    return f"{path_tmp}/{file_name}.blast_out"

def get_best_candidate(path_blast_out, length_seq, bitscore = 75) : 
    winner = 0
    labels_blast=["qseqid", "sseqid", "pident", "length", "mismatch", "gapopen", "qstart", "qend", "sstart", "send", "evalue", "bitscore"]
    blast_df = pd.read_csv(path_blast_out, sep = "\t", names = labels_blast)
    if len(blast_df) > 0 :
        row = blast_df.iloc[0] 
        if row["bitscore"] > bitscore and length_seq/int(row["length"])> 0.8:
            winner = dico_cluster_r[row["sseqid"]]
        else :
            winner = "No hits"
    else :
        winner = "No hits"
    return winner

def get_winner(record , path_tmp) :
    path_func , len_func = tmp_fasta_file(record, path_tmp)
    path_blast_out_func = blast_seq(path_func , path_db, path_tmp)
    winner = get_best_candidate(path_blast_out_func, len_func)
    return winner

# %% [markdown]
# > Ferriol et al

# %%
ferriol_winners = []
for record in tqdm(set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        vector = [0]*len(dico_cluster)
        vector[hit] = 1
        vector = np.array(vector)
        a = (record.description , winner, vector)
    else :
        vector = "Null"
    a = (record.description , winner, vector)
    ferriol_winners.append(a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:07<00:00, 17.44it/s]

# %% [markdown]
# > Bea et al

# %%
bea_winners = []

path_bea = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Bea"
path_domains_bea = f"{path_bea}/DepoScope_predictions.bea.domains.0709.fasta"

bea_dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_domains_bea}", "fasta") if len(record.seq) >0}
bea_set_records = [record for record in SeqIO.parse(f"{path_domains_bea}", "fasta") if len(record.seq) > 0]

for record in tqdm(bea_set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        vector = [0]*len(dico_cluster)
        vector[hit] = 1
        vector = np.array(vector)
        a = (record.description , winner, vector)
    else :
        vector = "Null"
    a = (record.description , winner, vector)
    bea_winners.append(a)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 71/71 [00:03<00:00, 20.61it/s]

# %% [markdown]
# > Towndsend et al

# %%
towndsend_winners = []

path_towndsend = "/media/concha-eloko/Linux/PPT_clean/in_vitro/Townsed"
path_domains_towndsend = f"{path_towndsend}/DepoScope_predictions.Townsed.domains.0909.fasta"

towndsend_dico_seq = {record.description : record.seq for record in SeqIO.parse(f"{path_domains_towndsend}", "fasta") if len(record.seq) >0}
towndsend_set_records = [record for record in SeqIO.parse(f"{path_domains_towndsend}", "fasta") if len(record.seq) > 0]

for record in tqdm(towndsend_set_records) :
    winner = get_winner(record, path_tmp)
    if winner != "No hits" :
        hit = int(winner.split("_")[-1])
        vector = [0]*len(dico_cluster)
        vector[hit] = 1
        vector = np.array(vector)
        a = (record.description , winner, vector)
    else :
        vector = "Null"
    a = (record.description , winner, vector)
    towndsend_winners.append(a)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44/44 [00:02<00:00, 21.91it/s]

# %% [markdown]
# ***
# # Make predictions

# %%
import pickle
import os
from joblib import load

path_seqbased = "/media/concha-eloko/Linux/PPT_clean"

models_TropiSeq = {}

for rf_model in os.listdir(f"{path_seqbased}/Seqbased_model/1702_models") :
        kltype = rf_model.split("_RF_")[1].split(".")[0]
        with open(f"{path_seqbased}/Seqbased_model/1702_models/{rf_model}", 'rb') as file:
            models_TropiSeq[kltype] = load(file)

TropiSeq_results = {}

# %% [markdown]
# > Get predictions :

# %%
# Ferriol part : 
for _,winner in tqdm(enumerate(ferriol_winners)) :
    if isinstance(winner[2], np.ndarray):
        tmp_positif = {}
        for kltype in models_TropiSeq :
            pred = models_TropiSeq[kltype].predict_proba(np.array(winner[2]).reshape(1, -1))
            if pred[0][1] >= 0.5 :
                tmp_positif[kltype] = pred[0][1]
        TropiSeq_results[winner[0]] = tmp_positif
    else : 
        TropiSeq_results[winner[0]] = "No hits"

# Bea part : 
for _,winner in tqdm(enumerate(bea_winners)) :
    if isinstance(winner[2], np.ndarray):
        tmp_positif = {}
        for kltype in models_TropiSeq :
            pred = models_TropiSeq[kltype].predict_proba(np.array(winner[2]).reshape(1, -1))
            if pred[0][1] >= 0.5 :
                tmp_positif[kltype] = pred[0][1]
        TropiSeq_results[winner[0]] = tmp_positif
    else : 
        TropiSeq_results[winner[0]] = "No hits"

# Towndsend part :
for _,winner in tqdm(enumerate(towndsend_winners)) :
    if isinstance(winner[2], np.ndarray):
        tmp_positif = {}
        for kltype in models_TropiSeq :
            pred = models_TropiSeq[kltype].predict_proba(np.array(winner[2]).reshape(1, -1))
            if pred[0][1] >= 0.5 :
                tmp_positif[kltype] = pred[0][1]
        TropiSeq_results[winner[0]] = tmp_positif
    else : 
        TropiSeq_results[winner[0]] = "No hits"


with open("/media/concha-eloko/Linux/PPT_clean/Seqbased_model.results.bit75.1902.tsv" , "w") as outfile :
    for prot in TropiSeq_results :
        if TropiSeq_results[prot] == "No hits" :
            outfile.write(f"{prot}\tNo hits\n")
        elif len(TropiSeq_results[prot]) == 0 :
            outfile.write(f"{prot}\tNo predictions\n")
        else :
            outfile.write(f"{prot}\t")
            hits = [f"{kltype}:{round(score,3)}" for kltype, score in TropiSeq_results[prot].items()]
            outfile.write(";".join(hits))
            outfile.write("\n")
# Out:
# 126it [06:40,  3.18s/it]
# 71it [04:29,  3.80s/it]
# 44it [02:15,  3.07s/it]

# %%
with open("/media/concha-eloko/Linux/PPT_clean/Seqbased_model.results.bit75.tsv" , "w") as outfile :
    for prot in TropiSeq_results :
        if TropiSeq_results[prot] == "No hits" :
            outfile.write(f"{prot}\tNo hits\n")
        elif len(TropiSeq_results[prot]) == 0 :
            outfile.write(f"{prot}\tNo hits\n")
        else :
            outfile.write(f"{prot}\t")
            hits = [f"{kltype}:{round(score,3)}" for kltype, score in TropiSeq_results[prot].items()]
            outfile.write(" ; ".join(hits))
            outfile.write("\n")

# %%
import pprint
pp = pprint.PrettyPrinter(width = 150, sort_dicts = True, compact = True)
out = pp.pprint(TropiSeq_results)
# Out:
# {'A1a_00002': {'KL102': 0.736972444555183},
#  'A1a_00014': {'KL151': 0.5987065085723603},
#  'A1b_00036': {'KL102': 0.736972444555183},
#  'A1b_00048': {},
#  'A1c_00034': 'No hits',
#  'A1c_00046': {'KL102': 0.736972444555183},
#  'A1d_00009': {},
#  'A1d_00013': {'KL102': 0.736972444555183},
#  'A1e_00012': {'KL112': 0.7797781306684983,
#                'KL21': 0.7394041356865866,
#                'KL24': 0.8104974796418947,
#                'KL28': 0.6286225729028304,
#                'KL39': 0.6602983248255738,
#                'KL48': 0.5854146520575353,
#                'KL8': 0.6666666666666659},
#  'A1e_00024': {'KL102': 0.736972444555183},
#  'A1f_00012': {'KL112': 0.7797781306684983,
#                'KL21': 0.7394041356865866,
#                'KL24': 0.8104974796418947,
#                'KL28': 0.6286225729028304,
#                'KL39': 0.6602983248255738,
#                'KL48': 0.5854146520575353,
#                'KL8': 0.6666666666666659},
#  'A1f_00024': {'KL102': 0.736972444555183},
#  'A1g_00045': {'KL102': 0.736972444555183},
#  'A1g_00057': 'No hits',
#  'A1h_00009': {'KL102': 0.736972444555183},
#  'A1h_00013': {'KL48': 0.5675088102903976},
#  'A1h_00021': {'KL2': 0.6751802370622282},
#  'A1i_00037': {'KL102': 0.736972444555183},
#  'A1i_00041': {'KL48': 0.5675088102903976},
#  'A1i_00049': {},
#  'A1j_00002': {'KL102': 0.736972444555183},
#  'A1j_00040': {},
#  'A1j_00049': {},
#  'A1k_00014': {'KL106': 0.5033422025727726, 'KL110': 0.7253609541459549, 'KL22': 0.6990102639296187, 'KL37': 0.8910256410256411},
#  